# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import pandas as pd

# %% [markdown]
# # Create dataset object for dataloader for XOR dataset

# %%
class Iris_dataset(torch.utils.data.Dataset):
    def __init__(self, data, labels):
        self.x = torch.tensor(data, dtype=torch.float32)
        self.y = torch.tensor(labels, dtype=torch.long)
        
    def __len__(self):
        return len(self.x)
    
    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]

# %%
data = pd.read_csv('../data/IRIS.csv')
df_norm = data[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']].apply(lambda x: (x - x.min()) / (x.max() - x.min()))
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
target= labelencoder.fit_transform(data['species'])
target = pd.DataFrame(target)
target.rename(columns = {0:'species'}, inplace = True)
df = pd.concat([df_norm, target], axis=1)

# %%
class ConstructNet(nn.Module):
    def __init__(self, DNA, loss_fn, input_size, output_size, outputlayer):
        print(DNA)
        super(ConstructNet, self).__init__()
        self.DNA = DNA
        self.input_size = input_size
        self.output_size = output_size
        self.layers = []
        self.loss_fn = loss_fn
        
        # Append first layer
        self.layers.append(nn.Linear(self.input_size, self.DNA[0][1]))
        self.layers.append(nn.ReLU())
        
        for i in range(1, len(self.DNA)):
            print(self.DNA[i])
            if self.DNA[i][0] == "D":
                # The input size is the output of the last layer
                tmp_input_size = self.last_layer_output_size()
                self.layers.append(nn.Linear(tmp_input_size, self.DNA[i][1]))
                self.layers.append(nn.ReLU())
            if self.DNA[i][0] == "R":
                self.layers.append(nn.Dropout(self.DNA[i][1]))
        
        # Append the output layer        
        self.layers.append(nn.Linear(self.layers[-2].out_features, self.output_size))
        #if self.output_size > 1: 
        #    self.layers.append(nn.Softmax(dim=1))
        #else:
        #    self.layers.append(nn.Sigmoid())
        self.layers.append(outputlayer)
        self.net = nn.Sequential(*self.layers)
        
    def forward(self, x):
        return self.net(x)
    '''
    Based on the layers created, find the output size of the last dense layer
    '''
    def last_layer_output_size(self):
        for layer in self.layers[::-1]:
            if isinstance(layer, nn.Linear):
                return layer.out_features
            
    def train_net(self, device, train_loader, optimizer, epoch, log_interval, print_stats):
        self.train()
        for batch_idx, (data, target) in enumerate(train_loader):
            data, target = data.to(device), target.to(device)
            optimizer.zero_grad()
            output = self.forward(data)
            loss = self.loss_fn(output, target)
            loss.backward()
            optimizer.step()
            if batch_idx % log_interval == 0 and print_stats:
                print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                    epoch, batch_idx * len(data), len(train_loader.dataset),
                    100. * batch_idx / len(train_loader), loss.item()))


    def test(self, device, test_loader, print_stats=False):
        self.eval()
        test_loss = 0
        correct = 0
        with torch.no_grad():
            for data, target in test_loader:
                data, target = data.to(device), target.to(device)
                output = self.forward(data)
                #print(f"output: {output}, target: {target}")
                test_loss += self.loss_fn.forward(output, target).item()  # sum up batch loss
                pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
                correct += pred.eq(target.view_as(pred)).sum().item()
        test_loss /= len(test_loader.dataset)
        accuracy = correct / len(test_loader.dataset)
        if print_stats:
            print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
                test_loss, correct, len(test_loader.dataset),
                100. * accuracy))
        return test_loss, accuracy
        
    def count_parameters(self):
        # https://discuss.pytorch.org/t/how-do-i-check-the-number-of-parameters-of-a-model/4325/7
        return sum(p.numel() for p in self.net.parameters() if p.requires_grad)

# %%
DNA_list = [
    [["D",1024],["D",512],["D",128]],
    [["D",1024],["R",0.2],["D",512],["R",0.2],["D",128]],
    [["D",64],["D", 64]]
]

# %% [markdown]
# # Initialise hyperparameters

# %%
batch_size = 16
use_mps = False and torch.backends.mps.is_available()
use_cuda = True and torch.cuda.is_available()
test_batch_size = 16
epochs = 30
lr = 0.02
gamma = 0.7
seed = 1
log_interval = 100
save_model = False

if use_cuda:
    device = torch.device("cuda")
elif use_mps:
    device = torch.device("mps")
else:
    device = torch.device("cpu")
    
train_kwargs = {'batch_size': batch_size}
test_kwargs = {'batch_size': test_batch_size}

# %%
train_dataset = Iris_dataset(df.values[:,:4], df['species'])
test_dataset = Iris_dataset(df.values[:,:4], df['species'])
train_loader = torch.utils.data.DataLoader(train_dataset,shuffle=True,**train_kwargs)
test_loader = torch.utils.data.DataLoader(test_dataset,shuffle=True, **test_kwargs)

# %%
outputlayer = nn.Softmax(dim=1)
generations = [[]]

for DNA in DNA_list:
    inv_net = ConstructNet(DNA, nn.CrossEntropyLoss(), input_size=4, output_size=3, outputlayer=outputlayer)
    print(inv_net)
    optimizer = optim.Adam(inv_net.parameters(), lr=lr)

    for epoch in range(1, epochs + 1):
        inv_net.train_net(device, train_loader, optimizer, epoch, log_interval, print_stats=True)
        inv_net.test(device, test_loader)
    if save_model:
        torch.save(inv_net.state_dict(), "mnist_cnn.pt")
    generations[0].append(inv_net)
# Out:
# ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=1024, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=1024, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=128, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=128, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )
# Train Epoch: 1 [0/150 (0%)]	Loss: 1.098945
# Train Epoch: 2 [0/150 (0%)]	Loss: 1.238945
# Train Epoch: 3 [0/150 (0%)]	Loss: 1.238945
# Train Epoch: 4 [0/150 (0%)]	Loss: 1.301445
# Train Epoch: 5 [0/150 (0%)]	Loss: 1.238945
# Train Epoch: 6 [0/150 (0%)]	Loss: 1.363945
# Train Epoch: 7 [0/150 (0%)]	Loss: 1.176445
# Train Epoch: 8 [0/150 (0%)]	Loss: 1.113945
# Train Epoch: 9 [0/150 (0%)]	Loss: 1.113945
# Train Epoch: 10 [0/150 (0%)]	Loss: 0.988945
# Train Epoch: 11 [0/150 (0%)]	Loss: 1.301445
# Train Epoch: 12 [0/150 (0%)]	Loss: 1.051445
# Train Epoch: 13 [0/150 (0%)]	Loss: 1.301445
# Train Epoch: 14 [0/150 (0%)]	Loss: 1.051445
# Train Epoch: 15 [0/150 (0%)]	Loss: 1.238945
# Train Epoch: 16 [0/150 (0%)]	Loss: 1.238945
# Train Epoch: 17 [0/150 (0%)]	Loss: 1.113945
# Train Epoch: 18 [0/150 (0%)]	Loss: 1.238945
# Train Epoch: 19 [0/150 (0%)]	Loss: 1.238945
# Train Epoch: 20 [0/150 (0%)]	Loss: 1.363945
# Train Epoch: 21 [0/150 (0%)]	Loss: 0.863945
# Train Epoch: 22 [0/150 (0%)]	Loss: 1.176445
# Train Epoch: 23 [0/150 (0%)]	Loss: 1.301445
# Train Epoch: 24 [0/150 (0%)]	Loss: 1.301445
# Train Epoch: 25 [0/150 (0%)]	Loss: 1.113945
# Train Epoch: 26 [0/150 (0%)]	Loss: 1.176445
# Train Epoch: 27 [0/150 (0%)]	Loss: 1.238945
# Train Epoch: 28 [0/150 (0%)]	Loss: 1.113945
# Train Epoch: 29 [0/150 (0%)]	Loss: 1.051445
# Train Epoch: 30 [0/150 (0%)]	Loss: 1.238945
# ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=1024, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=1024, out_features=512, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=512, out_features=128, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=128, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )
# Train Epoch: 1 [0/150 (0%)]	Loss: 1.096900
# Train Epoch: 2 [0/150 (0%)]	Loss: 1.488945
# Train Epoch: 3 [0/150 (0%)]	Loss: 1.051445
# Train Epoch: 4 [0/150 (0%)]	Loss: 1.176445
# Train Epoch: 5 [0/150 (0%)]	Loss: 1.176445
# Train Epoch: 6 [0/150 (0%)]	Loss: 1.238945
# Train Epoch: 7 [0/150 (0%)]	Loss: 1.176445
# Train Epoch: 8 [0/150 (0%)]	Loss: 1.176445
# Train Epoch: 9 [0/150 (0%)]	Loss: 1.301445
# Train Epoch: 10 [0/150 (0%)]	Loss: 1.301445
# Train Epoch: 11 [0/150 (0%)]	Loss: 1.176445
# Train Epoch: 12 [0/150 (0%)]	Loss: 1.238945
# Train Epoch: 13 [0/150 (0%)]	Loss: 1.363945
# Train Epoch: 14 [0/150 (0%)]	Loss: 1.113945
# Train Epoch: 15 [0/150 (0%)]	Loss: 1.238945
# Train Epoch: 16 [0/150 (0%)]	Loss: 1.363945
# Train Epoch: 17 [0/150 (0%)]	Loss: 1.113945
# Train Epoch: 18 [0/150 (0%)]	Loss: 1.301445
# Train Epoch: 19 [0/150 (0%)]	Loss: 0.988945
# Train Epoch: 20 [0/150 (0%)]	Loss: 1.176445
# Train Epoch: 21 [0/150 (0%)]	Loss: 1.301445
# Train Epoch: 22 [0/150 (0%)]	Loss: 1.238945
# Train Epoch: 23 [0/150 (0%)]	Loss: 0.926445
# Train Epoch: 24 [0/150 (0%)]	Loss: 1.238945
# Train Epoch: 25 [0/150 (0%)]	Loss: 1.238945
# Train Epoch: 26 [0/150 (0%)]	Loss: 1.176445
# Train Epoch: 27 [0/150 (0%)]	Loss: 1.113945
# Train Epoch: 28 [0/150 (0%)]	Loss: 1.176445
# Train Epoch: 29 [0/150 (0%)]	Loss: 1.176445
# Train Epoch: 30 [0/150 (0%)]	Loss: 1.176445
# ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=64, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=64, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )
# Train Epoch: 1 [0/150 (0%)]	Loss: 1.103111
# Train Epoch: 2 [0/150 (0%)]	Loss: 0.802231
# Train Epoch: 3 [0/150 (0%)]	Loss: 0.710434
# Train Epoch: 4 [0/150 (0%)]	Loss: 0.579894
# Train Epoch: 5 [0/150 (0%)]	Loss: 0.610562
# Train Epoch: 6 [0/150 (0%)]	Loss: 0.671057
# Train Epoch: 7 [0/150 (0%)]	Loss: 0.574053
# Train Epoch: 8 [0/150 (0%)]	Loss: 0.609702
# Train Epoch: 9 [0/150 (0%)]	Loss: 0.768309
# Train Epoch: 10 [0/150 (0%)]	Loss: 0.561137
# Train Epoch: 11 [0/150 (0%)]	Loss: 0.552477
# Train Epoch: 12 [0/150 (0%)]	Loss: 0.647385
# Train Epoch: 13 [0/150 (0%)]	Loss: 0.566660
# Train Epoch: 14 [0/150 (0%)]	Loss: 0.555079
# Train Epoch: 15 [0/150 (0%)]	Loss: 0.552593
# Train Epoch: 16 [0/150 (0%)]	Loss: 0.560309
# Train Epoch: 17 [0/150 (0%)]	Loss: 0.563923
# Train Epoch: 18 [0/150 (0%)]	Loss: 0.576113
# Train Epoch: 19 [0/150 (0%)]	Loss: 0.551558
# Train Epoch: 20 [0/150 (0%)]	Loss: 0.616771
# Train Epoch: 21 [0/150 (0%)]	Loss: 0.551452
# Train Epoch: 22 [0/150 (0%)]	Loss: 0.794029
# Train Epoch: 23 [0/150 (0%)]	Loss: 0.610380
# Train Epoch: 24 [0/150 (0%)]	Loss: 0.616794
# Train Epoch: 25 [0/150 (0%)]	Loss: 0.669581
# Train Epoch: 26 [0/150 (0%)]	Loss: 0.614461
# Train Epoch: 27 [0/150 (0%)]	Loss: 0.551933
# Train Epoch: 28 [0/150 (0%)]	Loss: 0.560536
# Train Epoch: 29 [0/150 (0%)]	Loss: 0.800265
# Train Epoch: 30 [0/150 (0%)]	Loss: 0.993362

# %%
generations
# Out:
# [[ConstructNet(
#     (loss_fn): CrossEntropyLoss()
#     (net): Sequential(
#       (0): Linear(in_features=4, out_features=1024, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=1024, out_features=512, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=512, out_features=128, bias=True)
#       (5): ReLU()
#       (6): Linear(in_features=128, out_features=3, bias=True)
#       (7): Softmax(dim=1)
#     )
#   ),
#   ConstructNet(
#     (loss_fn): CrossEntropyLoss()
#     (net): Sequential(
#       (0): Linear(in_features=4, out_features=1024, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.2, inplace=False)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): ReLU()
#       (5): Dropout(p=0.2, inplace=False)
#       (6): Linear(in_features=512, out_features=128, bias=True)
#       (7): ReLU()
#       (8): Linear(in_features=128, out_features=3, bias=True)
#       (9): Softmax(dim=1)
#     )
#   ),
#   ConstructNet(
#     (loss_fn): CrossEntropyLoss()
#     (net): Sequential(
#       (0): Linear(in_features=4, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=64, out_features=3, bias=True)
#       (5): Softmax(dim=1)
#     )
#   )]]

# %% [markdown]
# # Start of GA code

# %%
import random
import numpy as np
class GA():
    def __init__(self, generation_length, population_size, initial_size, initial_depth, 
                 lossFn, input_size, output_size, outputLayer, device, train_dataloader, test_dataloader, optimizerFn, epoch):
        self.generation_length = generation_length
        self.population_size = population_size
        self.initial = True # No previous individuals can be used for mutations
        self.initial_size = initial_size
        self.initial_depth = initial_depth
        
        self.lossFn = lossFn
        self.optimizerFn = optimizerFn
        self.input_size = input_size
        self.output_size = output_size
        self.outputLayer = outputLayer
        
        self.device = device
        self.train_dataloader = train_dataloader
        self.test_dataloader = test_dataloader
        self.epoch = epoch
        self.population = []
        
        #self.generate_population()
    
    def auto_evolve(self):
        for i in range(self.generation_length):
            print(f"Generation #{i}")
            self.generate_population()
            self.train_population()
            self.evaluate_population()
            self.calculate_fitness()
            
    def generate_population(self):
        tmp_list = []
        for index,item in enumerate(self.population):
            tmp_list.append({
                'genome': item['genome'],
                'model': item['model'],
            })
        self.population = tmp_list
        del tmp_list
        
        if self.initial:
            for i in range(self.population_size):
                genome = self.generate_individual()
                self.population.append({'genome': genome})
        else:
            # Delete 25% of the population
            del self.population[:int(np.floor(self.population_size/4))]
            # Generate new individuals to have the same population size
            for i in range(self.population_size-len(self.population)):
                genome = self.generate_individual()
                self.population.append({'genome': genome})
        # Create models for each individual        
        for index,individual in enumerate(self.population):
            model = ConstructNet(individual['genome'], self.lossFn, self.input_size, self.output_size, self.outputLayer)
            individual['model'] = model
            self.population[index] = individual
        self.initial = False
            
    def generate_individual(self):
        genome = []
        if self.initial:
            for chromosome in range(random.randint(np.floor(self.initial_depth/2), np.ceil(self.initial_depth*2))):
                layer_size = random.randint(np.floor(self.initial_size/2), np.ceil(self.initial_size*2))
                genome.append(["D",layer_size])
        else:
            # Get the DNA of one of the best 5 individuals, that are at the end of the list
            random_index = random.randint(len(self.population)-5, len(self.population)-1)
            #print(random_index)
            original_genome = self.population[random_index]['genome'].copy()
            genome = self.mutate_genome(original_genome)
        #print(genome)
        return genome
    
    def mutate_genome(self, genome):
        # example genome: [["D",1024],["D",512],["D",128]]
        # possible mutations: Add new larger layer, add new smaller layer, change layer size, remove layer
        # 1. Add new larger layer
        if random.random() < 0.25:
            # select random layer
            layer_index = random.randint(0, len(genome)-1)
            new_layer_size = np.ceil(genome[layer_index][1] * (1 + random.random())).astype(int)
            genome.insert(layer_index, ["D",new_layer_size])
        # 2. Add new smaller layer
        if random.random() < 0.25:
            # select random layer
            layer_index = random.randint(0, len(genome)-1)
            new_layer_size = np.floor(genome[layer_index][1] * (1 - random.random())).astype(int)
            genome.insert(layer_index, ["D",new_layer_size])
        # 3. Change layer size
        if random.random() < 0.25:
            # select random layer
            layer_index = random.randint(0, len(genome)-1)
            new_layer_size = np.round(genome[layer_index][1] * random.random()).astype(int)
            genome[layer_index][1] = new_layer_size
        # 4. Remove layer
        if random.random() < 0.25 and len(genome) > 1:
            # select random layer
            layer_index = random.randint(0, len(genome)-1)
            del genome[layer_index]
        return genome
    
    def print_population(self, top_n=False):
        if not top_n:
            top_n = len(self.population)
        for index,individual in enumerate(self.population[-top_n:]):
            print(f"Individual #{index}: {individual}")
            
    def train_population(self):
        print(self.population)
        for index,individual in enumerate(self.population):
            print(f"Training individual #{index}")
            if self.optimizerFn == "Adam":
                optimizer = torch.optim.Adam(individual['model'].parameters(), lr=0.01)
            individual['model'].train_net(self.device,self.train_dataloader, optimizer,self.epoch, 100, False)
    
    def evaluate_population(self):
        for index,individual in enumerate(self.population):
            print(f"Evaluating individual #{index}")
            loss, accuracy = individual['model'].test(self.device, self.test_dataloader)
            individual['id'] = index
            individual['loss'] = loss
            individual['accuracy'] = accuracy
            individual['parameters'] = individual['model'].count_parameters()
            self.population[index] = individual
        
    def calculate_fitness(self):
        # Create copy of list using only a few columns
        tmp_list = []
        for index,item in enumerate(self.population):
            tmp_list.append({
                'id' : item['id'],
                'accuracy': item['accuracy'],
                'parameters': item['parameters'],
                'fitness': 0
            })
        accuracy_list = sorted(tmp_list, key=lambda d: d['accuracy'])
        # Adding more emphasis on accuracy
        for index,item in enumerate(accuracy_list):
            accuracy_list[index]['fitness'] += index*2
        # Reverse sort, smaller is better
        parameter_size_list = sorted(accuracy_list, key=lambda d: d['parameters'], reverse=True)
        for index,item in enumerate(parameter_size_list):
            parameter_size_list[index]['fitness'] += index
        sorted_by_fitness = sorted(parameter_size_list, key=lambda d: d['fitness'])
        for fitness in sorted_by_fitness:
            for index,individual in enumerate(self.population):
                if individual['id'] == fitness['id']:
                    individual['fitness'] = fitness['fitness']
            self.population[index] = individual
        # Sort population
        self.population = sorted(self.population, key=lambda d: d['fitness'])
        #print(self.population)

# %%
train_dataset = Iris_dataset(df.values[:,:4], df['species'])
test_dataset = Iris_dataset(df.values[:,:4], df['species'])
train_loader = torch.utils.data.DataLoader(train_dataset,shuffle=True,**train_kwargs)
test_loader = torch.utils.data.DataLoader(test_dataset,shuffle=True, **test_kwargs)

generation = GA(generation_length=10,population_size=50,initial_size=256,initial_depth=5, lossFn=nn.CrossEntropyLoss(), input_size=4, output_size=3, outputLayer=nn.Softmax(dim=1), device=device, train_dataloader=train_loader, test_dataloader=test_loader, optimizerFn="Adam", epoch=100  )
generation.generate_population()
generation.print_population()
# Out:
# [['D', 157], ['D', 442], ['D', 493], ['D', 274], ['D', 256], ['D', 428], ['D', 339], ['D', 197]]
# ['D', 442]
# ['D', 493]
# ['D', 274]
# ['D', 256]
# ['D', 428]
# ['D', 339]
# ['D', 197]
# [['D', 385], ['D', 130], ['D', 457], ['D', 314]]
# ['D', 130]
# ['D', 457]
# ['D', 314]
# [['D', 436], ['D', 383], ['D', 373], ['D', 249], ['D', 222], ['D', 510], ['D', 256], ['D', 377], ['D', 282], ['D', 139]]
# ['D', 383]
# ['D', 373]
# ['D', 249]
# ['D', 222]
# ['D', 510]
# ['D', 256]
# ['D', 377]
# ['D', 282]
# ['D', 139]
# [['D', 332], ['D', 370], ['D', 151], ['D', 296], ['D', 409], ['D', 248], ['D', 424], ['D', 169]]
# ['D', 370]
# ['D', 151]
# ['D', 296]
# ['D', 409]
# ['D', 248]
# ['D', 424]
# ['D', 169]
# [['D', 222], ['D', 154], ['D', 219]]
# ['D', 154]
# ['D', 219]
# [['D', 337], ['D', 312]]
# ['D', 312]
# [['D', 291], ['D', 181]]
# ['D', 181]
# [['D', 195], ['D', 428]]
# ['D', 428]
# [['D', 202], ['D', 185]]
# ['D', 185]
# [['D', 262], ['D', 224]]
# ['D', 224]
# [['D', 472], ['D', 352], ['D', 404], ['D', 211], ['D', 332], ['D', 475], ['D', 281], ['D', 362], ['D', 413], ['D', 390]]
# ['D', 352]
# ['D', 404]
# ['D', 211]
# ['D', 332]
# ['D', 475]
# ['D', 281]
# ['D', 362]
# ['D', 413]
# ['D', 390]
# [['D', 455], ['D', 210], ['D', 431], ['D', 483], ['D', 376], ['D', 473]]
# ['D', 210]
# ['D', 431]
# ['D', 483]
# ['D', 376]
# ['D', 473]
# [['D', 465], ['D', 188], ['D', 286], ['D', 247], ['D', 155], ['D', 134], ['D', 509], ['D', 433]]
# ['D', 188]
# ['D', 286]
# ['D', 247]
# ['D', 155]
# ['D', 134]
# ['D', 509]
# ['D', 433]
# [['D', 230], ['D', 325]]
# ['D', 325]
# [['D', 395], ['D', 198]]
# ['D', 198]
# [['D', 391], ['D', 149], ['D', 229], ['D', 256], ['D', 137], ['D', 362], ['D', 469]]
# ['D', 149]
# ['D', 229]
# ['D', 256]
# ['D', 137]
# ['D', 362]
# ['D', 469]
# [['D', 208], ['D', 186], ['D', 160], ['D', 455], ['D', 174], ['D', 194], ['D', 288], ['D', 160], ['D', 499]]
# ['D', 186]
# ['D', 160]
# ['D', 455]
# ['D', 174]
# ['D', 194]
# ['D', 288]
# ['D', 160]
# ['D', 499]
# [['D', 200], ['D', 277], ['D', 428], ['D', 482], ['D', 182], ['D', 446], ['D', 395]]
# ['D', 277]
# ['D', 428]
# ['D', 482]
# ['D', 182]
# ['D', 446]
# ['D', 395]
# [['D', 416], ['D', 467], ['D', 447]]
# ['D', 467]
# ['D', 447]
# [['D', 455], ['D', 324], ['D', 164], ['D', 474], ['D', 468], ['D', 341], ['D', 344], ['D', 213], ['D', 210], ['D', 264]]
# ['D', 324]
# ['D', 164]
# ['D', 474]
# ['D', 468]
# ['D', 341]
# ['D', 344]
# ['D', 213]
# ['D', 210]
# ['D', 264]
# [['D', 512], ['D', 363]]
# ['D', 363]
# [['D', 405], ['D', 376], ['D', 438], ['D', 175]]
# ['D', 376]
# ['D', 438]
# ['D', 175]
# [['D', 222], ['D', 320], ['D', 195], ['D', 174], ['D', 452]]
# ['D', 320]
# ['D', 195]
# ['D', 174]
# ['D', 452]
# [['D', 412], ['D', 393], ['D', 446], ['D', 376], ['D', 350], ['D', 459], ['D', 330]]
# ['D', 393]
# ['D', 446]
# ['D', 376]
# ['D', 350]
# ['D', 459]
# ['D', 330]
# [['D', 271], ['D', 469], ['D', 249], ['D', 461], ['D', 330], ['D', 141], ['D', 149], ['D', 131]]
# ['D', 469]
# ['D', 249]
# ['D', 461]
# ['D', 330]
# ['D', 141]
# ['D', 149]
# ['D', 131]
# [['D', 150], ['D', 511]]
# ['D', 511]
# [['D', 304], ['D', 422], ['D', 436]]
# ['D', 422]
# ['D', 436]
# [['D', 213], ['D', 208]]
# ['D', 208]
# [['D', 248], ['D', 240]]
# ['D', 240]
# [['D', 330], ['D', 297], ['D', 144], ['D', 219], ['D', 490], ['D', 183], ['D', 227], ['D', 480], ['D', 175]]
# ['D', 297]
# ['D', 144]
# ['D', 219]
# ['D', 490]
# ['D', 183]
# ['D', 227]
# ['D', 480]
# ['D', 175]
# [['D', 408], ['D', 281], ['D', 228]]
# ['D', 281]
# ['D', 228]
# [['D', 129], ['D', 424], ['D', 135], ['D', 210], ['D', 246], ['D', 201], ['D', 323], ['D', 306], ['D', 267]]
# ['D', 424]
# ['D', 135]
# ['D', 210]
# ['D', 246]
# ['D', 201]
# ['D', 323]
# ['D', 306]
# ['D', 267]
# [['D', 342], ['D', 402], ['D', 436]]
# ['D', 402]
# ['D', 436]
# [['D', 501], ['D', 459], ['D', 440], ['D', 427], ['D', 368], ['D', 382], ['D', 496], ['D', 134], ['D', 403]]
# ['D', 459]
# ['D', 440]
# ['D', 427]
# ['D', 368]
# ['D', 382]
# ['D', 496]
# ['D', 134]
# ['D', 403]
# [['D', 504], ['D', 217], ['D', 371], ['D', 442], ['D', 134], ['D', 193]]
# ['D', 217]
# ['D', 371]
# ['D', 442]
# ['D', 134]
# ['D', 193]
# [['D', 489], ['D', 202], ['D', 344], ['D', 493], ['D', 387], ['D', 203]]
# ['D', 202]
# ['D', 344]
# ['D', 493]
# ['D', 387]
# ['D', 203]
# [['D', 304], ['D', 395]]
# ['D', 395]
# [['D', 263], ['D', 312], ['D', 270]]
# ['D', 312]
# ['D', 270]
# [['D', 441], ['D', 352], ['D', 174], ['D', 208], ['D', 389], ['D', 454]]
# ['D', 352]
# ['D', 174]
# ['D', 208]
# ['D', 389]
# ['D', 454]
# [['D', 321], ['D', 129], ['D', 355], ['D', 130], ['D', 490], ['D', 169], ['D', 365], ['D', 323], ['D', 153]]
# ['D', 129]
# ['D', 355]
# ['D', 130]
# ['D', 490]
# ['D', 169]
# ['D', 365]
# ['D', 323]
# ['D', 153]
# [['D', 386], ['D', 320], ['D', 497], ['D', 438], ['D', 309]]
# ['D', 320]
# ['D', 497]
# ['D', 438]
# ['D', 309]
# [['D', 169], ['D', 418], ['D', 506], ['D', 471], ['D', 389], ['D', 192]]
# ['D', 418]
# ['D', 506]
# ['D', 471]
# ['D', 389]
# ['D', 192]
# [['D', 360], ['D', 413], ['D', 149], ['D', 248], ['D', 439]]
# ['D', 413]
# ['D', 149]
# ['D', 248]
# ['D', 439]
# [['D', 416], ['D', 360], ['D', 239]]
# ['D', 360]
# ['D', 239]
# [['D', 266], ['D', 136], ['D', 146], ['D', 204], ['D', 333]]
# ['D', 136]
# ['D', 146]
# ['D', 204]
# ['D', 333]
# [['D', 370], ['D', 403], ['D', 438], ['D', 339], ['D', 386], ['D', 298]]
# ['D', 403]
# ['D', 438]
# ['D', 339]
# ['D', 386]
# ['D', 298]
# [['D', 423], ['D', 154], ['D', 418], ['D', 501], ['D', 493], ['D', 157], ['D', 200], ['D', 498], ['D', 329], ['D', 131]]
# ['D', 154]
# ['D', 418]
# ['D', 501]
# ['D', 493]
# ['D', 157]
# ['D', 200]
# ['D', 498]
# ['D', 329]
# ['D', 131]
# [['D', 337], ['D', 394]]
# ['D', 394]
# [['D', 468], ['D', 180], ['D', 411], ['D', 143], ['D', 260], ['D', 371]]
# ['D', 180]
# ['D', 411]
# ['D', 143]
# ['D', 260]
# ['D', 371]
# [['D', 376], ['D', 345], ['D', 507], ['D', 501], ['D', 347], ['D', 224], ['D', 207], ['D', 335], ['D', 321]]
# ['D', 345]
# ['D', 507]
# ['D', 501]
# ['D', 347]
# ['D', 224]
# ['D', 207]
# ['D', 335]
# ['D', 321]
# Individual #0: {'genome': [['D', 157], ['D', 442], ['D', 493], ['D', 274], ['D', 256], ['D', 428], ['D', 339], ['D', 197]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=157, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=157, out_features=442, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=442, out_features=493, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=493, out_features=274, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=274, out_features=256, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=256, out_features=428, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=428, out_features=339, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=339, out_features=197, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=197, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}
# Individual #1: {'genome': [['D', 385], ['D', 130], ['D', 457], ['D', 314]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=385, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=385, out_features=130, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=130, out_features=457, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=457, out_features=314, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=314, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}
# Individual #2: {'genome': [['D', 436], ['D', 383], ['D', 373], ['D', 249], ['D', 222], ['D', 510], ['D', 256], ['D', 377], ['D', 282], ['D', 139]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=436, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=436, out_features=383, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=383, out_features=373, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=373, out_features=249, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=249, out_features=222, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=222, out_features=510, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=510, out_features=256, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=256, out_features=377, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=377, out_features=282, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=282, out_features=139, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=139, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# )}
# Individual #3: {'genome': [['D', 332], ['D', 370], ['D', 151], ['D', 296], ['D', 409], ['D', 248], ['D', 424], ['D', 169]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=332, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=332, out_features=370, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=370, out_features=151, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=151, out_features=296, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=296, out_features=409, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=409, out_features=248, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=248, out_features=424, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=424, out_features=169, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=169, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}
# Individual #4: {'genome': [['D', 222], ['D', 154], ['D', 219]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=222, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=222, out_features=154, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=154, out_features=219, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=219, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}
# Individual #5: {'genome': [['D', 337], ['D', 312]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=337, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=337, out_features=312, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=312, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}
# Individual #6: {'genome': [['D', 291], ['D', 181]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=291, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=291, out_features=181, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=181, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}
# Individual #7: {'genome': [['D', 195], ['D', 428]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=195, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=195, out_features=428, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=428, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}
# Individual #8: {'genome': [['D', 202], ['D', 185]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=202, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=202, out_features=185, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=185, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}
# Individual #9: {'genome': [['D', 262], ['D', 224]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=262, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=262, out_features=224, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=224, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}
# Individual #10: {'genome': [['D', 472], ['D', 352], ['D', 404], ['D', 211], ['D', 332], ['D', 475], ['D', 281], ['D', 362], ['D', 413], ['D', 390]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=472, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=472, out_features=352, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=352, out_features=404, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=404, out_features=211, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=211, out_features=332, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=332, out_features=475, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=475, out_features=281, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=281, out_features=362, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=362, out_features=413, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=413, out_features=390, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=390, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# )}
# Individual #11: {'genome': [['D', 455], ['D', 210], ['D', 431], ['D', 483], ['D', 376], ['D', 473]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=455, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=455, out_features=210, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=210, out_features=431, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=431, out_features=483, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=483, out_features=376, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=376, out_features=473, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=473, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}
# Individual #12: {'genome': [['D', 465], ['D', 188], ['D', 286], ['D', 247], ['D', 155], ['D', 134], ['D', 509], ['D', 433]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=465, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=465, out_features=188, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=188, out_features=286, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=286, out_features=247, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=247, out_features=155, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=155, out_features=134, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=134, out_features=509, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=509, out_features=433, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=433, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}
# Individual #13: {'genome': [['D', 230], ['D', 325]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=230, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=230, out_features=325, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=325, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}
# Individual #14: {'genome': [['D', 395], ['D', 198]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=395, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=395, out_features=198, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=198, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}
# Individual #15: {'genome': [['D', 391], ['D', 149], ['D', 229], ['D', 256], ['D', 137], ['D', 362], ['D', 469]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=391, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=391, out_features=149, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=149, out_features=229, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=229, out_features=256, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=256, out_features=137, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=137, out_features=362, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=362, out_features=469, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=469, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}
# Individual #16: {'genome': [['D', 208], ['D', 186], ['D', 160], ['D', 455], ['D', 174], ['D', 194], ['D', 288], ['D', 160], ['D', 499]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=208, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=208, out_features=186, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=186, out_features=160, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=160, out_features=455, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=455, out_features=174, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=174, out_features=194, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=194, out_features=288, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=288, out_features=160, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=160, out_features=499, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=499, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}
# Individual #17: {'genome': [['D', 200], ['D', 277], ['D', 428], ['D', 482], ['D', 182], ['D', 446], ['D', 395]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=200, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=200, out_features=277, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=277, out_features=428, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=428, out_features=482, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=482, out_features=182, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=182, out_features=446, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=446, out_features=395, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=395, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}
# Individual #18: {'genome': [['D', 416], ['D', 467], ['D', 447]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=416, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=416, out_features=467, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=467, out_features=447, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=447, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}
# Individual #19: {'genome': [['D', 455], ['D', 324], ['D', 164], ['D', 474], ['D', 468], ['D', 341], ['D', 344], ['D', 213], ['D', 210], ['D', 264]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=455, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=455, out_features=324, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=324, out_features=164, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=164, out_features=474, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=474, out_features=468, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=468, out_features=341, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=341, out_features=344, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=344, out_features=213, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=213, out_features=210, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=210, out_features=264, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=264, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# )}
# Individual #20: {'genome': [['D', 512], ['D', 363]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=363, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=363, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}
# Individual #21: {'genome': [['D', 405], ['D', 376], ['D', 438], ['D', 175]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=405, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=405, out_features=376, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=376, out_features=438, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=438, out_features=175, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=175, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}
# Individual #22: {'genome': [['D', 222], ['D', 320], ['D', 195], ['D', 174], ['D', 452]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=222, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=222, out_features=320, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=320, out_features=195, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=195, out_features=174, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=174, out_features=452, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=452, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}
# Individual #23: {'genome': [['D', 412], ['D', 393], ['D', 446], ['D', 376], ['D', 350], ['D', 459], ['D', 330]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=412, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=412, out_features=393, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=393, out_features=446, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=446, out_features=376, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=376, out_features=350, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=350, out_features=459, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=459, out_features=330, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=330, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}
# Individual #24: {'genome': [['D', 271], ['D', 469], ['D', 249], ['D', 461], ['D', 330], ['D', 141], ['D', 149], ['D', 131]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=271, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=271, out_features=469, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=469, out_features=249, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=249, out_features=461, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=461, out_features=330, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=330, out_features=141, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=141, out_features=149, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=149, out_features=131, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=131, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}
# Individual #25: {'genome': [['D', 150], ['D', 511]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=150, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=150, out_features=511, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=511, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}
# Individual #26: {'genome': [['D', 304], ['D', 422], ['D', 436]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=304, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=304, out_features=422, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=422, out_features=436, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=436, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}
# Individual #27: {'genome': [['D', 213], ['D', 208]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=213, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=213, out_features=208, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=208, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}
# Individual #28: {'genome': [['D', 248], ['D', 240]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=248, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=248, out_features=240, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=240, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}
# Individual #29: {'genome': [['D', 330], ['D', 297], ['D', 144], ['D', 219], ['D', 490], ['D', 183], ['D', 227], ['D', 480], ['D', 175]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=330, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=330, out_features=297, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=297, out_features=144, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=144, out_features=219, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=219, out_features=490, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=490, out_features=183, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=183, out_features=227, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=227, out_features=480, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=480, out_features=175, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=175, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}
# Individual #30: {'genome': [['D', 408], ['D', 281], ['D', 228]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=408, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=408, out_features=281, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=281, out_features=228, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=228, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}
# Individual #31: {'genome': [['D', 129], ['D', 424], ['D', 135], ['D', 210], ['D', 246], ['D', 201], ['D', 323], ['D', 306], ['D', 267]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=129, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=129, out_features=424, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=424, out_features=135, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=135, out_features=210, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=210, out_features=246, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=246, out_features=201, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=201, out_features=323, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=323, out_features=306, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=306, out_features=267, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=267, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}
# Individual #32: {'genome': [['D', 342], ['D', 402], ['D', 436]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=342, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=342, out_features=402, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=402, out_features=436, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=436, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}
# Individual #33: {'genome': [['D', 501], ['D', 459], ['D', 440], ['D', 427], ['D', 368], ['D', 382], ['D', 496], ['D', 134], ['D', 403]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=501, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=501, out_features=459, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=459, out_features=440, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=440, out_features=427, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=427, out_features=368, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=368, out_features=382, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=382, out_features=496, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=496, out_features=134, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=134, out_features=403, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=403, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}
# Individual #34: {'genome': [['D', 504], ['D', 217], ['D', 371], ['D', 442], ['D', 134], ['D', 193]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=504, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=504, out_features=217, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=217, out_features=371, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=371, out_features=442, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=442, out_features=134, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=134, out_features=193, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=193, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}
# Individual #35: {'genome': [['D', 489], ['D', 202], ['D', 344], ['D', 493], ['D', 387], ['D', 203]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=489, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=489, out_features=202, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=202, out_features=344, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=344, out_features=493, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=493, out_features=387, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=387, out_features=203, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=203, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}
# Individual #36: {'genome': [['D', 304], ['D', 395]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=304, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=304, out_features=395, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=395, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}
# Individual #37: {'genome': [['D', 263], ['D', 312], ['D', 270]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=263, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=263, out_features=312, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=312, out_features=270, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=270, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}
# Individual #38: {'genome': [['D', 441], ['D', 352], ['D', 174], ['D', 208], ['D', 389], ['D', 454]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=441, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=441, out_features=352, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=352, out_features=174, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=174, out_features=208, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=208, out_features=389, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=389, out_features=454, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=454, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}
# Individual #39: {'genome': [['D', 321], ['D', 129], ['D', 355], ['D', 130], ['D', 490], ['D', 169], ['D', 365], ['D', 323], ['D', 153]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=321, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=321, out_features=129, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=129, out_features=355, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=355, out_features=130, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=130, out_features=490, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=490, out_features=169, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=169, out_features=365, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=365, out_features=323, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=323, out_features=153, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=153, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}
# Individual #40: {'genome': [['D', 386], ['D', 320], ['D', 497], ['D', 438], ['D', 309]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=386, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=386, out_features=320, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=320, out_features=497, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=497, out_features=438, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=438, out_features=309, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=309, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}
# Individual #41: {'genome': [['D', 169], ['D', 418], ['D', 506], ['D', 471], ['D', 389], ['D', 192]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=169, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=169, out_features=418, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=418, out_features=506, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=506, out_features=471, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=471, out_features=389, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=389, out_features=192, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=192, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}
# Individual #42: {'genome': [['D', 360], ['D', 413], ['D', 149], ['D', 248], ['D', 439]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=360, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=360, out_features=413, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=413, out_features=149, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=149, out_features=248, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=248, out_features=439, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=439, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}
# Individual #43: {'genome': [['D', 416], ['D', 360], ['D', 239]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=416, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=416, out_features=360, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=360, out_features=239, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=239, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}
# Individual #44: {'genome': [['D', 266], ['D', 136], ['D', 146], ['D', 204], ['D', 333]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=266, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=266, out_features=136, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=136, out_features=146, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=146, out_features=204, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=204, out_features=333, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=333, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}
# Individual #45: {'genome': [['D', 370], ['D', 403], ['D', 438], ['D', 339], ['D', 386], ['D', 298]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=370, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=370, out_features=403, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=403, out_features=438, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=438, out_features=339, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=339, out_features=386, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=386, out_features=298, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=298, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}
# Individual #46: {'genome': [['D', 423], ['D', 154], ['D', 418], ['D', 501], ['D', 493], ['D', 157], ['D', 200], ['D', 498], ['D', 329], ['D', 131]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=423, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=423, out_features=154, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=154, out_features=418, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=418, out_features=501, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=501, out_features=493, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=493, out_features=157, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=157, out_features=200, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=200, out_features=498, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=498, out_features=329, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=329, out_features=131, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=131, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# )}
# Individual #47: {'genome': [['D', 337], ['D', 394]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=337, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=337, out_features=394, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=394, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}
# Individual #48: {'genome': [['D', 468], ['D', 180], ['D', 411], ['D', 143], ['D', 260], ['D', 371]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=468, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=468, out_features=180, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=180, out_features=411, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=411, out_features=143, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=143, out_features=260, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=260, out_features=371, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=371, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}
# Individual #49: {'genome': [['D', 376], ['D', 345], ['D', 507], ['D', 501], ['D', 347], ['D', 224], ['D', 207], ['D', 335], ['D', 321]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=376, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=376, out_features=345, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=345, out_features=507, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=507, out_features=501, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=501, out_features=347, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=347, out_features=224, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=224, out_features=207, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=207, out_features=335, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=335, out_features=321, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=321, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}

# %%
generation.train_population()
# Out:
# [{'genome': [['D', 157], ['D', 442], ['D', 493], ['D', 274], ['D', 256], ['D', 428], ['D', 339], ['D', 197]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=157, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=157, out_features=442, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=442, out_features=493, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=493, out_features=274, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=274, out_features=256, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=256, out_features=428, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=428, out_features=339, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=339, out_features=197, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=197, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 385], ['D', 130], ['D', 457], ['D', 314]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=385, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=385, out_features=130, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=130, out_features=457, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=457, out_features=314, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=314, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 436], ['D', 383], ['D', 373], ['D', 249], ['D', 222], ['D', 510], ['D', 256], ['D', 377], ['D', 282], ['D', 139]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=436, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=436, out_features=383, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=383, out_features=373, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=373, out_features=249, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=249, out_features=222, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=222, out_features=510, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=510, out_features=256, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=256, out_features=377, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=377, out_features=282, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=282, out_features=139, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=139, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 332], ['D', 370], ['D', 151], ['D', 296], ['D', 409], ['D', 248], ['D', 424], ['D', 169]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=332, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=332, out_features=370, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=370, out_features=151, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=151, out_features=296, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=296, out_features=409, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=409, out_features=248, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=248, out_features=424, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=424, out_features=169, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=169, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 222], ['D', 154], ['D', 219]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=222, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=222, out_features=154, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=154, out_features=219, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=219, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 337], ['D', 312]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=337, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=337, out_features=312, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=312, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 291], ['D', 181]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=291, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=291, out_features=181, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=181, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 195], ['D', 428]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=195, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=195, out_features=428, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=428, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 202], ['D', 185]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=202, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=202, out_features=185, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=185, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 262], ['D', 224]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=262, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=262, out_features=224, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=224, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 472], ['D', 352], ['D', 404], ['D', 211], ['D', 332], ['D', 475], ['D', 281], ['D', 362], ['D', 413], ['D', 390]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=472, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=472, out_features=352, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=352, out_features=404, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=404, out_features=211, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=211, out_features=332, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=332, out_features=475, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=475, out_features=281, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=281, out_features=362, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=362, out_features=413, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=413, out_features=390, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=390, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 455], ['D', 210], ['D', 431], ['D', 483], ['D', 376], ['D', 473]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=455, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=455, out_features=210, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=210, out_features=431, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=431, out_features=483, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=483, out_features=376, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=376, out_features=473, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=473, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 465], ['D', 188], ['D', 286], ['D', 247], ['D', 155], ['D', 134], ['D', 509], ['D', 433]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=465, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=465, out_features=188, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=188, out_features=286, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=286, out_features=247, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=247, out_features=155, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=155, out_features=134, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=134, out_features=509, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=509, out_features=433, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=433, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 230], ['D', 325]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=230, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=230, out_features=325, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=325, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 395], ['D', 198]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=395, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=395, out_features=198, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=198, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 391], ['D', 149], ['D', 229], ['D', 256], ['D', 137], ['D', 362], ['D', 469]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=391, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=391, out_features=149, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=149, out_features=229, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=229, out_features=256, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=256, out_features=137, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=137, out_features=362, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=362, out_features=469, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=469, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 208], ['D', 186], ['D', 160], ['D', 455], ['D', 174], ['D', 194], ['D', 288], ['D', 160], ['D', 499]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=208, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=208, out_features=186, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=186, out_features=160, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=160, out_features=455, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=455, out_features=174, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=174, out_features=194, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=194, out_features=288, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=288, out_features=160, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=160, out_features=499, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=499, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 200], ['D', 277], ['D', 428], ['D', 482], ['D', 182], ['D', 446], ['D', 395]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=200, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=200, out_features=277, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=277, out_features=428, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=428, out_features=482, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=482, out_features=182, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=182, out_features=446, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=446, out_features=395, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=395, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 416], ['D', 467], ['D', 447]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=416, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=416, out_features=467, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=467, out_features=447, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=447, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 455], ['D', 324], ['D', 164], ['D', 474], ['D', 468], ['D', 341], ['D', 344], ['D', 213], ['D', 210], ['D', 264]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=455, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=455, out_features=324, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=324, out_features=164, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=164, out_features=474, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=474, out_features=468, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=468, out_features=341, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=341, out_features=344, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=344, out_features=213, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=213, out_features=210, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=210, out_features=264, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=264, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 512], ['D', 363]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=363, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=363, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 405], ['D', 376], ['D', 438], ['D', 175]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=405, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=405, out_features=376, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=376, out_features=438, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=438, out_features=175, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=175, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 222], ['D', 320], ['D', 195], ['D', 174], ['D', 452]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=222, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=222, out_features=320, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=320, out_features=195, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=195, out_features=174, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=174, out_features=452, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=452, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 412], ['D', 393], ['D', 446], ['D', 376], ['D', 350], ['D', 459], ['D', 330]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=412, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=412, out_features=393, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=393, out_features=446, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=446, out_features=376, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=376, out_features=350, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=350, out_features=459, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=459, out_features=330, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=330, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 271], ['D', 469], ['D', 249], ['D', 461], ['D', 330], ['D', 141], ['D', 149], ['D', 131]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=271, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=271, out_features=469, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=469, out_features=249, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=249, out_features=461, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=461, out_features=330, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=330, out_features=141, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=141, out_features=149, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=149, out_features=131, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=131, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 150], ['D', 511]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=150, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=150, out_features=511, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=511, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 304], ['D', 422], ['D', 436]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=304, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=304, out_features=422, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=422, out_features=436, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=436, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 213], ['D', 208]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=213, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=213, out_features=208, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=208, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 248], ['D', 240]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=248, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=248, out_features=240, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=240, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 330], ['D', 297], ['D', 144], ['D', 219], ['D', 490], ['D', 183], ['D', 227], ['D', 480], ['D', 175]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=330, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=330, out_features=297, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=297, out_features=144, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=144, out_features=219, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=219, out_features=490, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=490, out_features=183, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=183, out_features=227, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=227, out_features=480, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=480, out_features=175, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=175, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 408], ['D', 281], ['D', 228]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=408, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=408, out_features=281, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=281, out_features=228, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=228, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 129], ['D', 424], ['D', 135], ['D', 210], ['D', 246], ['D', 201], ['D', 323], ['D', 306], ['D', 267]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=129, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=129, out_features=424, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=424, out_features=135, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=135, out_features=210, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=210, out_features=246, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=246, out_features=201, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=201, out_features=323, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=323, out_features=306, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=306, out_features=267, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=267, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 342], ['D', 402], ['D', 436]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=342, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=342, out_features=402, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=402, out_features=436, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=436, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 501], ['D', 459], ['D', 440], ['D', 427], ['D', 368], ['D', 382], ['D', 496], ['D', 134], ['D', 403]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=501, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=501, out_features=459, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=459, out_features=440, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=440, out_features=427, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=427, out_features=368, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=368, out_features=382, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=382, out_features=496, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=496, out_features=134, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=134, out_features=403, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=403, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 504], ['D', 217], ['D', 371], ['D', 442], ['D', 134], ['D', 193]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=504, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=504, out_features=217, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=217, out_features=371, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=371, out_features=442, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=442, out_features=134, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=134, out_features=193, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=193, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 489], ['D', 202], ['D', 344], ['D', 493], ['D', 387], ['D', 203]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=489, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=489, out_features=202, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=202, out_features=344, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=344, out_features=493, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=493, out_features=387, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=387, out_features=203, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=203, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 304], ['D', 395]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=304, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=304, out_features=395, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=395, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 263], ['D', 312], ['D', 270]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=263, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=263, out_features=312, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=312, out_features=270, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=270, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 441], ['D', 352], ['D', 174], ['D', 208], ['D', 389], ['D', 454]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=441, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=441, out_features=352, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=352, out_features=174, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=174, out_features=208, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=208, out_features=389, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=389, out_features=454, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=454, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 321], ['D', 129], ['D', 355], ['D', 130], ['D', 490], ['D', 169], ['D', 365], ['D', 323], ['D', 153]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=321, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=321, out_features=129, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=129, out_features=355, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=355, out_features=130, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=130, out_features=490, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=490, out_features=169, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=169, out_features=365, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=365, out_features=323, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=323, out_features=153, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=153, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 386], ['D', 320], ['D', 497], ['D', 438], ['D', 309]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=386, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=386, out_features=320, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=320, out_features=497, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=497, out_features=438, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=438, out_features=309, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=309, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 169], ['D', 418], ['D', 506], ['D', 471], ['D', 389], ['D', 192]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=169, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=169, out_features=418, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=418, out_features=506, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=506, out_features=471, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=471, out_features=389, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=389, out_features=192, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=192, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 360], ['D', 413], ['D', 149], ['D', 248], ['D', 439]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=360, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=360, out_features=413, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=413, out_features=149, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=149, out_features=248, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=248, out_features=439, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=439, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 416], ['D', 360], ['D', 239]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=416, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=416, out_features=360, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=360, out_features=239, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=239, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 266], ['D', 136], ['D', 146], ['D', 204], ['D', 333]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=266, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=266, out_features=136, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=136, out_features=146, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=146, out_features=204, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=204, out_features=333, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=333, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 370], ['D', 403], ['D', 438], ['D', 339], ['D', 386], ['D', 298]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=370, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=370, out_features=403, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=403, out_features=438, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=438, out_features=339, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=339, out_features=386, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=386, out_features=298, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=298, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 423], ['D', 154], ['D', 418], ['D', 501], ['D', 493], ['D', 157], ['D', 200], ['D', 498], ['D', 329], ['D', 131]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=423, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=423, out_features=154, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=154, out_features=418, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=418, out_features=501, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=501, out_features=493, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=493, out_features=157, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=157, out_features=200, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=200, out_features=498, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=498, out_features=329, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=329, out_features=131, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=131, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 337], ['D', 394]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=337, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=337, out_features=394, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=394, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 468], ['D', 180], ['D', 411], ['D', 143], ['D', 260], ['D', 371]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=468, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=468, out_features=180, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=180, out_features=411, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=411, out_features=143, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=143, out_features=260, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=260, out_features=371, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=371, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 376], ['D', 345], ['D', 507], ['D', 501], ['D', 347], ['D', 224], ['D', 207], ['D', 335], ['D', 321]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=376, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=376, out_features=345, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=345, out_features=507, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=507, out_features=501, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=501, out_features=347, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=347, out_features=224, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=224, out_features=207, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=207, out_features=335, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=335, out_features=321, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=321, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}]
# Training individual #0
# Training individual #1
# Training individual #2
# Training individual #3
# Training individual #4
# Training individual #5
# Training individual #6
# Training individual #7
# Training individual #8
# Training individual #9
# Training individual #10
# Training individual #11
# Training individual #12
# Training individual #13
# Training individual #14
# Training individual #15
# Training individual #16
# Training individual #17
# Training individual #18
# Training individual #19
# Training individual #20
# Training individual #21
# Training individual #22
# Training individual #23
# Training individual #24
# Training individual #25
# Training individual #26
# Training individual #27
# Training individual #28
# Training individual #29
# Training individual #30
# Training individual #31
# Training individual #32
# Training individual #33
# Training individual #34
# Training individual #35
# Training individual #36
# Training individual #37
# Training individual #38
# Training individual #39
# Training individual #40
# Training individual #41
# Training individual #42
# Training individual #43
# Training individual #44
# Training individual #45
# Training individual #46
# Training individual #47
# Training individual #48
# Training individual #49

# %%
generation.evaluate_population()
# Out:
# Evaluating individual #0
# Evaluating individual #1
# Evaluating individual #2
# Evaluating individual #3
# Evaluating individual #4
# Evaluating individual #5
# Evaluating individual #6
# Evaluating individual #7
# Evaluating individual #8
# Evaluating individual #9
# Evaluating individual #10
# Evaluating individual #11
# Evaluating individual #12
# Evaluating individual #13
# Evaluating individual #14
# Evaluating individual #15
# Evaluating individual #16
# Evaluating individual #17
# Evaluating individual #18
# Evaluating individual #19
# Evaluating individual #20
# Evaluating individual #21
# Evaluating individual #22
# Evaluating individual #23
# Evaluating individual #24
# Evaluating individual #25
# Evaluating individual #26
# Evaluating individual #27
# Evaluating individual #28
# Evaluating individual #29
# Evaluating individual #30
# Evaluating individual #31
# Evaluating individual #32
# Evaluating individual #33
# Evaluating individual #34
# Evaluating individual #35
# Evaluating individual #36
# Evaluating individual #37
# Evaluating individual #38
# Evaluating individual #39
# Evaluating individual #40
# Evaluating individual #41
# Evaluating individual #42
# Evaluating individual #43
# Evaluating individual #44
# Evaluating individual #45
# Evaluating individual #46
# Evaluating individual #47
# Evaluating individual #48
# Evaluating individual #49

# %%
generation.print_population()
# Out:
# Individual #0: {'genome': [['D', 157], ['D', 442], ['D', 493], ['D', 274], ['D', 256], ['D', 428], ['D', 339], ['D', 197]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=157, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=157, out_features=442, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=442, out_features=493, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=493, out_features=274, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=274, out_features=256, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=256, out_features=428, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=428, out_features=339, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=339, out_features=197, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=197, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 0, 'loss': 0.07036999980608623, 'accuracy': 0.3333333333333333, 'parameters': 817777}
# Individual #1: {'genome': [['D', 385], ['D', 130], ['D', 457], ['D', 314]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=385, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=385, out_features=130, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=130, out_features=457, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=457, out_features=314, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=314, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# ), 'id': 1, 'loss': 0.059365206956863405, 'accuracy': 0.66, 'parameters': 256729}
# Individual #2: {'genome': [['D', 436], ['D', 383], ['D', 373], ['D', 249], ['D', 222], ['D', 510], ['D', 256], ['D', 377], ['D', 282], ['D', 139]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=436, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=436, out_features=383, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=383, out_features=373, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=373, out_features=249, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=249, out_features=222, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=222, out_features=510, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=510, out_features=256, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=256, out_features=377, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=377, out_features=282, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=282, out_features=139, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=139, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# ), 'id': 2, 'loss': 0.07322731812795004, 'accuracy': 0.3333333333333333, 'parameters': 949197}
# Individual #3: {'genome': [['D', 332], ['D', 370], ['D', 151], ['D', 296], ['D', 409], ['D', 248], ['D', 424], ['D', 169]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=332, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=332, out_features=370, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=370, out_features=151, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=151, out_features=296, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=296, out_features=409, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=409, out_features=248, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=248, out_features=424, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=424, out_features=169, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=169, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 3, 'loss': 0.058924857378005985, 'accuracy': 0.6666666666666666, 'parameters': 626947}
# Individual #4: {'genome': [['D', 222], ['D', 154], ['D', 219]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=222, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=222, out_features=154, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=154, out_features=219, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=219, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# ), 'id': 4, 'loss': 0.052265083392461144, 'accuracy': 0.72, 'parameters': 70057}
# Individual #5: {'genome': [['D', 337], ['D', 312]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=337, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=337, out_features=312, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=312, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 5, 'loss': 0.0441252076625824, 'accuracy': 0.88, 'parameters': 108080}
# Individual #6: {'genome': [['D', 291], ['D', 181]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=291, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=291, out_features=181, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=181, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 6, 'loss': 0.052659374872843424, 'accuracy': 0.7, 'parameters': 54853}
# Individual #7: {'genome': [['D', 195], ['D', 428]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=195, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=195, out_features=428, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=428, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 7, 'loss': 0.048675723473231, 'accuracy': 0.84, 'parameters': 86150}
# Individual #8: {'genome': [['D', 202], ['D', 185]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=202, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=202, out_features=185, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=185, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 8, 'loss': 0.04688845634460449, 'accuracy': 0.92, 'parameters': 39123}
# Individual #9: {'genome': [['D', 262], ['D', 224]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=262, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=262, out_features=224, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=224, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 9, 'loss': 0.05025702595710754, 'accuracy': 0.7466666666666667, 'parameters': 60897}
# Individual #10: {'genome': [['D', 472], ['D', 352], ['D', 404], ['D', 211], ['D', 332], ['D', 475], ['D', 281], ['D', 362], ['D', 413], ['D', 390]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=472, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=472, out_features=352, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=352, out_features=404, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=404, out_features=211, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=211, out_features=332, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=332, out_features=475, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=475, out_features=281, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=281, out_features=362, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=362, out_features=413, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=413, out_features=390, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=390, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# ), 'id': 10, 'loss': 0.07312634984652201, 'accuracy': 0.3333333333333333, 'parameters': 1173874}
# Individual #11: {'genome': [['D', 455], ['D', 210], ['D', 431], ['D', 483], ['D', 376], ['D', 473]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=455, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=455, out_features=210, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=210, out_features=431, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=431, out_features=483, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=483, out_features=376, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=376, out_features=473, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=473, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# ), 'id': 11, 'loss': 0.05898520509401957, 'accuracy': 0.6666666666666666, 'parameters': 759359}
# Individual #12: {'genome': [['D', 465], ['D', 188], ['D', 286], ['D', 247], ['D', 155], ['D', 134], ['D', 509], ['D', 433]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=465, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=465, out_features=188, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=188, out_features=286, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=286, out_features=247, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=247, out_features=155, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=155, out_features=134, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=134, out_features=509, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=509, out_features=433, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=433, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 12, 'loss': 0.07086482683817545, 'accuracy': 0.3333333333333333, 'parameters': 565067}
# Individual #13: {'genome': [['D', 230], ['D', 325]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=230, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=230, out_features=325, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=325, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 13, 'loss': 0.059339613517125446, 'accuracy': 0.6666666666666666, 'parameters': 77203}
# Individual #14: {'genome': [['D', 395], ['D', 198]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=395, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=395, out_features=198, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=198, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 14, 'loss': 0.05496184746424357, 'accuracy': 0.6666666666666666, 'parameters': 80980}
# Individual #15: {'genome': [['D', 391], ['D', 149], ['D', 229], ['D', 256], ['D', 137], ['D', 362], ['D', 469]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=391, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=391, out_features=149, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=149, out_features=229, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=229, out_features=256, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=256, out_features=137, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=137, out_features=362, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=362, out_features=469, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=469, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# ), 'id': 15, 'loss': 0.0722338620821635, 'accuracy': 0.3333333333333333, 'parameters': 410415}
# Individual #16: {'genome': [['D', 208], ['D', 186], ['D', 160], ['D', 455], ['D', 174], ['D', 194], ['D', 288], ['D', 160], ['D', 499]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=208, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=208, out_features=186, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=186, out_features=160, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=160, out_features=455, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=455, out_features=174, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=174, out_features=194, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=194, out_features=288, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=288, out_features=160, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=160, out_features=499, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=499, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 16, 'loss': 0.0732407808303833, 'accuracy': 0.3333333333333333, 'parameters': 440622}
# Individual #17: {'genome': [['D', 200], ['D', 277], ['D', 428], ['D', 482], ['D', 182], ['D', 446], ['D', 395]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=200, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=200, out_features=277, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=277, out_features=428, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=428, out_features=482, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=482, out_features=182, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=182, out_features=446, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=446, out_features=395, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=395, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# ), 'id': 17, 'loss': 0.06957866430282593, 'accuracy': 0.6, 'parameters': 729716}
# Individual #18: {'genome': [['D', 416], ['D', 467], ['D', 447]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=416, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=416, out_features=467, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=467, out_features=447, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=447, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# ), 'id': 18, 'loss': 0.058290756940841675, 'accuracy': 0.6666666666666666, 'parameters': 407359}
# Individual #19: {'genome': [['D', 455], ['D', 324], ['D', 164], ['D', 474], ['D', 468], ['D', 341], ['D', 344], ['D', 213], ['D', 210], ['D', 264]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=455, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=455, out_features=324, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=324, out_features=164, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=164, out_features=474, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=474, out_features=468, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=468, out_features=341, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=341, out_features=344, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=344, out_features=213, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=213, out_features=210, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=210, out_features=264, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=264, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# ), 'id': 19, 'loss': 0.06900384585062663, 'accuracy': 0.3333333333333333, 'parameters': 956330}
# Individual #20: {'genome': [['D', 512], ['D', 363]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=363, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=363, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 20, 'loss': 0.045755484104156495, 'accuracy': 0.9733333333333334, 'parameters': 189871}
# Individual #21: {'genome': [['D', 405], ['D', 376], ['D', 438], ['D', 175]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=405, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=405, out_features=376, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=376, out_features=438, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=438, out_features=175, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=175, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# ), 'id': 21, 'loss': 0.0590111776192983, 'accuracy': 0.6666666666666666, 'parameters': 397160}
# Individual #22: {'genome': [['D', 222], ['D', 320], ['D', 195], ['D', 174], ['D', 452]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=222, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=222, out_features=320, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=320, out_features=195, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=195, out_features=174, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=174, out_features=452, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=452, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# ), 'id': 22, 'loss': 0.07427698890368144, 'accuracy': 0.38666666666666666, 'parameters': 249628}
# Individual #23: {'genome': [['D', 412], ['D', 393], ['D', 446], ['D', 376], ['D', 350], ['D', 459], ['D', 330]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=412, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=412, out_features=393, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=393, out_features=446, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=446, out_features=376, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=376, out_features=350, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=350, out_features=459, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=459, out_features=330, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=330, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# ), 'id': 23, 'loss': 0.07085859775543213, 'accuracy': 0.3333333333333333, 'parameters': 954017}
# Individual #24: {'genome': [['D', 271], ['D', 469], ['D', 249], ['D', 461], ['D', 330], ['D', 141], ['D', 149], ['D', 131]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=271, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=271, out_features=469, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=469, out_features=249, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=249, out_features=461, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=461, out_features=330, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=330, out_features=141, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=141, out_features=149, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=149, out_features=131, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=131, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 24, 'loss': 0.0653909953435262, 'accuracy': 0.6666666666666666, 'parameters': 601538}
# Individual #25: {'genome': [['D', 150], ['D', 511]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=150, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=150, out_features=511, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=511, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 25, 'loss': 0.04869117776552836, 'accuracy': 0.8466666666666667, 'parameters': 79447}
# Individual #26: {'genome': [['D', 304], ['D', 422], ['D', 436]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=304, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=304, out_features=422, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=422, out_features=436, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=436, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# ), 'id': 26, 'loss': 0.04225660761197408, 'accuracy': 0.9533333333333334, 'parameters': 315969}
# Individual #27: {'genome': [['D', 213], ['D', 208]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=213, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=213, out_features=208, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=208, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 27, 'loss': 0.04863487482070923, 'accuracy': 0.88, 'parameters': 46204}
# Individual #28: {'genome': [['D', 248], ['D', 240]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=248, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=248, out_features=240, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=240, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 28, 'loss': 0.04823871771494548, 'accuracy': 0.86, 'parameters': 61723}
# Individual #29: {'genome': [['D', 330], ['D', 297], ['D', 144], ['D', 219], ['D', 490], ['D', 183], ['D', 227], ['D', 480], ['D', 175]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=330, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=330, out_features=297, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=297, out_features=144, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=144, out_features=219, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=219, out_features=490, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=490, out_features=183, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=183, out_features=227, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=227, out_features=480, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=480, out_features=175, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=175, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 29, 'loss': 0.057149254480997724, 'accuracy': 0.6666666666666666, 'parameters': 608188}
# Individual #30: {'genome': [['D', 408], ['D', 281], ['D', 228]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=408, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=408, out_features=281, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=281, out_features=228, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=228, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# ), 'id': 30, 'loss': 0.05889939586321513, 'accuracy': 0.6666666666666666, 'parameters': 181952}
# Individual #31: {'genome': [['D', 129], ['D', 424], ['D', 135], ['D', 210], ['D', 246], ['D', 201], ['D', 323], ['D', 306], ['D', 267]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=129, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=129, out_features=424, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=424, out_features=135, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=135, out_features=210, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=210, out_features=246, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=246, out_features=201, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=201, out_features=323, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=323, out_features=306, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=306, out_features=267, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=267, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 31, 'loss': 0.05879789153734843, 'accuracy': 0.5066666666666667, 'parameters': 490416}
# Individual #32: {'genome': [['D', 342], ['D', 402], ['D', 436]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=342, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=342, out_features=402, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=402, out_features=436, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=436, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# ), 'id': 32, 'loss': 0.05163488149642945, 'accuracy': 0.6866666666666666, 'parameters': 316615}
# Individual #33: {'genome': [['D', 501], ['D', 459], ['D', 440], ['D', 427], ['D', 368], ['D', 382], ['D', 496], ['D', 134], ['D', 403]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=501, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=501, out_features=459, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=459, out_features=440, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=440, out_features=427, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=427, out_features=368, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=368, out_features=382, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=382, out_features=496, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=496, out_features=134, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=134, out_features=403, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=403, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 33, 'loss': 0.06863799571990967, 'accuracy': 0.3333333333333333, 'parameters': 1234275}
# Individual #34: {'genome': [['D', 504], ['D', 217], ['D', 371], ['D', 442], ['D', 134], ['D', 193]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=504, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=504, out_features=217, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=217, out_features=371, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=371, out_features=442, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=442, out_features=134, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=134, out_features=193, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=193, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# ), 'id': 34, 'loss': 0.060279643932978313, 'accuracy': 0.66, 'parameters': 443406}
# Individual #35: {'genome': [['D', 489], ['D', 202], ['D', 344], ['D', 493], ['D', 387], ['D', 203]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=489, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=489, out_features=202, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=202, out_features=344, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=344, out_features=493, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=493, out_features=387, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=387, out_features=203, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=203, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# ), 'id': 35, 'loss': 0.05872600436210632, 'accuracy': 0.6666666666666666, 'parameters': 611896}
# Individual #36: {'genome': [['D', 304], ['D', 395]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=304, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=304, out_features=395, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=395, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 36, 'loss': 0.05165534655253092, 'accuracy': 0.7466666666666667, 'parameters': 123183}
# Individual #37: {'genome': [['D', 263], ['D', 312], ['D', 270]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=263, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=263, out_features=312, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=312, out_features=270, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=270, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# ), 'id': 37, 'loss': 0.05172400712966919, 'accuracy': 0.6933333333333334, 'parameters': 169006}
# Individual #38: {'genome': [['D', 441], ['D', 352], ['D', 174], ['D', 208], ['D', 389], ['D', 454]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=441, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=441, out_features=352, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=352, out_features=174, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=174, out_features=208, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=208, out_features=389, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=389, out_features=454, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=454, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# ), 'id': 38, 'loss': 0.052154897451400756, 'accuracy': 0.6866666666666666, 'parameters': 515337}
# Individual #39: {'genome': [['D', 321], ['D', 129], ['D', 355], ['D', 130], ['D', 490], ['D', 169], ['D', 365], ['D', 323], ['D', 153]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=321, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=321, out_features=129, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=129, out_features=355, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=355, out_features=130, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=130, out_features=490, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=490, out_features=169, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=169, out_features=365, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=365, out_features=323, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=323, out_features=153, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=153, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 39, 'loss': 0.06707374493281047, 'accuracy': 0.3333333333333333, 'parameters': 513044}
# Individual #40: {'genome': [['D', 386], ['D', 320], ['D', 497], ['D', 438], ['D', 309]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=386, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=386, out_features=320, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=320, out_features=497, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=497, out_features=438, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=438, out_features=309, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=309, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# ), 'id': 40, 'loss': 0.055801039934158324, 'accuracy': 0.6666666666666666, 'parameters': 640012}
# Individual #41: {'genome': [['D', 169], ['D', 418], ['D', 506], ['D', 471], ['D', 389], ['D', 192]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=169, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=169, out_features=418, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=418, out_features=506, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=506, out_features=471, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=471, out_features=389, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=389, out_features=192, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=192, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# ), 'id': 41, 'loss': 0.056419130166371664, 'accuracy': 0.6666666666666666, 'parameters': 781783}
# Individual #42: {'genome': [['D', 360], ['D', 413], ['D', 149], ['D', 248], ['D', 439]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=360, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=360, out_features=413, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=413, out_features=149, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=149, out_features=248, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=248, out_features=439, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=439, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# ), 'id': 42, 'loss': 0.0552300234635671, 'accuracy': 0.6666666666666666, 'parameters': 360410}
# Individual #43: {'genome': [['D', 416], ['D', 360], ['D', 239]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=416, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=416, out_features=360, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=360, out_features=239, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=239, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# ), 'id': 43, 'loss': 0.05829076488812764, 'accuracy': 0.6666666666666666, 'parameters': 239199}
# Individual #44: {'genome': [['D', 266], ['D', 136], ['D', 146], ['D', 204], ['D', 333]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=266, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=266, out_features=136, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=136, out_features=146, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=146, out_features=204, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=204, out_features=333, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=333, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# ), 'id': 44, 'loss': 0.058278104861577355, 'accuracy': 0.6666666666666666, 'parameters': 156899}
# Individual #45: {'genome': [['D', 370], ['D', 403], ['D', 438], ['D', 339], ['D', 386], ['D', 298]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=370, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=370, out_features=403, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=403, out_features=438, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=438, out_features=339, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=339, out_features=386, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=386, out_features=298, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=298, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# ), 'id': 45, 'loss': 0.06371386369069418, 'accuracy': 0.6666666666666666, 'parameters': 724599}
# Individual #46: {'genome': [['D', 423], ['D', 154], ['D', 418], ['D', 501], ['D', 493], ['D', 157], ['D', 200], ['D', 498], ['D', 329], ['D', 131]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=423, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=423, out_features=154, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=154, out_features=418, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=418, out_features=501, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=501, out_features=493, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=493, out_features=157, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=157, out_features=200, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=200, out_features=498, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=498, out_features=329, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=329, out_features=131, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=131, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# ), 'id': 46, 'loss': 0.08120743632316589, 'accuracy': 0.3333333333333333, 'parameters': 1006659}
# Individual #47: {'genome': [['D', 337], ['D', 394]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=337, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=337, out_features=394, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=394, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 47, 'loss': 0.059001686175664265, 'accuracy': 0.6666666666666666, 'parameters': 136042}
# Individual #48: {'genome': [['D', 468], ['D', 180], ['D', 411], ['D', 143], ['D', 260], ['D', 371]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=468, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=468, out_features=180, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=180, out_features=411, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=411, out_features=143, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=143, out_features=260, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=260, out_features=371, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=371, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# ), 'id': 48, 'loss': 0.06820751984914143, 'accuracy': 0.6666666666666666, 'parameters': 355454}
# Individual #49: {'genome': [['D', 376], ['D', 345], ['D', 507], ['D', 501], ['D', 347], ['D', 224], ['D', 207], ['D', 335], ['D', 321]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=376, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=376, out_features=345, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=345, out_features=507, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=507, out_features=501, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=501, out_features=347, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=347, out_features=224, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=224, out_features=207, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=207, out_features=335, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=335, out_features=321, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=321, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 49, 'loss': 0.07280393203099568, 'accuracy': 0.3333333333333333, 'parameters': 1039098}

# %%
generation.calculate_fitness()

# %% [markdown]
# # Now use the automated evolve

# %%
train_dataset = Iris_dataset(df.values[:,:4], df['species'])
test_dataset = Iris_dataset(df.values[:,:4], df['species'])
train_loader = torch.utils.data.DataLoader(train_dataset,shuffle=True,**train_kwargs)
test_loader = torch.utils.data.DataLoader(test_dataset,shuffle=True, **test_kwargs)

generation = GA(generation_length=10,population_size=50,initial_size=256,initial_depth=5, lossFn=nn.CrossEntropyLoss(), input_size=4, output_size=3, outputLayer=nn.Softmax(dim=1), device=device, train_dataloader=train_loader, test_dataloader=test_loader, optimizerFn="Adam", epoch=100  )
generation.auto_evolve()
# Out:
# Generation #0
# [['D', 345], ['D', 365], ['D', 430], ['D', 265], ['D', 479]]
# ['D', 365]
# ['D', 430]
# ['D', 265]
# ['D', 479]
# [['D', 386], ['D', 331], ['D', 136], ['D', 174], ['D', 274], ['D', 286], ['D', 449], ['D', 137]]
# ['D', 331]
# ['D', 136]
# ['D', 174]
# ['D', 274]
# ['D', 286]
# ['D', 449]
# ['D', 137]
# [['D', 159], ['D', 249], ['D', 160], ['D', 193], ['D', 489], ['D', 140], ['D', 223], ['D', 140]]
# ['D', 249]
# ['D', 160]
# ['D', 193]
# ['D', 489]
# ['D', 140]
# ['D', 223]
# ['D', 140]
# [['D', 420], ['D', 198], ['D', 338], ['D', 470], ['D', 428]]
# ['D', 198]
# ['D', 338]
# ['D', 470]
# ['D', 428]
# [['D', 189], ['D', 129], ['D', 423], ['D', 328], ['D', 382], ['D', 277]]
# ['D', 129]
# ['D', 423]
# ['D', 328]
# ['D', 382]
# ['D', 277]
# [['D', 396], ['D', 403]]
# ['D', 403]
# [['D', 378], ['D', 460]]
# ['D', 460]
# [['D', 312], ['D', 434]]
# ['D', 434]
# [['D', 221], ['D', 129], ['D', 310]]
# ['D', 129]
# ['D', 310]
# [['D', 441], ['D', 199]]
# ['D', 199]
# [['D', 487], ['D', 155], ['D', 134], ['D', 486], ['D', 388], ['D', 243], ['D', 209]]
# ['D', 155]
# ['D', 134]
# ['D', 486]
# ['D', 388]
# ['D', 243]
# ['D', 209]
# [['D', 130], ['D', 466], ['D', 317]]
# ['D', 466]
# ['D', 317]
# [['D', 363], ['D', 305], ['D', 220], ['D', 228], ['D', 350], ['D', 165], ['D', 271], ['D', 299]]
# ['D', 305]
# ['D', 220]
# ['D', 228]
# ['D', 350]
# ['D', 165]
# ['D', 271]
# ['D', 299]
# [['D', 471], ['D', 448]]
# ['D', 448]
# [['D', 234], ['D', 183], ['D', 336], ['D', 376], ['D', 166], ['D', 504], ['D', 290], ['D', 370], ['D', 224], ['D', 504]]
# ['D', 183]
# ['D', 336]
# ['D', 376]
# ['D', 166]
# ['D', 504]
# ['D', 290]
# ['D', 370]
# ['D', 224]
# ['D', 504]
# [['D', 371], ['D', 436], ['D', 438], ['D', 393], ['D', 155], ['D', 130], ['D', 379]]
# ['D', 436]
# ['D', 438]
# ['D', 393]
# ['D', 155]
# ['D', 130]
# ['D', 379]
# [['D', 290], ['D', 377], ['D', 449], ['D', 276], ['D', 297]]
# ['D', 377]
# ['D', 449]
# ['D', 276]
# ['D', 297]
# [['D', 389], ['D', 167], ['D', 464], ['D', 249], ['D', 255], ['D', 236], ['D', 398], ['D', 352], ['D', 157], ['D', 284]]
# ['D', 167]
# ['D', 464]
# ['D', 249]
# ['D', 255]
# ['D', 236]
# ['D', 398]
# ['D', 352]
# ['D', 157]
# ['D', 284]
# [['D', 132], ['D', 265], ['D', 509], ['D', 173]]
# ['D', 265]
# ['D', 509]
# ['D', 173]
# [['D', 208], ['D', 214], ['D', 388], ['D', 385], ['D', 250], ['D', 496], ['D', 441], ['D', 170], ['D', 190]]
# ['D', 214]
# ['D', 388]
# ['D', 385]
# ['D', 250]
# ['D', 496]
# ['D', 441]
# ['D', 170]
# ['D', 190]
# [['D', 431], ['D', 342], ['D', 165], ['D', 257]]
# ['D', 342]
# ['D', 165]
# ['D', 257]
# [['D', 448], ['D', 422], ['D', 392], ['D', 374], ['D', 463], ['D', 317], ['D', 171], ['D', 234], ['D', 426]]
# ['D', 422]
# ['D', 392]
# ['D', 374]
# ['D', 463]
# ['D', 317]
# ['D', 171]
# ['D', 234]
# ['D', 426]
# [['D', 437], ['D', 375], ['D', 164], ['D', 400], ['D', 445], ['D', 173]]
# ['D', 375]
# ['D', 164]
# ['D', 400]
# ['D', 445]
# ['D', 173]
# [['D', 299], ['D', 176], ['D', 428], ['D', 511], ['D', 484], ['D', 486], ['D', 510]]
# ['D', 176]
# ['D', 428]
# ['D', 511]
# ['D', 484]
# ['D', 486]
# ['D', 510]
# [['D', 200], ['D', 320], ['D', 351], ['D', 380], ['D', 147], ['D', 335], ['D', 234]]
# ['D', 320]
# ['D', 351]
# ['D', 380]
# ['D', 147]
# ['D', 335]
# ['D', 234]
# [['D', 504], ['D', 251], ['D', 386], ['D', 152], ['D', 435], ['D', 315], ['D', 343]]
# ['D', 251]
# ['D', 386]
# ['D', 152]
# ['D', 435]
# ['D', 315]
# ['D', 343]
# [['D', 317], ['D', 146], ['D', 390], ['D', 343], ['D', 328], ['D', 191], ['D', 327], ['D', 189], ['D', 492], ['D', 370]]
# ['D', 146]
# ['D', 390]
# ['D', 343]
# ['D', 328]
# ['D', 191]
# ['D', 327]
# ['D', 189]
# ['D', 492]
# ['D', 370]
# [['D', 254], ['D', 156], ['D', 197], ['D', 213], ['D', 241], ['D', 479], ['D', 275], ['D', 204], ['D', 422], ['D', 234]]
# ['D', 156]
# ['D', 197]
# ['D', 213]
# ['D', 241]
# ['D', 479]
# ['D', 275]
# ['D', 204]
# ['D', 422]
# ['D', 234]
# [['D', 441], ['D', 352], ['D', 271], ['D', 452], ['D', 390]]
# ['D', 352]
# ['D', 271]
# ['D', 452]
# ['D', 390]
# [['D', 467], ['D', 195], ['D', 476], ['D', 305], ['D', 485]]
# ['D', 195]
# ['D', 476]
# ['D', 305]
# ['D', 485]
# [['D', 246], ['D', 276], ['D', 285], ['D', 133], ['D', 435], ['D', 267], ['D', 434], ['D', 272], ['D', 176]]
# ['D', 276]
# ['D', 285]
# ['D', 133]
# ['D', 435]
# ['D', 267]
# ['D', 434]
# ['D', 272]
# ['D', 176]
# [['D', 149], ['D', 187], ['D', 342], ['D', 425], ['D', 247]]
# ['D', 187]
# ['D', 342]
# ['D', 425]
# ['D', 247]
# [['D', 281], ['D', 244], ['D', 431], ['D', 371], ['D', 142], ['D', 183], ['D', 347], ['D', 421], ['D', 353]]
# ['D', 244]
# ['D', 431]
# ['D', 371]
# ['D', 142]
# ['D', 183]
# ['D', 347]
# ['D', 421]
# ['D', 353]
# [['D', 415], ['D', 190], ['D', 374], ['D', 359], ['D', 202], ['D', 409], ['D', 510], ['D', 233], ['D', 175]]
# ['D', 190]
# ['D', 374]
# ['D', 359]
# ['D', 202]
# ['D', 409]
# ['D', 510]
# ['D', 233]
# ['D', 175]
# [['D', 282], ['D', 466]]
# ['D', 466]
# [['D', 457], ['D', 255]]
# ['D', 255]
# [['D', 179], ['D', 288]]
# ['D', 288]
# [['D', 433], ['D', 423], ['D', 266], ['D', 218], ['D', 245], ['D', 393], ['D', 499], ['D', 294], ['D', 289]]
# ['D', 423]
# ['D', 266]
# ['D', 218]
# ['D', 245]
# ['D', 393]
# ['D', 499]
# ['D', 294]
# ['D', 289]
# [['D', 275], ['D', 448], ['D', 291], ['D', 146], ['D', 289], ['D', 191], ['D', 426], ['D', 288]]
# ['D', 448]
# ['D', 291]
# ['D', 146]
# ['D', 289]
# ['D', 191]
# ['D', 426]
# ['D', 288]
# [['D', 260], ['D', 230], ['D', 219], ['D', 441], ['D', 434], ['D', 136], ['D', 460], ['D', 310], ['D', 186], ['D', 300]]
# ['D', 230]
# ['D', 219]
# ['D', 441]
# ['D', 434]
# ['D', 136]
# ['D', 460]
# ['D', 310]
# ['D', 186]
# ['D', 300]
# [['D', 491], ['D', 355], ['D', 320], ['D', 467], ['D', 130], ['D', 284]]
# ['D', 355]
# ['D', 320]
# ['D', 467]
# ['D', 130]
# ['D', 284]
# [['D', 338], ['D', 168], ['D', 205]]
# ['D', 168]
# ['D', 205]
# [['D', 135], ['D', 155]]
# ['D', 155]
# [['D', 341], ['D', 457], ['D', 287], ['D', 389], ['D', 387], ['D', 441], ['D', 267], ['D', 435], ['D', 147], ['D', 219]]
# ['D', 457]
# ['D', 287]
# ['D', 389]
# ['D', 387]
# ['D', 441]
# ['D', 267]
# ['D', 435]
# ['D', 147]
# ['D', 219]
# [['D', 243], ['D', 390], ['D', 299], ['D', 196], ['D', 150], ['D', 473], ['D', 198]]
# ['D', 390]
# ['D', 299]
# ['D', 196]
# ['D', 150]
# ['D', 473]
# ['D', 198]
# [['D', 171], ['D', 491], ['D', 229], ['D', 214], ['D', 345], ['D', 288], ['D', 142], ['D', 380], ['D', 191]]
# ['D', 491]
# ['D', 229]
# ['D', 214]
# ['D', 345]
# ['D', 288]
# ['D', 142]
# ['D', 380]
# ['D', 191]
# [['D', 460], ['D', 496], ['D', 507], ['D', 150], ['D', 161], ['D', 385], ['D', 171], ['D', 311], ['D', 432]]
# ['D', 496]
# ['D', 507]
# ['D', 150]
# ['D', 161]
# ['D', 385]
# ['D', 171]
# ['D', 311]
# ['D', 432]
# [['D', 132], ['D', 261]]
# ['D', 261]
# [['D', 293], ['D', 204], ['D', 472]]
# ['D', 204]
# ['D', 472]
# [['D', 160], ['D', 136], ['D', 438], ['D', 170], ['D', 319], ['D', 264], ['D', 220]]
# ['D', 136]
# ['D', 438]
# ['D', 170]
# ['D', 319]
# ['D', 264]
# ['D', 220]
# [{'genome': [['D', 345], ['D', 365], ['D', 430], ['D', 265], ['D', 479]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=345, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=345, out_features=365, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=365, out_features=430, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=430, out_features=265, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=265, out_features=479, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=479, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 386], ['D', 331], ['D', 136], ['D', 174], ['D', 274], ['D', 286], ['D', 449], ['D', 137]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=386, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=386, out_features=331, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=331, out_features=136, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=136, out_features=174, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=174, out_features=274, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=274, out_features=286, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=286, out_features=449, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=449, out_features=137, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=137, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 159], ['D', 249], ['D', 160], ['D', 193], ['D', 489], ['D', 140], ['D', 223], ['D', 140]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=159, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=159, out_features=249, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=249, out_features=160, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=160, out_features=193, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=193, out_features=489, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=489, out_features=140, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=140, out_features=223, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=223, out_features=140, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=140, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 420], ['D', 198], ['D', 338], ['D', 470], ['D', 428]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=420, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=420, out_features=198, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=198, out_features=338, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=338, out_features=470, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=470, out_features=428, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=428, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 189], ['D', 129], ['D', 423], ['D', 328], ['D', 382], ['D', 277]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=189, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=189, out_features=129, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=129, out_features=423, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=423, out_features=328, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=328, out_features=382, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=382, out_features=277, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=277, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 396], ['D', 403]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=396, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=396, out_features=403, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=403, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 378], ['D', 460]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=378, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=378, out_features=460, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=460, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 312], ['D', 434]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=312, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=312, out_features=434, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=434, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 221], ['D', 129], ['D', 310]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=221, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=221, out_features=129, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=129, out_features=310, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=310, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 441], ['D', 199]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=441, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=441, out_features=199, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=199, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 487], ['D', 155], ['D', 134], ['D', 486], ['D', 388], ['D', 243], ['D', 209]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=487, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=487, out_features=155, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=155, out_features=134, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=134, out_features=486, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=486, out_features=388, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=388, out_features=243, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=243, out_features=209, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=209, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 130], ['D', 466], ['D', 317]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=130, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=130, out_features=466, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=466, out_features=317, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=317, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 363], ['D', 305], ['D', 220], ['D', 228], ['D', 350], ['D', 165], ['D', 271], ['D', 299]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=363, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=363, out_features=305, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=305, out_features=220, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=220, out_features=228, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=228, out_features=350, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=350, out_features=165, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=165, out_features=271, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=271, out_features=299, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=299, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 471], ['D', 448]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=471, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=471, out_features=448, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=448, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 234], ['D', 183], ['D', 336], ['D', 376], ['D', 166], ['D', 504], ['D', 290], ['D', 370], ['D', 224], ['D', 504]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=234, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=234, out_features=183, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=183, out_features=336, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=336, out_features=376, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=376, out_features=166, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=166, out_features=504, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=504, out_features=290, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=290, out_features=370, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=370, out_features=224, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=224, out_features=504, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=504, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 371], ['D', 436], ['D', 438], ['D', 393], ['D', 155], ['D', 130], ['D', 379]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=371, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=371, out_features=436, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=436, out_features=438, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=438, out_features=393, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=393, out_features=155, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=155, out_features=130, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=130, out_features=379, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=379, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 290], ['D', 377], ['D', 449], ['D', 276], ['D', 297]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=290, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=290, out_features=377, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=377, out_features=449, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=449, out_features=276, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=276, out_features=297, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=297, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 389], ['D', 167], ['D', 464], ['D', 249], ['D', 255], ['D', 236], ['D', 398], ['D', 352], ['D', 157], ['D', 284]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=389, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=389, out_features=167, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=167, out_features=464, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=464, out_features=249, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=249, out_features=255, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=255, out_features=236, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=236, out_features=398, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=398, out_features=352, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=352, out_features=157, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=157, out_features=284, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=284, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 132], ['D', 265], ['D', 509], ['D', 173]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=132, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=132, out_features=265, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=265, out_features=509, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=509, out_features=173, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=173, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 208], ['D', 214], ['D', 388], ['D', 385], ['D', 250], ['D', 496], ['D', 441], ['D', 170], ['D', 190]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=208, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=208, out_features=214, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=214, out_features=388, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=388, out_features=385, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=385, out_features=250, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=250, out_features=496, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=496, out_features=441, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=441, out_features=170, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=170, out_features=190, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=190, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 431], ['D', 342], ['D', 165], ['D', 257]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=431, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=431, out_features=342, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=342, out_features=165, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=165, out_features=257, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=257, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 448], ['D', 422], ['D', 392], ['D', 374], ['D', 463], ['D', 317], ['D', 171], ['D', 234], ['D', 426]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=448, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=448, out_features=422, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=422, out_features=392, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=392, out_features=374, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=374, out_features=463, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=463, out_features=317, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=317, out_features=171, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=171, out_features=234, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=234, out_features=426, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=426, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 437], ['D', 375], ['D', 164], ['D', 400], ['D', 445], ['D', 173]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=437, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=437, out_features=375, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=375, out_features=164, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=164, out_features=400, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=400, out_features=445, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=445, out_features=173, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=173, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 299], ['D', 176], ['D', 428], ['D', 511], ['D', 484], ['D', 486], ['D', 510]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=299, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=299, out_features=176, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=176, out_features=428, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=428, out_features=511, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=511, out_features=484, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=484, out_features=486, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=486, out_features=510, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=510, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 200], ['D', 320], ['D', 351], ['D', 380], ['D', 147], ['D', 335], ['D', 234]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=200, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=200, out_features=320, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=320, out_features=351, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=351, out_features=380, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=380, out_features=147, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=147, out_features=335, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=335, out_features=234, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=234, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 504], ['D', 251], ['D', 386], ['D', 152], ['D', 435], ['D', 315], ['D', 343]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=504, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=504, out_features=251, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=251, out_features=386, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=386, out_features=152, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=152, out_features=435, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=435, out_features=315, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=315, out_features=343, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=343, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 317], ['D', 146], ['D', 390], ['D', 343], ['D', 328], ['D', 191], ['D', 327], ['D', 189], ['D', 492], ['D', 370]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=317, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=317, out_features=146, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=146, out_features=390, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=390, out_features=343, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=343, out_features=328, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=328, out_features=191, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=191, out_features=327, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=327, out_features=189, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=189, out_features=492, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=492, out_features=370, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=370, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 254], ['D', 156], ['D', 197], ['D', 213], ['D', 241], ['D', 479], ['D', 275], ['D', 204], ['D', 422], ['D', 234]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=254, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=254, out_features=156, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=156, out_features=197, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=197, out_features=213, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=213, out_features=241, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=241, out_features=479, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=479, out_features=275, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=275, out_features=204, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=204, out_features=422, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=422, out_features=234, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=234, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 441], ['D', 352], ['D', 271], ['D', 452], ['D', 390]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=441, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=441, out_features=352, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=352, out_features=271, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=271, out_features=452, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=452, out_features=390, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=390, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 467], ['D', 195], ['D', 476], ['D', 305], ['D', 485]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=467, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=467, out_features=195, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=195, out_features=476, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=476, out_features=305, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=305, out_features=485, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=485, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 246], ['D', 276], ['D', 285], ['D', 133], ['D', 435], ['D', 267], ['D', 434], ['D', 272], ['D', 176]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=246, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=246, out_features=276, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=276, out_features=285, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=285, out_features=133, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=133, out_features=435, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=435, out_features=267, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=267, out_features=434, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=434, out_features=272, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=272, out_features=176, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=176, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 149], ['D', 187], ['D', 342], ['D', 425], ['D', 247]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=149, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=149, out_features=187, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=187, out_features=342, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=342, out_features=425, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=425, out_features=247, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=247, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 281], ['D', 244], ['D', 431], ['D', 371], ['D', 142], ['D', 183], ['D', 347], ['D', 421], ['D', 353]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=281, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=281, out_features=244, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=244, out_features=431, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=431, out_features=371, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=371, out_features=142, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=142, out_features=183, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=183, out_features=347, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=347, out_features=421, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=421, out_features=353, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=353, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 415], ['D', 190], ['D', 374], ['D', 359], ['D', 202], ['D', 409], ['D', 510], ['D', 233], ['D', 175]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=415, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=415, out_features=190, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=190, out_features=374, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=374, out_features=359, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=359, out_features=202, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=202, out_features=409, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=409, out_features=510, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=510, out_features=233, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=233, out_features=175, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=175, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 282], ['D', 466]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=282, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=282, out_features=466, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=466, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 457], ['D', 255]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=457, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=457, out_features=255, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=255, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 179], ['D', 288]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=179, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=179, out_features=288, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=288, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 433], ['D', 423], ['D', 266], ['D', 218], ['D', 245], ['D', 393], ['D', 499], ['D', 294], ['D', 289]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=433, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=433, out_features=423, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=423, out_features=266, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=266, out_features=218, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=218, out_features=245, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=245, out_features=393, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=393, out_features=499, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=499, out_features=294, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=294, out_features=289, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=289, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 275], ['D', 448], ['D', 291], ['D', 146], ['D', 289], ['D', 191], ['D', 426], ['D', 288]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=275, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=275, out_features=448, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=448, out_features=291, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=291, out_features=146, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=146, out_features=289, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=289, out_features=191, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=191, out_features=426, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=426, out_features=288, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=288, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 260], ['D', 230], ['D', 219], ['D', 441], ['D', 434], ['D', 136], ['D', 460], ['D', 310], ['D', 186], ['D', 300]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=260, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=260, out_features=230, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=230, out_features=219, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=219, out_features=441, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=441, out_features=434, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=434, out_features=136, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=136, out_features=460, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=460, out_features=310, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=310, out_features=186, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=186, out_features=300, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=300, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 491], ['D', 355], ['D', 320], ['D', 467], ['D', 130], ['D', 284]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=491, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=491, out_features=355, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=355, out_features=320, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=320, out_features=467, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=467, out_features=130, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=130, out_features=284, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=284, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 338], ['D', 168], ['D', 205]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=338, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=338, out_features=168, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=168, out_features=205, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=205, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 135], ['D', 155]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=135, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=135, out_features=155, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=155, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 341], ['D', 457], ['D', 287], ['D', 389], ['D', 387], ['D', 441], ['D', 267], ['D', 435], ['D', 147], ['D', 219]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=341, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=341, out_features=457, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=457, out_features=287, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=287, out_features=389, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=389, out_features=387, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=387, out_features=441, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=441, out_features=267, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=267, out_features=435, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=435, out_features=147, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=147, out_features=219, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=219, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 243], ['D', 390], ['D', 299], ['D', 196], ['D', 150], ['D', 473], ['D', 198]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=243, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=243, out_features=390, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=390, out_features=299, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=299, out_features=196, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=196, out_features=150, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=150, out_features=473, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=473, out_features=198, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=198, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 171], ['D', 491], ['D', 229], ['D', 214], ['D', 345], ['D', 288], ['D', 142], ['D', 380], ['D', 191]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=171, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=171, out_features=491, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=491, out_features=229, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=229, out_features=214, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=214, out_features=345, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=345, out_features=288, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=288, out_features=142, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=142, out_features=380, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=380, out_features=191, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=191, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 460], ['D', 496], ['D', 507], ['D', 150], ['D', 161], ['D', 385], ['D', 171], ['D', 311], ['D', 432]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=460, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=460, out_features=496, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=496, out_features=507, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=507, out_features=150, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=150, out_features=161, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=161, out_features=385, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=385, out_features=171, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=171, out_features=311, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=311, out_features=432, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=432, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 132], ['D', 261]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=132, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=132, out_features=261, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=261, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 293], ['D', 204], ['D', 472]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=293, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=293, out_features=204, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=204, out_features=472, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=472, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 160], ['D', 136], ['D', 438], ['D', 170], ['D', 319], ['D', 264], ['D', 220]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=160, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=160, out_features=136, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=136, out_features=438, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=438, out_features=170, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=170, out_features=319, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=319, out_features=264, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=264, out_features=220, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=220, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}]
# Training individual #0
# Training individual #1
# Training individual #2
# Training individual #3
# Training individual #4
# Training individual #5
# Training individual #6
# Training individual #7
# Training individual #8
# Training individual #9
# Training individual #10
# Training individual #11
# Training individual #12
# Training individual #13
# Training individual #14
# Training individual #15
# Training individual #16
# Training individual #17
# Training individual #18
# Training individual #19
# Training individual #20
# Training individual #21
# Training individual #22
# Training individual #23
# Training individual #24
# Training individual #25
# Training individual #26
# Training individual #27
# Training individual #28
# Training individual #29
# Training individual #30
# Training individual #31
# Training individual #32
# Training individual #33
# Training individual #34
# Training individual #35
# Training individual #36
# Training individual #37
# Training individual #38
# Training individual #39
# Training individual #40
# Training individual #41
# Training individual #42
# Training individual #43
# Training individual #44
# Training individual #45
# Training individual #46
# Training individual #47
# Training individual #48
# Training individual #49
# Evaluating individual #0
# Evaluating individual #1
# Evaluating individual #2
# Evaluating individual #3
# Evaluating individual #4
# Evaluating individual #5
# Evaluating individual #6
# Evaluating individual #7
# Evaluating individual #8
# Evaluating individual #9
# Evaluating individual #10
# Evaluating individual #11
# Evaluating individual #12
# Evaluating individual #13
# Evaluating individual #14
# Evaluating individual #15
# Evaluating individual #16
# Evaluating individual #17
# Evaluating individual #18
# Evaluating individual #19
# Evaluating individual #20
# Evaluating individual #21
# Evaluating individual #22
# Evaluating individual #23
# Evaluating individual #24
# Evaluating individual #25
# Evaluating individual #26
# Evaluating individual #27
# Evaluating individual #28
# Evaluating individual #29
# Evaluating individual #30
# Evaluating individual #31
# Evaluating individual #32
# Evaluating individual #33
# Evaluating individual #34
# Evaluating individual #35
# Evaluating individual #36
# Evaluating individual #37
# Evaluating individual #38
# Evaluating individual #39
# Evaluating individual #40
# Evaluating individual #41
# Evaluating individual #42
# Evaluating individual #43
# Evaluating individual #44
# Evaluating individual #45
# Evaluating individual #46
# Evaluating individual #47
# Evaluating individual #48
# Evaluating individual #49
# Generation #1
# [['D', 467], ['D', 195], ['D', 476], ['D', 305], ['D', 485]]
# ['D', 195]
# ['D', 476]
# ['D', 305]
# ['D', 485]
# [['D', 171], ['D', 491], ['D', 229], ['D', 214], ['D', 345], ['D', 288], ['D', 142], ['D', 380], ['D', 191]]
# ['D', 491]
# ['D', 229]
# ['D', 214]
# ['D', 345]
# ['D', 288]
# ['D', 142]
# ['D', 380]
# ['D', 191]
# [['D', 363], ['D', 305], ['D', 220], ['D', 228], ['D', 350], ['D', 165], ['D', 271], ['D', 299]]
# ['D', 305]
# ['D', 220]
# ['D', 228]
# ['D', 350]
# ['D', 165]
# ['D', 271]
# ['D', 299]
# [['D', 460], ['D', 496], ['D', 507], ['D', 150], ['D', 161], ['D', 385], ['D', 171], ['D', 311], ['D', 432]]
# ['D', 496]
# ['D', 507]
# ['D', 150]
# ['D', 161]
# ['D', 385]
# ['D', 171]
# ['D', 311]
# ['D', 432]
# [['D', 491], ['D', 355], ['D', 320], ['D', 467], ['D', 130], ['D', 284]]
# ['D', 355]
# ['D', 320]
# ['D', 467]
# ['D', 130]
# ['D', 284]
# [['D', 299], ['D', 176], ['D', 428], ['D', 511], ['D', 484], ['D', 486], ['D', 510]]
# ['D', 176]
# ['D', 428]
# ['D', 511]
# ['D', 484]
# ['D', 486]
# ['D', 510]
# [['D', 290], ['D', 377], ['D', 449], ['D', 276], ['D', 297]]
# ['D', 377]
# ['D', 449]
# ['D', 276]
# ['D', 297]
# [['D', 208], ['D', 214], ['D', 388], ['D', 385], ['D', 250], ['D', 496], ['D', 441], ['D', 170], ['D', 190]]
# ['D', 214]
# ['D', 388]
# ['D', 385]
# ['D', 250]
# ['D', 496]
# ['D', 441]
# ['D', 170]
# ['D', 190]
# [['D', 130], ['D', 466], ['D', 317]]
# ['D', 466]
# ['D', 317]
# [['D', 345], ['D', 365], ['D', 430], ['D', 265], ['D', 479]]
# ['D', 365]
# ['D', 430]
# ['D', 265]
# ['D', 479]
# [['D', 200], ['D', 320], ['D', 351], ['D', 380], ['D', 147], ['D', 335], ['D', 234]]
# ['D', 320]
# ['D', 351]
# ['D', 380]
# ['D', 147]
# ['D', 335]
# ['D', 234]
# [['D', 189], ['D', 129], ['D', 423], ['D', 328], ['D', 382], ['D', 277]]
# ['D', 129]
# ['D', 423]
# ['D', 328]
# ['D', 382]
# ['D', 277]
# [['D', 433], ['D', 423], ['D', 266], ['D', 218], ['D', 245], ['D', 393], ['D', 499], ['D', 294], ['D', 289]]
# ['D', 423]
# ['D', 266]
# ['D', 218]
# ['D', 245]
# ['D', 393]
# ['D', 499]
# ['D', 294]
# ['D', 289]
# [['D', 420], ['D', 198], ['D', 338], ['D', 470], ['D', 428]]
# ['D', 198]
# ['D', 338]
# ['D', 470]
# ['D', 428]
# [['D', 132], ['D', 265], ['D', 509], ['D', 173]]
# ['D', 265]
# ['D', 509]
# ['D', 173]
# [['D', 281], ['D', 244], ['D', 431], ['D', 371], ['D', 142], ['D', 183], ['D', 347], ['D', 421], ['D', 353]]
# ['D', 244]
# ['D', 431]
# ['D', 371]
# ['D', 142]
# ['D', 183]
# ['D', 347]
# ['D', 421]
# ['D', 353]
# [['D', 437], ['D', 375], ['D', 164], ['D', 400], ['D', 445], ['D', 173]]
# ['D', 375]
# ['D', 164]
# ['D', 400]
# ['D', 445]
# ['D', 173]
# [['D', 293], ['D', 204], ['D', 472]]
# ['D', 204]
# ['D', 472]
# [['D', 441], ['D', 352], ['D', 271], ['D', 452], ['D', 390]]
# ['D', 352]
# ['D', 271]
# ['D', 452]
# ['D', 390]
# [['D', 159], ['D', 249], ['D', 160], ['D', 193], ['D', 489], ['D', 140], ['D', 223], ['D', 140]]
# ['D', 249]
# ['D', 160]
# ['D', 193]
# ['D', 489]
# ['D', 140]
# ['D', 223]
# ['D', 140]
# ...
#     (0): Linear(in_features=4, out_features=127, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=127, out_features=3, bias=True)
#     (3): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 3]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=3, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=3, out_features=3, bias=True)
#     (3): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 221], ['D', 4], ['D', 27], ['D', 519], ['D', 310]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=221, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=221, out_features=4, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=4, out_features=27, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=27, out_features=519, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=519, out_features=310, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=310, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 1]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=1, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=1, out_features=3, bias=True)
#     (3): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 206], ['D', 27], ['D', 519], ['D', 310]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=206, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=206, out_features=27, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=27, out_features=519, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=519, out_features=310, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=310, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 100]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=3, bias=True)
#     (3): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 1]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=1, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=1, out_features=3, bias=True)
#     (3): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 1]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=1, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=1, out_features=3, bias=True)
#     (3): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 135]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=135, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=135, out_features=3, bias=True)
#     (3): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 150], ['D', 163], ['D', 175]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=150, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=150, out_features=163, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=163, out_features=175, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=175, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 163], ['D', 175]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=163, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=163, out_features=175, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=175, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 206], ['D', 27], ['D', 519], ['D', 310]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=206, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=206, out_features=27, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=27, out_features=519, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=519, out_features=310, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=310, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 306]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=306, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=306, out_features=3, bias=True)
#     (3): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 135], ['D', 155]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=135, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=135, out_features=155, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=155, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 130], ['D', 466], ['D', 317]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=130, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=130, out_features=466, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=466, out_features=317, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=317, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 378], ['D', 460]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=378, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=378, out_features=460, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=460, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 471], ['D', 448]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=471, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=471, out_features=448, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=448, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 132], ['D', 261]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=132, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=132, out_features=261, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=261, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 163], ['D', 175]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=163, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=163, out_features=175, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=175, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 255]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=255, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=255, out_features=3, bias=True)
#     (3): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 221], ['D', 27], ['D', 310]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=221, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=221, out_features=27, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=27, out_features=310, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=310, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 398], ['D', 255]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=398, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=398, out_features=255, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=255, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 396], ['D', 403]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=396, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=396, out_features=403, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=403, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 398], ['D', 255]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=398, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=398, out_features=255, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=255, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 255]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=255, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=255, out_features=3, bias=True)
#     (3): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 188], ['D', 255]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=188, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=188, out_features=255, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=255, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 172], ['D', 255]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=172, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=172, out_features=255, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=255, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 370], ['D', 188], ['D', 255]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=370, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=370, out_features=188, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=188, out_features=255, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=255, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 188], ['D', 255]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=188, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=188, out_features=255, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=255, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 188], ['D', 255]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=188, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=188, out_features=255, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=255, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 188], ['D', 255]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=188, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=188, out_features=255, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=255, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 370], ['D', 188], ['D', 255]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=370, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=370, out_features=188, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=188, out_features=255, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=255, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 370], ['D', 188], ['D', 255]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=370, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=370, out_features=188, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=188, out_features=255, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=255, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 80], ['D', 370], ['D', 188], ['D', 255]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=80, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=80, out_features=370, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=370, out_features=188, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=188, out_features=255, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=255, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 677], ['D', 370], ['D', 188], ['D', 255]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=677, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=677, out_features=370, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=370, out_features=188, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=188, out_features=255, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=255, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 370], ['D', 188], ['D', 255]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=370, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=370, out_features=188, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=188, out_features=255, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=255, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}]
# Training individual #0
# Training individual #1
# Training individual #2
# Training individual #3
# Training individual #4
# Training individual #5
# Training individual #6
# Training individual #7
# Training individual #8
# Training individual #9
# Training individual #10
# Training individual #11
# Training individual #12
# Training individual #13
# Training individual #14
# Training individual #15
# Training individual #16
# Training individual #17
# Training individual #18
# Training individual #19
# Training individual #20
# Training individual #21
# Training individual #22
# Training individual #23
# Training individual #24
# Training individual #25
# Training individual #26
# Training individual #27
# Training individual #28
# Training individual #29
# Training individual #30
# Training individual #31
# Training individual #32
# Training individual #33
# Training individual #34
# Training individual #35
# Training individual #36
# Training individual #37
# Training individual #38
# Training individual #39
# Training individual #40
# Training individual #41
# Training individual #42
# Training individual #43
# Training individual #44
# Training individual #45
# Training individual #46
# Training individual #47
# Training individual #48
# Training individual #49
# Evaluating individual #0
# Evaluating individual #1
# Evaluating individual #2
# Evaluating individual #3
# Evaluating individual #4
# Evaluating individual #5
# Evaluating individual #6
# Evaluating individual #7
# Evaluating individual #8
# Evaluating individual #9
# Evaluating individual #10
# Evaluating individual #11
# Evaluating individual #12
# Evaluating individual #13
# Evaluating individual #14
# Evaluating individual #15
# Evaluating individual #16
# Evaluating individual #17
# Evaluating individual #18
# Evaluating individual #19
# Evaluating individual #20
# Evaluating individual #21
# Evaluating individual #22
# Evaluating individual #23
# Evaluating individual #24
# Evaluating individual #25
# Evaluating individual #26
# Evaluating individual #27
# Evaluating individual #28
# Evaluating individual #29
# Evaluating individual #30
# Evaluating individual #31
# Evaluating individual #32
# Evaluating individual #33
# Evaluating individual #34
# Evaluating individual #35
# Evaluating individual #36
# Evaluating individual #37
# Evaluating individual #38
# Evaluating individual #39
# Evaluating individual #40
# Evaluating individual #41
# Evaluating individual #42
# Evaluating individual #43
# Evaluating individual #44
# Evaluating individual #45
# Evaluating individual #46
# Evaluating individual #47
# Evaluating individual #48
# Evaluating individual #49

# %% [markdown]
# # Best architectures

# %%
generation.print_population(5)
# Out:
# Individual #0: {'genome': [['D', 306]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=306, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=306, out_features=3, bias=True)
#     (3): Softmax(dim=1)
#   )
# ), 'id': 26, 'loss': 0.0557524840037028, 'accuracy': 0.8066666666666666, 'parameters': 2451, 'fitness': 113}
# Individual #1: {'genome': [['D', 150], ['D', 163], ['D', 175]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=150, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=150, out_features=163, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=163, out_features=175, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=175, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# ), 'id': 23, 'loss': 0.04325804074605306, 'accuracy': 0.9333333333333333, 'parameters': 54591, 'fitness': 115}
# Individual #2: {'genome': [['D', 188], ['D', 255]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=188, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=188, out_features=255, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=255, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 39, 'loss': 0.0468983244895935, 'accuracy': 0.9266666666666666, 'parameters': 49903, 'fitness': 117}
# Individual #3: {'genome': [['D', 135], ['D', 155]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=135, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=135, out_features=155, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=155, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 27, 'loss': 0.04948233922322591, 'accuracy': 0.8866666666666667, 'parameters': 22223, 'fitness': 118}
# Individual #4: {'genome': [['D', 172], ['D', 255]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=172, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=172, out_features=255, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=255, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 40, 'loss': 0.04738814155260722, 'accuracy': 0.9466666666666667, 'parameters': 45743, 'fitness': 122}
