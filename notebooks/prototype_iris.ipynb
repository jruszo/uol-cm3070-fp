# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import pandas as pd

# %% [markdown]
# # Create dataset object for dataloader for XOR dataset

# %%
class Iris_dataset(torch.utils.data.Dataset):
    def __init__(self, data, labels):
        self.x = torch.tensor(data, dtype=torch.float32)
        self.y = torch.tensor(labels, dtype=torch.long)
        
    def __len__(self):
        return len(self.x)
    
    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]

# %%
data = pd.read_csv('../data/IRIS.csv')
df_norm = data[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']].apply(lambda x: (x - x.min()) / (x.max() - x.min()))
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
target= labelencoder.fit_transform(data['species'])
target = pd.DataFrame(target)
target.rename(columns = {0:'species'}, inplace = True)
df = pd.concat([df_norm, target], axis=1)

# %%
class ConstructNet(nn.Module):
    def __init__(self, DNA, loss_fn, input_size, output_size, outputlayer):
        super(ConstructNet, self).__init__()
        self.DNA = DNA
        self.input_size = input_size
        self.output_size = output_size
        self.layers = []
        self.loss_fn = loss_fn
        
        # Append first layer
        self.layers.append(nn.Linear(self.input_size, self.DNA[0][1]))
        self.layers.append(nn.ReLU())
        
        for i in range(1, len(self.DNA)):
            if self.DNA[i][0] == "D":
                # The input size is the output of the last layer
                tmp_input_size = self.last_layer_output_size()
                self.layers.append(nn.Linear(tmp_input_size, self.DNA[i][1]))
                self.layers.append(nn.ReLU())
            if self.DNA[i][0] == "R":
                self.layers.append(nn.Dropout(self.DNA[i][1]))
        
        # Append the output layer        
        self.layers.append(nn.Linear(self.layers[-2].out_features, self.output_size))
        #if self.output_size > 1: 
        #    self.layers.append(nn.Softmax(dim=1))
        #else:
        #    self.layers.append(nn.Sigmoid())
        self.layers.append(outputlayer)
        self.net = nn.Sequential(*self.layers)
        
    def forward(self, x):
        return self.net(x)
    '''
    Based on the layers created, find the output size of the last dense layer
    '''
    def last_layer_output_size(self):
        for layer in self.layers[::-1]:
            if isinstance(layer, nn.Linear):
                return layer.out_features
            
    def train_net(self, device, train_loader, optimizer, epoch, log_interval, print_stats):
        self.train()
        for batch_idx, (data, target) in enumerate(train_loader):
            data, target = data.to(device), target.to(device)
            optimizer.zero_grad()
            output = self.forward(data)
            loss = self.loss_fn(output, target)
            loss.backward()
            optimizer.step()
            if batch_idx % log_interval == 0 and print_stats:
                print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                    epoch, batch_idx * len(data), len(train_loader.dataset),
                    100. * batch_idx / len(train_loader), loss.item()))


    def test(self, device, test_loader, print_stats=False):
        self.eval()
        test_loss = 0
        correct = 0
        with torch.no_grad():
            for data, target in test_loader:
                data, target = data.to(device), target.to(device)
                output = self.forward(data)
                #print(f"output: {output}, target: {target}")
                test_loss += self.loss_fn.forward(output, target).item()  # sum up batch loss
                pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
                correct += pred.eq(target.view_as(pred)).sum().item()
        test_loss /= len(test_loader.dataset)
        accuracy = correct / len(test_loader.dataset)
        if print_stats:
            print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
                test_loss, correct, len(test_loader.dataset),
                100. * accuracy))
        return test_loss, accuracy
        
    def count_parameters(self):
        # https://discuss.pytorch.org/t/how-do-i-check-the-number-of-parameters-of-a-model/4325/7
        return sum(p.numel() for p in self.net.parameters() if p.requires_grad)

# %%
DNA_list = [
    [["D",1024],["D",512],["D",128]],
    [["D",1024],["R",0.2],["D",512],["R",0.2],["D",128]],
    [["D",64],["D", 64]]
]

# %% [markdown]
# # Initialise hyperparameters

# %%
batch_size = 16
use_mps = False and torch.backends.mps.is_available()
use_cuda = True and torch.cuda.is_available()
test_batch_size = 16
epochs = 30
lr = 0.02
gamma = 0.7
seed = 1
log_interval = 100
save_model = False

if use_cuda:
    device = torch.device("cuda")
elif use_mps:
    device = torch.device("mps")
else:
    device = torch.device("cpu")
    
train_kwargs = {'batch_size': batch_size}
test_kwargs = {'batch_size': test_batch_size}

# %%
train_dataset = Iris_dataset(df.values[:,:4], df['species'])
test_dataset = Iris_dataset(df.values[:,:4], df['species'])
train_loader = torch.utils.data.DataLoader(train_dataset,shuffle=True,**train_kwargs)
test_loader = torch.utils.data.DataLoader(test_dataset,shuffle=True, **test_kwargs)

# %%
outputlayer = nn.Softmax(dim=1)
generations = [[]]

for DNA in DNA_list:
    inv_net = ConstructNet(DNA, nn.CrossEntropyLoss(), input_size=4, output_size=3, outputlayer=outputlayer)
    print(inv_net)
    optimizer = optim.Adam(inv_net.parameters(), lr=lr)

    for epoch in range(1, epochs + 1):
        inv_net.train_net(device, train_loader, optimizer, epoch, log_interval, print_stats=True)
        inv_net.test(device, test_loader)
    if save_model:
        torch.save(inv_net.state_dict(), "mnist_cnn.pt")
    generations[0].append(inv_net)
# Out:
# ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=1024, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=1024, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=128, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=128, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )
# Train Epoch: 1 [0/150 (0%)]	Loss: 1.098877
#
# Test set: Average loss: 0.0819, Accuracy: 50/150 (33%)
#
# Train Epoch: 2 [0/150 (0%)]	Loss: 1.113945
#
# Test set: Average loss: 0.0791, Accuracy: 50/150 (33%)
#
# Train Epoch: 3 [0/150 (0%)]	Loss: 1.363945
#
# Test set: Average loss: 0.0812, Accuracy: 50/150 (33%)
#
# Train Epoch: 4 [0/150 (0%)]	Loss: 0.988945
#
# Test set: Average loss: 0.0805, Accuracy: 50/150 (33%)
#
# Train Epoch: 5 [0/150 (0%)]	Loss: 1.238945
#
# Test set: Average loss: 0.0805, Accuracy: 50/150 (33%)
#
# Train Epoch: 6 [0/150 (0%)]	Loss: 1.113945
#
# Test set: Average loss: 0.0805, Accuracy: 50/150 (33%)
#
# Train Epoch: 7 [0/150 (0%)]	Loss: 1.301445
#
# Test set: Average loss: 0.0812, Accuracy: 50/150 (33%)
#
# Train Epoch: 8 [0/150 (0%)]	Loss: 1.363945
#
# Test set: Average loss: 0.0805, Accuracy: 50/150 (33%)
#
# Train Epoch: 9 [0/150 (0%)]	Loss: 1.363945
#
# Test set: Average loss: 0.0798, Accuracy: 50/150 (33%)
#
# Train Epoch: 10 [0/150 (0%)]	Loss: 1.238945
#
# Test set: Average loss: 0.0819, Accuracy: 50/150 (33%)
#
# Train Epoch: 11 [0/150 (0%)]	Loss: 1.363945
#
# Test set: Average loss: 0.0819, Accuracy: 50/150 (33%)
#
# Train Epoch: 12 [0/150 (0%)]	Loss: 1.426445
#
# Test set: Average loss: 0.0791, Accuracy: 50/150 (33%)
#
# Train Epoch: 13 [0/150 (0%)]	Loss: 1.238945
#
# Test set: Average loss: 0.0805, Accuracy: 50/150 (33%)
#
# Train Epoch: 14 [0/150 (0%)]	Loss: 1.238945
#
# Test set: Average loss: 0.0805, Accuracy: 50/150 (33%)
#
# Train Epoch: 15 [0/150 (0%)]	Loss: 1.426445
#
# Test set: Average loss: 0.0819, Accuracy: 50/150 (33%)
#
# Train Epoch: 16 [0/150 (0%)]	Loss: 1.113945
#
# Test set: Average loss: 0.0805, Accuracy: 50/150 (33%)
#
# Train Epoch: 17 [0/150 (0%)]	Loss: 1.301445
#
# Test set: Average loss: 0.0819, Accuracy: 50/150 (33%)
#
# Train Epoch: 18 [0/150 (0%)]	Loss: 1.363945
#
# Test set: Average loss: 0.0819, Accuracy: 50/150 (33%)
#
# Train Epoch: 19 [0/150 (0%)]	Loss: 1.238945
#
# Test set: Average loss: 0.0812, Accuracy: 50/150 (33%)
#
# Train Epoch: 20 [0/150 (0%)]	Loss: 1.113945
#
# Test set: Average loss: 0.0805, Accuracy: 50/150 (33%)
#
# Train Epoch: 21 [0/150 (0%)]	Loss: 1.051445
#
# Test set: Average loss: 0.0812, Accuracy: 50/150 (33%)
#
# Train Epoch: 22 [0/150 (0%)]	Loss: 1.301445
#
# Test set: Average loss: 0.0812, Accuracy: 50/150 (33%)
#
# Train Epoch: 23 [0/150 (0%)]	Loss: 1.238945
#
# Test set: Average loss: 0.0798, Accuracy: 50/150 (33%)
#
# Train Epoch: 24 [0/150 (0%)]	Loss: 1.238945
#
# Test set: Average loss: 0.0805, Accuracy: 50/150 (33%)
#
# Train Epoch: 25 [0/150 (0%)]	Loss: 1.238945
#
# Test set: Average loss: 0.0819, Accuracy: 50/150 (33%)
#
# Train Epoch: 26 [0/150 (0%)]	Loss: 1.301445
#
# Test set: Average loss: 0.0819, Accuracy: 50/150 (33%)
#
# Train Epoch: 27 [0/150 (0%)]	Loss: 1.176445
#
# Test set: Average loss: 0.0819, Accuracy: 50/150 (33%)
#
# Train Epoch: 28 [0/150 (0%)]	Loss: 0.988945
#
# Test set: Average loss: 0.0819, Accuracy: 50/150 (33%)
#
# Train Epoch: 29 [0/150 (0%)]	Loss: 1.176445
#
# Test set: Average loss: 0.0812, Accuracy: 50/150 (33%)
#
# Train Epoch: 30 [0/150 (0%)]	Loss: 1.051445
#
# Test set: Average loss: 0.0812, Accuracy: 50/150 (33%)
#
# ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=1024, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=1024, out_features=512, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=512, out_features=128, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=128, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )
# Train Epoch: 1 [0/150 (0%)]	Loss: 1.096260
#
# Test set: Average loss: 0.0812, Accuracy: 50/150 (33%)
#
# Train Epoch: 2 [0/150 (0%)]	Loss: 1.238945
#
# Test set: Average loss: 0.0819, Accuracy: 50/150 (33%)
#
# Train Epoch: 3 [0/150 (0%)]	Loss: 0.863945
#
# Test set: Average loss: 0.0819, Accuracy: 50/150 (33%)
#
# Train Epoch: 4 [0/150 (0%)]	Loss: 1.176445
#
# Test set: Average loss: 0.0819, Accuracy: 50/150 (33%)
#
# Train Epoch: 5 [0/150 (0%)]	Loss: 1.301445
#
# Test set: Average loss: 0.0812, Accuracy: 50/150 (33%)
#
# Train Epoch: 6 [0/150 (0%)]	Loss: 1.238945
#
# Test set: Average loss: 0.0812, Accuracy: 50/150 (33%)
#
# Train Epoch: 7 [0/150 (0%)]	Loss: 1.301445
#
# Test set: Average loss: 0.0798, Accuracy: 50/150 (33%)
#
# Train Epoch: 8 [0/150 (0%)]	Loss: 1.238945
#
# Test set: Average loss: 0.0826, Accuracy: 50/150 (33%)
#
# Train Epoch: 9 [0/150 (0%)]	Loss: 1.301445
#
# Test set: Average loss: 0.0819, Accuracy: 50/150 (33%)
#
# Train Epoch: 10 [0/150 (0%)]	Loss: 1.238945
#
# Test set: Average loss: 0.0812, Accuracy: 50/150 (33%)
#
# Train Epoch: 11 [0/150 (0%)]	Loss: 1.176445
#
# Test set: Average loss: 0.0805, Accuracy: 50/150 (33%)
#
# Train Epoch: 12 [0/150 (0%)]	Loss: 1.176445
#
# Test set: Average loss: 0.0819, Accuracy: 50/150 (33%)
#
# Train Epoch: 13 [0/150 (0%)]	Loss: 1.176445
#
# Test set: Average loss: 0.0805, Accuracy: 50/150 (33%)
#
# Train Epoch: 14 [0/150 (0%)]	Loss: 1.238945
#
# Test set: Average loss: 0.0826, Accuracy: 50/150 (33%)
# Train Epoch: 15 [0/150 (0%)]	Loss: 1.238945
#
# Test set: Average loss: 0.0826, Accuracy: 50/150 (33%)
#
# Train Epoch: 16 [0/150 (0%)]	Loss: 1.176445
#
# Test set: Average loss: 0.0798, Accuracy: 50/150 (33%)
#
# Train Epoch: 17 [0/150 (0%)]	Loss: 1.301445
#
# Test set: Average loss: 0.0812, Accuracy: 50/150 (33%)
#
# Train Epoch: 18 [0/150 (0%)]	Loss: 1.176445
#
# Test set: Average loss: 0.0805, Accuracy: 50/150 (33%)
#
# Train Epoch: 19 [0/150 (0%)]	Loss: 1.176445
#
# Test set: Average loss: 0.0805, Accuracy: 50/150 (33%)
#
# Train Epoch: 20 [0/150 (0%)]	Loss: 1.301445
#
# Test set: Average loss: 0.0826, Accuracy: 50/150 (33%)
#
# Train Epoch: 21 [0/150 (0%)]	Loss: 1.176445
#
# Test set: Average loss: 0.0812, Accuracy: 50/150 (33%)
#
# Train Epoch: 22 [0/150 (0%)]	Loss: 1.113945
#
# Test set: Average loss: 0.0798, Accuracy: 50/150 (33%)
#
# Train Epoch: 23 [0/150 (0%)]	Loss: 1.051445
#
# Test set: Average loss: 0.0805, Accuracy: 50/150 (33%)
#
# Train Epoch: 24 [0/150 (0%)]	Loss: 1.176445
#
# Test set: Average loss: 0.0819, Accuracy: 50/150 (33%)
#
# Train Epoch: 25 [0/150 (0%)]	Loss: 1.426445
#
# Test set: Average loss: 0.0805, Accuracy: 50/150 (33%)
#
# Train Epoch: 26 [0/150 (0%)]	Loss: 1.176445
#
# Test set: Average loss: 0.0812, Accuracy: 50/150 (33%)
#
# Train Epoch: 27 [0/150 (0%)]	Loss: 1.238945
#
# Test set: Average loss: 0.0819, Accuracy: 50/150 (33%)
#
# Train Epoch: 28 [0/150 (0%)]	Loss: 1.238945
#
# Test set: Average loss: 0.0805, Accuracy: 50/150 (33%)
#
# Train Epoch: 29 [0/150 (0%)]	Loss: 1.113945
#
# Test set: Average loss: 0.0812, Accuracy: 50/150 (33%)
#
# Train Epoch: 30 [0/150 (0%)]	Loss: 1.238945
#
# Test set: Average loss: 0.0819, Accuracy: 50/150 (33%)
#
# ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=64, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=64, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )
# Train Epoch: 1 [0/150 (0%)]	Loss: 1.100268
#
# Test set: Average loss: 0.0544, Accuracy: 100/150 (67%)
#
# Train Epoch: 2 [0/150 (0%)]	Loss: 1.035411
#
# Test set: Average loss: 0.0455, Accuracy: 131/150 (87%)
#
# Train Epoch: 3 [0/150 (0%)]	Loss: 0.662242
#
# Test set: Average loss: 0.0399, Accuracy: 143/150 (95%)
#
# Train Epoch: 4 [0/150 (0%)]	Loss: 0.574213
#
# Test set: Average loss: 0.0390, Accuracy: 145/150 (97%)
#
# Train Epoch: 5 [0/150 (0%)]	Loss: 0.609106
#
# Test set: Average loss: 0.0433, Accuracy: 136/150 (91%)
#
# Train Epoch: 6 [0/150 (0%)]	Loss: 0.649878
#
# Test set: Average loss: 0.0407, Accuracy: 140/150 (93%)
#
# Train Epoch: 7 [0/150 (0%)]	Loss: 0.600194
#
# Test set: Average loss: 0.0392, Accuracy: 144/150 (96%)
#
# Train Epoch: 8 [0/150 (0%)]	Loss: 0.602455
#
# Test set: Average loss: 0.0386, Accuracy: 144/150 (96%)
#
# Train Epoch: 9 [0/150 (0%)]	Loss: 0.553026
#
# Test set: Average loss: 0.0400, Accuracy: 143/150 (95%)
#
# Train Epoch: 10 [0/150 (0%)]	Loss: 0.552551
#
# Test set: Average loss: 0.0411, Accuracy: 139/150 (93%)
#
# Train Epoch: 11 [0/150 (0%)]	Loss: 0.689642
#
# Test set: Average loss: 0.0391, Accuracy: 145/150 (97%)
#
# Train Epoch: 12 [0/150 (0%)]	Loss: 0.620446
#
# Test set: Average loss: 0.0386, Accuracy: 145/150 (97%)
#
# Train Epoch: 13 [0/150 (0%)]	Loss: 0.607577
#
# Test set: Average loss: 0.0409, Accuracy: 141/150 (94%)
#
# Train Epoch: 14 [0/150 (0%)]	Loss: 0.605160
#
# Test set: Average loss: 0.0401, Accuracy: 142/150 (95%)
#
# Train Epoch: 15 [0/150 (0%)]	Loss: 0.593142
#
# Test set: Average loss: 0.0401, Accuracy: 143/150 (95%)
#
# Train Epoch: 16 [0/150 (0%)]	Loss: 0.593116
#
# Test set: Average loss: 0.0386, Accuracy: 144/150 (96%)
#
# Train Epoch: 17 [0/150 (0%)]	Loss: 0.561388
#
# Test set: Average loss: 0.0389, Accuracy: 145/150 (97%)
#
# Train Epoch: 18 [0/150 (0%)]	Loss: 0.614033
#
# Test set: Average loss: 0.0382, Accuracy: 148/150 (99%)
#
# Train Epoch: 19 [0/150 (0%)]	Loss: 0.599460
#
# Test set: Average loss: 0.0388, Accuracy: 145/150 (97%)
#
# Train Epoch: 20 [0/150 (0%)]	Loss: 0.605150
#
# Test set: Average loss: 0.0387, Accuracy: 144/150 (96%)
#
# Train Epoch: 21 [0/150 (0%)]	Loss: 0.612695
#
# Test set: Average loss: 0.0404, Accuracy: 141/150 (94%)
#
# Train Epoch: 22 [0/150 (0%)]	Loss: 0.607224
#
# Test set: Average loss: 0.0388, Accuracy: 145/150 (97%)
#
# Train Epoch: 23 [0/150 (0%)]	Loss: 0.655026
#
# Test set: Average loss: 0.0388, Accuracy: 145/150 (97%)
#
# Train Epoch: 24 [0/150 (0%)]	Loss: 0.554728
#
# Test set: Average loss: 0.0389, Accuracy: 145/150 (97%)
#
# Train Epoch: 25 [0/150 (0%)]	Loss: 0.616292
#
# Test set: Average loss: 0.0380, Accuracy: 147/150 (98%)
#
# Train Epoch: 26 [0/150 (0%)]	Loss: 0.561797
#
# Test set: Average loss: 0.0397, Accuracy: 145/150 (97%)
#
# Train Epoch: 27 [0/150 (0%)]	Loss: 0.551649
#
# Test set: Average loss: 0.0393, Accuracy: 144/150 (96%)
#
# Train Epoch: 28 [0/150 (0%)]	Loss: 0.596292
#
# Test set: Average loss: 0.0390, Accuracy: 145/150 (97%)
#
# Train Epoch: 29 [0/150 (0%)]	Loss: 0.552903
#
# Test set: Average loss: 0.0388, Accuracy: 145/150 (97%)
#
# Train Epoch: 30 [0/150 (0%)]	Loss: 0.554772
#
# Test set: Average loss: 0.0397, Accuracy: 144/150 (96%)

# %%
generations
# Out:
# [[ConstructNet(
#     (loss_fn): CrossEntropyLoss()
#     (net): Sequential(
#       (0): Linear(in_features=4, out_features=1024, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=1024, out_features=512, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=512, out_features=128, bias=True)
#       (5): ReLU()
#       (6): Linear(in_features=128, out_features=3, bias=True)
#       (7): Softmax(dim=1)
#     )
#   ),
#   ConstructNet(
#     (loss_fn): CrossEntropyLoss()
#     (net): Sequential(
#       (0): Linear(in_features=4, out_features=1024, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.2, inplace=False)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): ReLU()
#       (5): Dropout(p=0.2, inplace=False)
#       (6): Linear(in_features=512, out_features=128, bias=True)
#       (7): ReLU()
#       (8): Linear(in_features=128, out_features=3, bias=True)
#       (9): Softmax(dim=1)
#     )
#   ),
#   ConstructNet(
#     (loss_fn): CrossEntropyLoss()
#     (net): Sequential(
#       (0): Linear(in_features=4, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=64, out_features=3, bias=True)
#       (5): Softmax(dim=1)
#     )
#   )]]

# %% [markdown]
# # Start of GA code

# %%
import random
import numpy as np
class GA():
    def __init__(self, generation_length, population_size, initial_size, initial_depth, 
                 lossFn, input_size, output_size, outputLayer, device, train_dataloader, test_dataloader, optimizerFn, epoch):
        self.generation_length = generation_length
        self.population_size = population_size
        self.initial = True # No previous individuals can be used for mutations
        self.initial_size = initial_size
        self.initial_depth = initial_depth
        
        self.lossFn = lossFn
        self.optimizerFn = optimizerFn
        self.input_size = input_size
        self.output_size = output_size
        self.outputLayer = outputLayer
        
        self.device = device
        self.train_dataloader = train_dataloader
        self.test_dataloader = test_dataloader
        self.epoch = epoch
        
        self.generate_population()
    
    def generate_population(self):
        self.population = []
        for i in range(self.population_size):
            self.population.append({'model': self.generate_individual()})
        self.initial = False
            
    def generate_individual(self):
        genome = []
        if self.initial:
            for chromosome in range(random.randint(np.floor(self.initial_depth/2), np.ceil(self.initial_depth*2))):
                layer_size = random.randint(np.floor(self.initial_size/2), np.ceil(self.initial_size*2))
                genome.append(["D",layer_size])
        return ConstructNet(genome, self.lossFn, self.input_size, self.output_size, self.outputLayer)
    
    def print_population(self):
        for index,individual in enumerate(self.population):
            print(f"Individual #{index}: {individual}")
            
    def train_population(self):
        for index,individual in enumerate(self.population):
            print(f"Training individual #{index}")
            if(self.optimizerFn == "Adam"):
                optimizer = torch.optim.Adam(individual['model'].parameters(), lr=0.01)
            individual['model'].train_net(self.device,self.train_dataloader, optimizer,self.epoch, 100, False)
    
    def evaluate_population(self):
        for index,individual in enumerate(self.population):
            print(f"Evaluating individual #{index}")
            loss, accuracy = individual['model'].test(self.device, self.test_dataloader)
            individual['id'] = index
            individual['loss'] = loss
            individual['accuracy'] = accuracy
            individual['parameters'] = individual['model'].count_parameters()
            self.population[index] = individual
        # sort population by accuracy
        #self.population = sorted(self.population, key=lambda d: d['accuracy'])
        
    def calculate_fitness(self):
        # Create copy of list using only a few columns
        tmp_list = []
        for index,item in enumerate(self.population):
            tmp_list.append({
                'id' : item['id'],
                'accuracy': item['accuracy'],
                'parameters': item['parameters'],
                'fitness': 0
            })
        accuracy_list = sorted(tmp_list, key=lambda d: d['accuracy'])
        # Adding more emphasis on accuracy
        for index,item in enumerate(accuracy_list):
            accuracy_list[index]['fitness'] += index*2
        # Reverse sort, smaller is better
        parameter_size_list = sorted(accuracy_list, key=lambda d: d['parameters'], reverse=True)
        for index,item in enumerate(parameter_size_list):
            parameter_size_list[index]['fitness'] += index
        sorted_by_fitness = sorted(parameter_size_list, key=lambda d: d['fitness'])
        #print("======= list by accuracy_list =========")
        #print(accuracy_list)
        #print("======= list by parameter_size =========")
        #print(parameter_size_list)
        #print("======= list by fitness =========")
        #print(sorted_by_fitness)
        for fitness in sorted_by_fitness:
            for index,individual in enumerate(self.population):
                if individual['id'] == fitness['id']:
                    individual['fitness'] = fitness['fitness']
            self.population[index] = individual
        # Sort population
        self.population = sorted(self.population, key=lambda d: d['fitness'])
        print(self.population)

# %%
train_dataset = Iris_dataset(df.values[:,:4], df['species'])
test_dataset = Iris_dataset(df.values[:,:4], df['species'])
train_loader = torch.utils.data.DataLoader(train_dataset,shuffle=True,**train_kwargs)
test_loader = torch.utils.data.DataLoader(test_dataset,shuffle=True, **test_kwargs)

generation = GA(generation_length=10,population_size=50,initial_size=256,initial_depth=5, lossFn=nn.CrossEntropyLoss(), input_size=4, output_size=3, outputLayer=nn.Softmax(dim=1), device=device, train_dataloader=train_loader, test_dataloader=test_loader, optimizerFn="Adam", epoch=100  )
generation.print_population()
# Out:
# Individual #0: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=303, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=303, out_features=438, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=438, out_features=500, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=500, out_features=339, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=339, out_features=176, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=176, out_features=476, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=476, out_features=303, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=303, out_features=349, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=349, out_features=155, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=155, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}
# Individual #1: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=344, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=344, out_features=174, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=174, out_features=479, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=479, out_features=280, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=280, out_features=168, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=168, out_features=222, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=222, out_features=497, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=497, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}
# Individual #2: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=456, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=456, out_features=189, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=189, out_features=467, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=467, out_features=223, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=223, out_features=312, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=312, out_features=476, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=476, out_features=288, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=288, out_features=161, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=161, out_features=247, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=247, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}
# Individual #3: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=218, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=218, out_features=460, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=460, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}
# Individual #4: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=246, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=246, out_features=231, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=231, out_features=131, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=131, out_features=319, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=319, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}
# Individual #5: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=134, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=134, out_features=343, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=343, out_features=233, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=233, out_features=424, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=424, out_features=314, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=314, out_features=312, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=312, out_features=177, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=177, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}
# Individual #6: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=269, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=269, out_features=169, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=169, out_features=160, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=160, out_features=296, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=296, out_features=427, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=427, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}
# Individual #7: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=129, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=129, out_features=324, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=324, out_features=470, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=470, out_features=321, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=321, out_features=209, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=209, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}
# Individual #8: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=498, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=498, out_features=205, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=205, out_features=158, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=158, out_features=441, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=441, out_features=315, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=315, out_features=417, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=417, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}
# Individual #9: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=237, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=237, out_features=210, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=210, out_features=387, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=387, out_features=295, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=295, out_features=198, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=198, out_features=366, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=366, out_features=319, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=319, out_features=455, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=455, out_features=329, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=329, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}
# Individual #10: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=254, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=254, out_features=260, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=260, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}
# Individual #11: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=465, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=465, out_features=272, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=272, out_features=474, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=474, out_features=484, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=484, out_features=491, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=491, out_features=432, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=432, out_features=395, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=395, out_features=431, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=431, out_features=388, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=388, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}
# Individual #12: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=289, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=289, out_features=341, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=341, out_features=156, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=156, out_features=502, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=502, out_features=250, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=250, out_features=230, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=230, out_features=372, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=372, out_features=420, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=420, out_features=371, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=371, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}
# Individual #13: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=194, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=194, out_features=256, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=256, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}
# Individual #14: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=465, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=465, out_features=254, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=254, out_features=241, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=241, out_features=401, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=401, out_features=431, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=431, out_features=291, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=291, out_features=173, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=173, out_features=269, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=269, out_features=472, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=472, out_features=234, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=234, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# )}
# Individual #15: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=405, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=405, out_features=466, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=466, out_features=217, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=217, out_features=504, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=504, out_features=492, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=492, out_features=259, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=259, out_features=496, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=496, out_features=335, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=335, out_features=450, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=450, out_features=509, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=509, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# )}
# Individual #16: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=367, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=367, out_features=219, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=219, out_features=501, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=501, out_features=417, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=417, out_features=265, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=265, out_features=197, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=197, out_features=450, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=450, out_features=176, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=176, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}
# Individual #17: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=292, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=292, out_features=413, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=413, out_features=173, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=173, out_features=391, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=391, out_features=217, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=217, out_features=262, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=262, out_features=483, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=483, out_features=229, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=229, out_features=348, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=348, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}
# Individual #18: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=507, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=507, out_features=296, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=296, out_features=396, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=396, out_features=407, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=407, out_features=351, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=351, out_features=497, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=497, out_features=429, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=429, out_features=357, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=357, out_features=337, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=337, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}
# Individual #19: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=330, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=330, out_features=363, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=363, out_features=373, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=373, out_features=303, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=303, out_features=351, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=351, out_features=363, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=363, out_features=393, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=393, out_features=274, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=274, out_features=250, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=250, out_features=347, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=347, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# )}
# Individual #20: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=333, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=333, out_features=490, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=490, out_features=440, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=440, out_features=363, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=363, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}
# Individual #21: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=375, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=375, out_features=291, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=291, out_features=230, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=230, out_features=405, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=405, out_features=381, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=381, out_features=456, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=456, out_features=222, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=222, out_features=376, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=376, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}
# Individual #22: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=501, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=501, out_features=502, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=502, out_features=130, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=130, out_features=476, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=476, out_features=454, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=454, out_features=245, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=245, out_features=312, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=312, out_features=218, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=218, out_features=376, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=376, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}
# Individual #23: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=228, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=228, out_features=207, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=207, out_features=250, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=250, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}
# Individual #24: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=470, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=470, out_features=299, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=299, out_features=147, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=147, out_features=510, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=510, out_features=306, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=306, out_features=278, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=278, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}
# Individual #25: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=136, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=136, out_features=292, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=292, out_features=309, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=309, out_features=297, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=297, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}
# Individual #26: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=338, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=338, out_features=294, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=294, out_features=244, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=244, out_features=388, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=388, out_features=193, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=193, out_features=223, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=223, out_features=212, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=212, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}
# Individual #27: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=398, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=398, out_features=167, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=167, out_features=492, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=492, out_features=164, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=164, out_features=228, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=228, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}
# Individual #28: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=205, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=205, out_features=438, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=438, out_features=463, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=463, out_features=302, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=302, out_features=139, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=139, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}
# Individual #29: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=223, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=223, out_features=462, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=462, out_features=462, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=462, out_features=436, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=436, out_features=459, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=459, out_features=246, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=246, out_features=460, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=460, out_features=373, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=373, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}
# Individual #30: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=250, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=250, out_features=366, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=366, out_features=170, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=170, out_features=462, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=462, out_features=214, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=214, out_features=246, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=246, out_features=284, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=284, out_features=153, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=153, out_features=324, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=324, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}
# Individual #31: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=260, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=260, out_features=177, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=177, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}
# Individual #32: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=293, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=293, out_features=416, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=416, out_features=244, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=244, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}
# Individual #33: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=484, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=484, out_features=235, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=235, out_features=331, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=331, out_features=165, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=165, out_features=463, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=463, out_features=451, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=451, out_features=320, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=320, out_features=435, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=435, out_features=492, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=492, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}
# Individual #34: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=381, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=381, out_features=406, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=406, out_features=299, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=299, out_features=327, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=327, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}
# Individual #35: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=451, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=451, out_features=200, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=200, out_features=296, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=296, out_features=275, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=275, out_features=253, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=253, out_features=215, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=215, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}
# Individual #36: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=296, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=296, out_features=379, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=379, out_features=471, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=471, out_features=132, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=132, out_features=446, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=446, out_features=478, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=478, out_features=392, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=392, out_features=297, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=297, out_features=313, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=313, out_features=274, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=274, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# )}
# Individual #37: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=170, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=170, out_features=186, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=186, out_features=149, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=149, out_features=268, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=268, out_features=262, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=262, out_features=147, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=147, out_features=182, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=182, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}
# Individual #38: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=267, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=267, out_features=345, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=345, out_features=189, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=189, out_features=499, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=499, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}
# Individual #39: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=167, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=167, out_features=456, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=456, out_features=322, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=322, out_features=470, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=470, out_features=176, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=176, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}
# Individual #40: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=360, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=360, out_features=237, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=237, out_features=430, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=430, out_features=158, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=158, out_features=492, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=492, out_features=206, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=206, out_features=485, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=485, out_features=204, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=204, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}
# Individual #41: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=273, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=273, out_features=510, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=510, out_features=332, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=332, out_features=326, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=326, out_features=358, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=358, out_features=458, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=458, out_features=286, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=286, out_features=439, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=439, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}
# Individual #42: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=314, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=314, out_features=327, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=327, out_features=505, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=505, out_features=401, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=401, out_features=149, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=149, out_features=209, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=209, out_features=359, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=359, out_features=397, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=397, out_features=207, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=207, out_features=197, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=197, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# )}
# Individual #43: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=469, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=469, out_features=405, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=405, out_features=477, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=477, out_features=164, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=164, out_features=187, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=187, out_features=303, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=303, out_features=269, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=269, out_features=187, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=187, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}
# Individual #44: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=199, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=199, out_features=356, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=356, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}
# Individual #45: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=213, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=213, out_features=359, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=359, out_features=155, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=155, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}
# Individual #46: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=191, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=191, out_features=236, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=236, out_features=503, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=503, out_features=215, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=215, out_features=272, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=272, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}
# Individual #47: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=233, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=233, out_features=350, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=350, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}
# Individual #48: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=450, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=450, out_features=450, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=450, out_features=330, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=330, out_features=160, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=160, out_features=488, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=488, out_features=428, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=428, out_features=360, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=360, out_features=402, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=402, out_features=400, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=400, out_features=394, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=394, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# )}
# Individual #49: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=247, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=247, out_features=340, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=340, out_features=380, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=380, out_features=175, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=175, out_features=198, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=198, out_features=252, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=252, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}

# %%
generation.train_population()
# Out:
# Training individual #0
# Training individual #1
# Training individual #2
# Training individual #3
# Training individual #4
# Training individual #5
# Training individual #6
# Training individual #7
# Training individual #8
# Training individual #9
# Training individual #10
# Training individual #11
# Training individual #12
# Training individual #13
# Training individual #14
# Training individual #15
# Training individual #16
# Training individual #17
# Training individual #18
# Training individual #19
# Training individual #20
# Training individual #21
# Training individual #22
# Training individual #23
# Training individual #24
# Training individual #25
# Training individual #26
# Training individual #27
# Training individual #28
# Training individual #29
# Training individual #30
# Training individual #31
# Training individual #32
# Training individual #33
# Training individual #34
# Training individual #35
# Training individual #36
# Training individual #37
# Training individual #38
# Training individual #39
# Training individual #40
# Training individual #41
# Training individual #42
# Training individual #43
# Training individual #44
# Training individual #45
# Training individual #46
# Training individual #47
# Training individual #48
# Training individual #49

# %%
generation.evaluate_population()
# Out:
# Evaluating individual #0
# Evaluating individual #1
# Evaluating individual #2
# Evaluating individual #3
# Evaluating individual #4
# Evaluating individual #5
# Evaluating individual #6
# Evaluating individual #7
# Evaluating individual #8
# Evaluating individual #9
# Evaluating individual #10
# Evaluating individual #11
# Evaluating individual #12
# Evaluating individual #13
# Evaluating individual #14
# Evaluating individual #15
# Evaluating individual #16
# Evaluating individual #17
# Evaluating individual #18
# Evaluating individual #19
# Evaluating individual #20
# Evaluating individual #21
# Evaluating individual #22
# Evaluating individual #23
# Evaluating individual #24
# Evaluating individual #25
# Evaluating individual #26
# Evaluating individual #27
# Evaluating individual #28
# Evaluating individual #29
# Evaluating individual #30
# Evaluating individual #31
# Evaluating individual #32
# Evaluating individual #33
# Evaluating individual #34
# Evaluating individual #35
# Evaluating individual #36
# Evaluating individual #37
# Evaluating individual #38
# Evaluating individual #39
# Evaluating individual #40
# Evaluating individual #41
# Evaluating individual #42
# Evaluating individual #43
# Evaluating individual #44
# Evaluating individual #45
# Evaluating individual #46
# Evaluating individual #47
# Evaluating individual #48
# Evaluating individual #49

# %%
generation.print_population()
# Out:
# Individual #0: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=303, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=303, out_features=438, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=438, out_features=500, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=500, out_features=339, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=339, out_features=176, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=176, out_features=476, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=476, out_features=303, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=303, out_features=349, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=349, out_features=155, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=155, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 0, 'loss': 0.06198034048080445, 'accuracy': 0.3333333333333333, 'parameters': 973443}
# Individual #1: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=344, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=344, out_features=174, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=174, out_features=479, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=479, out_features=280, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=280, out_features=168, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=168, out_features=222, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=222, out_features=497, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=497, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# ), 'id': 1, 'loss': 0.08051299095153809, 'accuracy': 0.3333333333333333, 'parameters': 477026}
# Individual #2: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=456, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=456, out_features=189, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=189, out_features=467, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=467, out_features=223, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=223, out_features=312, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=312, out_features=476, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=476, out_features=288, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=288, out_features=161, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=161, out_features=247, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=247, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 2, 'loss': 0.06621554811795552, 'accuracy': 0.5933333333333334, 'parameters': 725286}
# Individual #3: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=218, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=218, out_features=460, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=460, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 3, 'loss': 0.05774741689364116, 'accuracy': 0.6666666666666666, 'parameters': 103213}
# Individual #4: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=246, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=246, out_features=231, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=231, out_features=131, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=131, out_features=319, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=319, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# ), 'id': 4, 'loss': 0.057883230845133464, 'accuracy': 0.6666666666666666, 'parameters': 131747}
# Individual #5: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=134, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=134, out_features=343, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=343, out_features=233, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=233, out_features=424, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=424, out_features=314, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=314, out_features=312, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=312, out_features=177, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=177, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# ), 'id': 5, 'loss': 0.07261703173319499, 'accuracy': 0.3333333333333333, 'parameters': 514008}
# Individual #6: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=269, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=269, out_features=169, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=169, out_features=160, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=160, out_features=296, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=296, out_features=427, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=427, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# ), 'id': 6, 'loss': 0.05489007910092672, 'accuracy': 0.6733333333333333, 'parameters': 249934}
# Individual #7: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=129, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=129, out_features=324, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=324, out_features=470, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=470, out_features=321, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=321, out_features=209, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=209, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# ), 'id': 7, 'loss': 0.057569000323613485, 'accuracy': 0.6666666666666666, 'parameters': 414634}
# Individual #8: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=498, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=498, out_features=205, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=205, out_features=158, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=158, out_features=441, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=441, out_features=315, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=315, out_features=417, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=417, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# ), 'id': 8, 'loss': 0.08120743115743001, 'accuracy': 0.3333333333333333, 'parameters': 479708}
# Individual #9: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=237, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=237, out_features=210, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=210, out_features=387, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=387, out_features=295, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=295, out_features=198, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=198, out_features=366, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=366, out_features=319, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=319, out_features=455, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=455, out_features=329, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=329, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 9, 'loss': 0.05504196405410767, 'accuracy': 0.6666666666666666, 'parameters': 792411}
# Individual #10: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=254, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=254, out_features=260, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=260, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 10, 'loss': 0.04564550558725993, 'accuracy': 0.9133333333333333, 'parameters': 68353}
# Individual #11: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=465, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=465, out_features=272, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=272, out_features=474, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=474, out_features=484, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=484, out_features=491, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=491, out_features=432, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=432, out_features=395, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=395, out_features=431, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=431, out_features=388, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=388, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 11, 'loss': 0.08051299095153809, 'accuracy': 0.3333333333333333, 'parameters': 1449552}
# Individual #12: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=289, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=289, out_features=341, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=341, out_features=156, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=156, out_features=502, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=502, out_features=250, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=250, out_features=230, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=230, out_features=372, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=372, out_features=420, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=420, out_features=371, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=371, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 12, 'loss': 0.06845122496287027, 'accuracy': 0.3333333333333333, 'parameters': 815880}
# Individual #13: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=194, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=194, out_features=256, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=256, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 13, 'loss': 0.04511857708295186, 'accuracy': 0.9466666666666667, 'parameters': 51661}
# Individual #14: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=465, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=465, out_features=254, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=254, out_features=241, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=241, out_features=401, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=401, out_features=431, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=431, out_features=291, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=291, out_features=173, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=173, out_features=269, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=269, out_features=472, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=472, out_features=234, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=234, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# ), 'id': 14, 'loss': 0.07309880495071411, 'accuracy': 0.3333333333333333, 'parameters': 914309}
# Individual #15: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=405, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=405, out_features=466, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=466, out_features=217, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=217, out_features=504, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=504, out_features=492, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=492, out_features=259, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=259, out_features=496, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=496, out_features=335, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=335, out_features=450, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=450, out_features=509, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=509, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# ), 'id': 15, 'loss': 0.07325068791707356, 'accuracy': 0.3333333333333333, 'parameters': 1456323}
# Individual #16: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=367, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=367, out_features=219, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=219, out_features=501, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=501, out_features=417, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=417, out_features=265, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=265, out_features=197, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=197, out_features=450, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=450, out_features=176, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=176, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 16, 'loss': 0.06043626467386882, 'accuracy': 0.64, 'parameters': 734160}
# Individual #17: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=292, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=292, out_features=413, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=413, out_features=173, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=173, out_features=391, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=391, out_features=217, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=217, out_features=262, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=262, out_features=483, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=483, out_features=229, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=229, out_features=348, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=348, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 17, 'loss': 0.06945368528366089, 'accuracy': 0.3333333333333333, 'parameters': 723257}
# Individual #18: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=507, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=507, out_features=296, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=296, out_features=396, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=396, out_features=407, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=407, out_features=351, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=351, out_features=497, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=497, out_features=429, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=429, out_features=357, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=357, out_features=337, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=337, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 18, 'loss': 0.07309888283411661, 'accuracy': 0.3333333333333333, 'parameters': 1239058}
# Individual #19: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=330, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=330, out_features=363, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=363, out_features=373, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=373, out_features=303, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=303, out_features=351, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=351, out_features=363, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=363, out_features=393, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=393, out_features=274, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=274, out_features=250, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=250, out_features=347, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=347, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# ), 'id': 19, 'loss': 0.06949580152829488, 'accuracy': 0.6666666666666666, 'parameters': 1013276}
# Individual #20: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=333, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=333, out_features=490, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=490, out_features=440, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=440, out_features=363, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=363, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# ), 'id': 20, 'loss': 0.05956790248552958, 'accuracy': 0.6133333333333333, 'parameters': 542540}
# Individual #21: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=375, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=375, out_features=291, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=291, out_features=230, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=230, out_features=405, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=405, out_features=381, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=381, out_features=456, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=456, out_features=222, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=222, out_features=376, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=376, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 21, 'loss': 0.0595864999294281, 'accuracy': 0.6533333333333333, 'parameters': 787317}
# Individual #22: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=501, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=501, out_features=502, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=502, out_features=130, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=130, out_features=476, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=476, out_features=454, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=454, out_features=245, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=245, out_features=312, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=312, out_features=218, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=218, out_features=376, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=376, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 22, 'loss': 0.06770843187967936, 'accuracy': 0.6666666666666666, 'parameters': 938749}
# Individual #23: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=228, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=228, out_features=207, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=207, out_features=250, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=250, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# ), 'id': 23, 'loss': 0.053662881056467694, 'accuracy': 0.6666666666666666, 'parameters': 101296}
# Individual #24: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=470, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=470, out_features=299, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=299, out_features=147, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=147, out_features=510, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=510, out_features=306, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=306, out_features=278, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=278, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# ), 'id': 24, 'loss': 0.0749303142229716, 'accuracy': 0.3333333333333333, 'parameters': 505308}
# Individual #25: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=136, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=136, out_features=292, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=292, out_features=309, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=309, out_features=297, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=297, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# ), 'id': 25, 'loss': 0.05192970792452494, 'accuracy': 0.6666666666666666, 'parameters': 224185}
# Individual #26: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=338, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=338, out_features=294, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=294, out_features=244, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=244, out_features=388, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=388, out_features=193, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=193, out_features=223, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=223, out_features=212, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=212, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# ), 'id': 26, 'loss': 0.07150259176890056, 'accuracy': 0.3333333333333333, 'parameters': 434862}
# Individual #27: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=398, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=398, out_features=167, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=167, out_features=492, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=492, out_features=164, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=164, out_features=228, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=228, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# ), 'id': 27, 'loss': 0.05393536527951558, 'accuracy': 0.6666666666666666, 'parameters': 270438}
# Individual #28: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=205, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=205, out_features=438, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=438, out_features=463, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=463, out_features=302, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=302, out_features=139, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=139, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# ), 'id': 28, 'loss': 0.05735430796941121, 'accuracy': 0.6666666666666666, 'parameters': 477175}
# Individual #29: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=223, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=223, out_features=462, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=462, out_features=462, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=462, out_features=436, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=436, out_features=459, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=459, out_features=246, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=246, out_features=460, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=460, out_features=373, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=373, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 29, 'loss': 0.07981854399045309, 'accuracy': 0.3333333333333333, 'parameters': 1120815}
# Individual #30: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=250, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=250, out_features=366, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=366, out_features=170, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=170, out_features=462, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=462, out_features=214, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=214, out_features=246, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=246, out_features=284, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=284, out_features=153, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=153, out_features=324, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=324, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 30, 'loss': 0.08190187772115072, 'accuracy': 0.3333333333333333, 'parameters': 551104}
# Individual #31: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=260, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=260, out_features=177, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=177, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 31, 'loss': 0.05602973779042562, 'accuracy': 0.6666666666666666, 'parameters': 48031}
# Individual #32: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=293, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=293, out_features=416, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=416, out_features=244, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=244, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# ), 'id': 32, 'loss': 0.04836955666542053, 'accuracy': 0.78, 'parameters': 226252}
# Individual #33: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=484, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=484, out_features=235, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=235, out_features=331, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=331, out_features=165, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=165, out_features=463, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=463, out_features=451, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=451, out_features=320, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=320, out_features=435, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=435, out_features=492, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=492, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 33, 'loss': 0.07318919658660888, 'accuracy': 0.3333333333333333, 'parameters': 1035679}
# Individual #34: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=381, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=381, out_features=406, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=406, out_features=299, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=299, out_features=327, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=327, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# ), 'id': 34, 'loss': 0.056771633625030515, 'accuracy': 0.6733333333333333, 'parameters': 377774}
# Individual #35: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=451, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=451, out_features=200, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=200, out_features=296, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=296, out_features=275, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=275, out_features=253, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=253, out_features=215, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=215, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# ), 'id': 35, 'loss': 0.08152552207310994, 'accuracy': 0.34, 'parameters': 358912}
# Individual #36: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=296, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=296, out_features=379, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=379, out_features=471, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=471, out_features=132, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=132, out_features=446, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=446, out_features=478, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=478, out_features=392, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=392, out_features=297, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=297, out_features=313, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=313, out_features=274, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=274, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# ), 'id': 36, 'loss': 0.05972474972407023, 'accuracy': 0.62, 'parameters': 1112935}
# Individual #37: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=170, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=170, out_features=186, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=186, out_features=149, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=149, out_features=268, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=268, out_features=262, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=262, out_features=147, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=147, out_features=182, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=182, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# ), 'id': 37, 'loss': 0.07314897934595743, 'accuracy': 0.34, 'parameters': 237343}
# Individual #38: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=267, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=267, out_features=345, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=345, out_features=189, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=189, out_features=499, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=499, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# ), 'id': 38, 'loss': 0.05945036888122559, 'accuracy': 0.6666666666666666, 'parameters': 255499}
# Individual #39: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=167, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=167, out_features=456, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=456, out_features=322, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=322, out_features=470, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=470, out_features=176, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=176, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# ), 'id': 39, 'loss': 0.08190187374750774, 'accuracy': 0.3333333333333333, 'parameters': 459834}
# Individual #40: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=360, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=360, out_features=237, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=237, out_features=430, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=430, out_features=158, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=158, out_features=492, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=492, out_features=206, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=206, out_features=485, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=485, out_features=204, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=204, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 40, 'loss': 0.06758985002835592, 'accuracy': 0.3333333333333333, 'parameters': 637735}
# Individual #41: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=273, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=273, out_features=510, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=510, out_features=332, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=332, out_features=326, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=326, out_features=358, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=358, out_features=458, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=458, out_features=286, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=286, out_features=439, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=439, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 41, 'loss': 0.05898520270983378, 'accuracy': 0.6666666666666666, 'parameters': 959390}
# Individual #42: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=314, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=314, out_features=327, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=327, out_features=505, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=505, out_features=401, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=401, out_features=149, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=149, out_features=209, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=209, out_features=359, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=359, out_features=397, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=397, out_features=207, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=207, out_features=197, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=197, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# ), 'id': 42, 'loss': 0.06512858788172404, 'accuracy': 0.6666666666666666, 'parameters': 906635}
# Individual #43: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=469, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=469, out_features=405, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=405, out_features=477, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=477, out_features=164, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=164, out_features=187, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=187, out_features=303, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=303, out_features=269, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=269, out_features=187, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=187, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 43, 'loss': 0.08051299015680949, 'accuracy': 0.3333333333333333, 'parameters': 685398}
# Individual #44: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=199, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=199, out_features=356, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=356, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 44, 'loss': 0.05969406127929688, 'accuracy': 0.6666666666666666, 'parameters': 73266}
# Individual #45: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=213, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=213, out_features=359, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=359, out_features=155, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=155, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# ), 'id': 45, 'loss': 0.04699748436609904, 'accuracy': 0.9666666666666667, 'parameters': 134159}
# Individual #46: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=191, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=191, out_features=236, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=236, out_features=503, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=503, out_features=215, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=215, out_features=272, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=272, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# ), 'id': 46, 'loss': 0.05248058795928955, 'accuracy': 0.6666666666666666, 'parameters': 333409}
# Individual #47: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=233, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=233, out_features=350, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=350, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 47, 'loss': 0.046684089899063114, 'accuracy': 0.92, 'parameters': 84118}
# Individual #48: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=450, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=450, out_features=450, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=450, out_features=330, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=330, out_features=160, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=160, out_features=488, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=488, out_features=428, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=428, out_features=360, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=360, out_features=402, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=402, out_features=400, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=400, out_features=394, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=394, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# ), 'id': 48, 'loss': 0.0732312790552775, 'accuracy': 0.3333333333333333, 'parameters': 1314791}
# Individual #49: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=247, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=247, out_features=340, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=340, out_features=380, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=380, out_features=175, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=175, out_features=198, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=198, out_features=252, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=252, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# ), 'id': 49, 'loss': 0.05882240613301595, 'accuracy': 0.6666666666666666, 'parameters': 367565}

# %%
generation.calculate_fitness()
# Out:
# [{'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=303, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=303, out_features=438, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=438, out_features=500, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=500, out_features=339, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=339, out_features=176, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=176, out_features=476, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=476, out_features=303, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=303, out_features=349, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=349, out_features=155, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=155, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 0, 'loss': 0.06198034048080445, 'accuracy': 0.3333333333333333, 'parameters': 973443, 'fitness': 8}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=465, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=465, out_features=272, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=272, out_features=474, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=474, out_features=484, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=484, out_features=491, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=491, out_features=432, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=432, out_features=395, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=395, out_features=431, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=431, out_features=388, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=388, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 11, 'loss': 0.08051299095153809, 'accuracy': 0.3333333333333333, 'parameters': 1449552, 'fitness': 9}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=405, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=405, out_features=466, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=466, out_features=217, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=217, out_features=504, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=504, out_features=492, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=492, out_features=259, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=259, out_features=496, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=496, out_features=335, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=335, out_features=450, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=450, out_features=509, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=509, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# ), 'id': 15, 'loss': 0.07325068791707356, 'accuracy': 0.3333333333333333, 'parameters': 1456323, 'fitness': 14}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=507, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=507, out_features=296, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=296, out_features=396, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=396, out_features=407, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=407, out_features=351, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=351, out_features=497, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=497, out_features=429, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=429, out_features=357, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=357, out_features=337, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=337, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 18, 'loss': 0.07309888283411661, 'accuracy': 0.3333333333333333, 'parameters': 1239058, 'fitness': 21}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=289, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=289, out_features=341, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=341, out_features=156, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=156, out_features=502, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=502, out_features=250, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=250, out_features=230, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=230, out_features=372, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=372, out_features=420, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=420, out_features=371, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=371, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 12, 'loss': 0.06845122496287027, 'accuracy': 0.3333333333333333, 'parameters': 815880, 'fitness': 23}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=465, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=465, out_features=254, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=254, out_features=241, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=241, out_features=401, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=401, out_features=431, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=431, out_features=291, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=291, out_features=173, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=173, out_features=269, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=269, out_features=472, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=472, out_features=234, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=234, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# ), 'id': 14, 'loss': 0.07309880495071411, 'accuracy': 0.3333333333333333, 'parameters': 914309, 'fitness': 23}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=134, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=134, out_features=343, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=343, out_features=233, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=233, out_features=424, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=424, out_features=314, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=314, out_features=312, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=312, out_features=177, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=177, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# ), 'id': 5, 'loss': 0.07261703173319499, 'accuracy': 0.3333333333333333, 'parameters': 514008, 'fitness': 27}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=223, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=223, out_features=462, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=462, out_features=462, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=462, out_features=436, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=436, out_features=459, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=459, out_features=246, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=246, out_features=460, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=460, out_features=373, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=373, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 29, 'loss': 0.07981854399045309, 'accuracy': 0.3333333333333333, 'parameters': 1120815, 'fitness': 28}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=344, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=344, out_features=174, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=174, out_features=479, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=479, out_features=280, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=280, out_features=168, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=168, out_features=222, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=222, out_features=497, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=497, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# ), 'id': 1, 'loss': 0.08051299095153809, 'accuracy': 0.3333333333333333, 'parameters': 477026, 'fitness': 29}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=498, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=498, out_features=205, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=205, out_features=158, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=158, out_features=441, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=441, out_features=315, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=315, out_features=417, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=417, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# ), 'id': 8, 'loss': 0.08120743115743001, 'accuracy': 0.3333333333333333, 'parameters': 479708, 'fitness': 31}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=292, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=292, out_features=413, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=413, out_features=173, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=173, out_features=391, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=391, out_features=217, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=217, out_features=262, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=262, out_features=483, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=483, out_features=229, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=229, out_features=348, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=348, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 17, 'loss': 0.06945368528366089, 'accuracy': 0.3333333333333333, 'parameters': 723257, 'fitness': 34}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=484, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=484, out_features=235, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=235, out_features=331, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=331, out_features=165, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=165, out_features=463, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=463, out_features=451, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=451, out_features=320, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=320, out_features=435, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=435, out_features=492, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=492, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 33, 'loss': 0.07318919658660888, 'accuracy': 0.3333333333333333, 'parameters': 1035679, 'fitness': 34}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=450, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=450, out_features=450, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=450, out_features=330, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=330, out_features=160, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=160, out_features=488, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=488, out_features=428, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=428, out_features=360, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=360, out_features=402, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=402, out_features=400, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=400, out_features=394, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=394, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# ), 'id': 48, 'loss': 0.0732312790552775, 'accuracy': 0.3333333333333333, 'parameters': 1314791, 'fitness': 38}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=470, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=470, out_features=299, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=299, out_features=147, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=147, out_features=510, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=510, out_features=306, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=306, out_features=278, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=278, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# ), 'id': 24, 'loss': 0.0749303142229716, 'accuracy': 0.3333333333333333, 'parameters': 505308, 'fitness': 44}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=250, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=250, out_features=366, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=366, out_features=170, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=170, out_features=462, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=462, out_features=214, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=214, out_features=246, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=246, out_features=284, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=284, out_features=153, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=153, out_features=324, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=324, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 30, 'loss': 0.08190187772115072, 'accuracy': 0.3333333333333333, 'parameters': 551104, 'fitness': 47}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=338, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=338, out_features=294, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=294, out_features=244, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=244, out_features=388, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=388, out_features=193, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=193, out_features=223, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=223, out_features=212, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=212, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# ), 'id': 26, 'loss': 0.07150259176890056, 'accuracy': 0.3333333333333333, 'parameters': 434862, 'fitness': 51}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=296, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=296, out_features=379, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=379, out_features=471, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=471, out_features=132, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=132, out_features=446, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=446, out_features=478, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=478, out_features=392, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=392, out_features=297, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=297, out_features=313, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=313, out_features=274, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=274, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# ), 'id': 36, 'loss': 0.05972474972407023, 'accuracy': 0.62, 'parameters': 1112935, 'fitness': 51}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=360, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=360, out_features=237, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=237, out_features=430, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=430, out_features=158, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=158, out_features=492, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=492, out_features=206, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=206, out_features=485, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=485, out_features=204, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=204, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 40, 'loss': 0.06758985002835592, 'accuracy': 0.3333333333333333, 'parameters': 637735, 'fitness': 52}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=469, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=469, out_features=405, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=405, out_features=477, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=477, out_features=164, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=164, out_features=187, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=187, out_features=303, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=303, out_features=269, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=269, out_features=187, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=187, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 43, 'loss': 0.08051299015680949, 'accuracy': 0.3333333333333333, 'parameters': 685398, 'fitness': 53}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=167, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=167, out_features=456, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=456, out_features=322, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=322, out_features=470, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=470, out_features=176, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=176, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# ), 'id': 39, 'loss': 0.08190187374750774, 'accuracy': 0.3333333333333333, 'parameters': 459834, 'fitness': 58}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=456, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=456, out_features=189, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=189, out_features=467, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=467, out_features=223, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=223, out_features=312, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=312, out_features=476, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=476, out_features=288, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=288, out_features=161, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=161, out_features=247, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=247, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 2, 'loss': 0.06621554811795552, 'accuracy': 0.5933333333333334, 'parameters': 725286, 'fitness': 59}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=367, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=367, out_features=219, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=219, out_features=501, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=501, out_features=417, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=417, out_features=265, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=265, out_features=197, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=197, out_features=450, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=450, out_features=176, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=176, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 16, 'loss': 0.06043626467386882, 'accuracy': 0.64, 'parameters': 734160, 'fitness': 64}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=375, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=375, out_features=291, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=291, out_features=230, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=230, out_features=405, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=405, out_features=381, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=381, out_features=456, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=456, out_features=222, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=222, out_features=376, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=376, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 21, 'loss': 0.0595864999294281, 'accuracy': 0.6533333333333333, 'parameters': 787317, 'fitness': 65}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=333, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=333, out_features=490, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=490, out_features=440, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=440, out_features=363, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=363, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# ), 'id': 20, 'loss': 0.05956790248552958, 'accuracy': 0.6133333333333333, 'parameters': 542540, 'fitness': 66}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=330, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=330, out_features=363, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=363, out_features=373, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=373, out_features=303, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=303, out_features=351, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=351, out_features=363, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=363, out_features=393, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=393, out_features=274, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=274, out_features=250, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=250, out_features=347, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=347, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# ), 'id': 19, 'loss': 0.06949580152829488, 'accuracy': 0.6666666666666666, 'parameters': 1013276, 'fitness': 67}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=451, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=451, out_features=200, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=200, out_features=296, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=296, out_features=275, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=275, out_features=253, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=253, out_features=215, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=215, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# ), 'id': 35, 'loss': 0.08152552207310994, 'accuracy': 0.34, 'parameters': 358912, 'fitness': 71}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=237, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=237, out_features=210, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=210, out_features=387, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=387, out_features=295, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=295, out_features=198, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=198, out_features=366, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=366, out_features=319, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=319, out_features=455, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=455, out_features=329, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=329, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 9, 'loss': 0.05504196405410767, 'accuracy': 0.6666666666666666, 'parameters': 792411, 'fitness': 72}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=501, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=501, out_features=502, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=502, out_features=130, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=130, out_features=476, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=476, out_features=454, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=454, out_features=245, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=245, out_features=312, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=312, out_features=218, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=218, out_features=376, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=376, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 22, 'loss': 0.06770843187967936, 'accuracy': 0.6666666666666666, 'parameters': 938749, 'fitness': 72}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=170, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=170, out_features=186, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=186, out_features=149, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=149, out_features=268, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=268, out_features=262, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=262, out_features=147, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=147, out_features=182, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=182, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# ), 'id': 37, 'loss': 0.07314897934595743, 'accuracy': 0.34, 'parameters': 237343, 'fitness': 78}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=273, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=273, out_features=510, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=510, out_features=332, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=332, out_features=326, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=326, out_features=358, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=358, out_features=458, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=458, out_features=286, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=286, out_features=439, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=439, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 41, 'loss': 0.05898520270983378, 'accuracy': 0.6666666666666666, 'parameters': 959390, 'fitness': 85}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=129, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=129, out_features=324, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=324, out_features=470, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=470, out_features=321, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=321, out_features=209, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=209, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# ), 'id': 7, 'loss': 0.057569000323613485, 'accuracy': 0.6666666666666666, 'parameters': 414634, 'fitness': 86}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=314, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=314, out_features=327, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=327, out_features=505, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=505, out_features=401, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=401, out_features=149, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=149, out_features=209, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=209, out_features=359, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=359, out_features=397, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=397, out_features=207, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=207, out_features=197, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=197, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# ), 'id': 42, 'loss': 0.06512858788172404, 'accuracy': 0.6666666666666666, 'parameters': 906635, 'fitness': 90}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=218, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=218, out_features=460, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=460, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 3, 'loss': 0.05774741689364116, 'accuracy': 0.6666666666666666, 'parameters': 103213, 'fitness': 95}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=246, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=246, out_features=231, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=231, out_features=131, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=131, out_features=319, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=319, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# ), 'id': 4, 'loss': 0.057883230845133464, 'accuracy': 0.6666666666666666, 'parameters': 131747, 'fitness': 96}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=205, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=205, out_features=438, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=438, out_features=463, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=463, out_features=302, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=302, out_features=139, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=139, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# ), 'id': 28, 'loss': 0.05735430796941121, 'accuracy': 0.6666666666666666, 'parameters': 477175, 'fitness': 96}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=398, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=398, out_features=167, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=167, out_features=492, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=492, out_features=164, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=164, out_features=228, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=228, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# ), 'id': 27, 'loss': 0.05393536527951558, 'accuracy': 0.6666666666666666, 'parameters': 270438, 'fitness': 103}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=136, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=136, out_features=292, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=292, out_features=309, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=309, out_features=297, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=297, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# ), 'id': 25, 'loss': 0.05192970792452494, 'accuracy': 0.6666666666666666, 'parameters': 224185, 'fitness': 106}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=228, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=228, out_features=207, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=207, out_features=250, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=250, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# ), 'id': 23, 'loss': 0.053662881056467694, 'accuracy': 0.6666666666666666, 'parameters': 101296, 'fitness': 108}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=267, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=267, out_features=345, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=345, out_features=189, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=189, out_features=499, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=499, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# ), 'id': 38, 'loss': 0.05945036888122559, 'accuracy': 0.6666666666666666, 'parameters': 255499, 'fitness': 110}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=191, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=191, out_features=236, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=236, out_features=503, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=503, out_features=215, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=215, out_features=272, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=272, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# ), 'id': 46, 'loss': 0.05248058795928955, 'accuracy': 0.6666666666666666, 'parameters': 333409, 'fitness': 116}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=247, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=247, out_features=340, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=340, out_features=380, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=380, out_features=175, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=175, out_features=198, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=198, out_features=252, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=252, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# ), 'id': 49, 'loss': 0.05882240613301595, 'accuracy': 0.6666666666666666, 'parameters': 367565, 'fitness': 116}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=381, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=381, out_features=406, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=406, out_features=299, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=299, out_features=327, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=327, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# ), 'id': 34, 'loss': 0.056771633625030515, 'accuracy': 0.6733333333333333, 'parameters': 377774, 'fitness': 119}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=260, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=260, out_features=177, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=177, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 31, 'loss': 0.05602973779042562, 'accuracy': 0.6666666666666666, 'parameters': 48031, 'fitness': 121}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=269, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=269, out_features=169, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=169, out_features=160, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=160, out_features=296, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=296, out_features=427, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=427, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# ), 'id': 6, 'loss': 0.05489007910092672, 'accuracy': 0.6733333333333333, 'parameters': 249934, 'fitness': 123}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=199, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=199, out_features=356, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=356, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 44, 'loss': 0.05969406127929688, 'accuracy': 0.6666666666666666, 'parameters': 73266, 'fitness': 126}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=293, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=293, out_features=416, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=416, out_features=244, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=244, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# ), 'id': 32, 'loss': 0.04836955666542053, 'accuracy': 0.78, 'parameters': 226252, 'fitness': 129}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=254, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=254, out_features=260, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=260, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 10, 'loss': 0.04564550558725993, 'accuracy': 0.9133333333333333, 'parameters': 68353, 'fitness': 139}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=213, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=213, out_features=359, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=359, out_features=155, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=155, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# ), 'id': 45, 'loss': 0.04699748436609904, 'accuracy': 0.9666666666666667, 'parameters': 134159, 'fitness': 139}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=233, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=233, out_features=350, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=350, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 47, 'loss': 0.046684089899063114, 'accuracy': 0.92, 'parameters': 84118, 'fitness': 139}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=194, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=194, out_features=256, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=256, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 13, 'loss': 0.04511857708295186, 'accuracy': 0.9466666666666667, 'parameters': 51661, 'fitness': 144}]
