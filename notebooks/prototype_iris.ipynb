# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import pandas as pd

# %% [markdown]
# # Create dataset object for dataloader for XOR dataset

# %%
class Iris_dataset(torch.utils.data.Dataset):
    def __init__(self, data, labels):
        self.x = torch.tensor(data, dtype=torch.float32)
        self.y = torch.tensor(labels, dtype=torch.long)
        
    def __len__(self):
        return len(self.x)
    
    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]

# %%
data = pd.read_csv('../data/IRIS.csv')
df_norm = data[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']].apply(lambda x: (x - x.min()) / (x.max() - x.min()))
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
target= labelencoder.fit_transform(data['species'])
target = pd.DataFrame(target)
target.rename(columns = {0:'species'}, inplace = True)
df = pd.concat([df_norm, target], axis=1)

# %%
class ConstructNet(nn.Module):
    def __init__(self, DNA, loss_fn, input_size, output_size, outputlayer):
        print(DNA)
        super(ConstructNet, self).__init__()
        self.DNA = DNA
        self.input_size = input_size
        self.output_size = output_size
        self.layers = []
        self.loss_fn = loss_fn
        
        # Append first layer
        self.layers.append(nn.Linear(self.input_size, self.DNA[0][1]))
        self.layers.append(nn.ReLU())
        
        for i in range(1, len(self.DNA)):
            print(self.DNA[i])
            if self.DNA[i][0] == "D":
                # The input size is the output of the last layer
                tmp_input_size = self.last_layer_output_size()
                self.layers.append(nn.Linear(tmp_input_size, self.DNA[i][1]))
                self.layers.append(nn.ReLU())
            if self.DNA[i][0] == "R":
                self.layers.append(nn.Dropout(self.DNA[i][1]))
        
        # Append the output layer        
        self.layers.append(nn.Linear(self.layers[-2].out_features, self.output_size))
        #if self.output_size > 1: 
        #    self.layers.append(nn.Softmax(dim=1))
        #else:
        #    self.layers.append(nn.Sigmoid())
        self.layers.append(outputlayer)
        self.net = nn.Sequential(*self.layers)
        
    def forward(self, x):
        return self.net(x)
    '''
    Based on the layers created, find the output size of the last dense layer
    '''
    def last_layer_output_size(self):
        for layer in self.layers[::-1]:
            if isinstance(layer, nn.Linear):
                return layer.out_features
            
    def train_net(self, device, train_loader, optimizer, epoch, log_interval, print_stats):
        self.train()
        for batch_idx, (data, target) in enumerate(train_loader):
            data, target = data.to(device), target.to(device)
            optimizer.zero_grad()
            output = self.forward(data)
            loss = self.loss_fn(output, target)
            loss.backward()
            optimizer.step()
            if batch_idx % log_interval == 0 and print_stats:
                print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                    epoch, batch_idx * len(data), len(train_loader.dataset),
                    100. * batch_idx / len(train_loader), loss.item()))


    def test(self, device, test_loader, print_stats=False):
        self.eval()
        test_loss = 0
        correct = 0
        with torch.no_grad():
            for data, target in test_loader:
                data, target = data.to(device), target.to(device)
                output = self.forward(data)
                #print(f"output: {output}, target: {target}")
                test_loss += self.loss_fn.forward(output, target).item()  # sum up batch loss
                pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
                correct += pred.eq(target.view_as(pred)).sum().item()
        test_loss /= len(test_loader.dataset)
        accuracy = correct / len(test_loader.dataset)
        if print_stats:
            print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
                test_loss, correct, len(test_loader.dataset),
                100. * accuracy))
        return test_loss, accuracy
        
    def count_parameters(self):
        # https://discuss.pytorch.org/t/how-do-i-check-the-number-of-parameters-of-a-model/4325/7
        return sum(p.numel() for p in self.net.parameters() if p.requires_grad)

# %%
DNA_list = [
    [["D",1024],["D",512],["D",128]],
    [["D",1024],["R",0.2],["D",512],["R",0.2],["D",128]],
    [["D",64],["D", 64]]
]

# %% [markdown]
# # Initialise hyperparameters

# %%
batch_size = 16
use_mps = False and torch.backends.mps.is_available()
use_cuda = True and torch.cuda.is_available()
test_batch_size = 16
epochs = 30
lr = 0.02
gamma = 0.7
seed = 1
log_interval = 100
save_model = False

if use_cuda:
    device = torch.device("cuda")
elif use_mps:
    device = torch.device("mps")
else:
    device = torch.device("cpu")
    
train_kwargs = {'batch_size': batch_size}
test_kwargs = {'batch_size': test_batch_size}

# %%
train_dataset = Iris_dataset(df.values[:,:4], df['species'])
test_dataset = Iris_dataset(df.values[:,:4], df['species'])
train_loader = torch.utils.data.DataLoader(train_dataset,shuffle=True,**train_kwargs)
test_loader = torch.utils.data.DataLoader(test_dataset,shuffle=True, **test_kwargs)

# %%
outputlayer = nn.Softmax(dim=1)
generations = [[]]

for DNA in DNA_list:
    inv_net = ConstructNet(DNA, nn.CrossEntropyLoss(), input_size=4, output_size=3, outputlayer=outputlayer)
    print(inv_net)
    optimizer = optim.Adam(inv_net.parameters(), lr=lr)

    for epoch in range(1, epochs + 1):
        inv_net.train_net(device, train_loader, optimizer, epoch, log_interval, print_stats=True)
        inv_net.test(device, test_loader)
    if save_model:
        torch.save(inv_net.state_dict(), "mnist_cnn.pt")
    generations[0].append(inv_net)
# Out:
# [['D', 1024], ['D', 512], ['D', 128]]
# ['D', 512]
# ['D', 128]
# ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=1024, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=1024, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=128, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=128, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )
# Train Epoch: 1 [0/150 (0%)]	Loss: 1.100782
# Train Epoch: 2 [0/150 (0%)]	Loss: 1.051445
# Train Epoch: 3 [0/150 (0%)]	Loss: 0.801445
# Train Epoch: 4 [0/150 (0%)]	Loss: 0.926445
# Train Epoch: 5 [0/150 (0%)]	Loss: 0.863945
# Train Epoch: 6 [0/150 (0%)]	Loss: 0.988945
# Train Epoch: 7 [0/150 (0%)]	Loss: 1.051445
# Train Epoch: 8 [0/150 (0%)]	Loss: 0.738945
# Train Epoch: 9 [0/150 (0%)]	Loss: 0.926445
# Train Epoch: 10 [0/150 (0%)]	Loss: 1.113945
# Train Epoch: 11 [0/150 (0%)]	Loss: 0.926445
# Train Epoch: 12 [0/150 (0%)]	Loss: 1.113945
# Train Epoch: 13 [0/150 (0%)]	Loss: 0.988945
# Train Epoch: 14 [0/150 (0%)]	Loss: 0.988945
# Train Epoch: 15 [0/150 (0%)]	Loss: 0.988945
# Train Epoch: 16 [0/150 (0%)]	Loss: 0.988945
# Train Epoch: 17 [0/150 (0%)]	Loss: 0.863945
# Train Epoch: 18 [0/150 (0%)]	Loss: 1.051445
# Train Epoch: 19 [0/150 (0%)]	Loss: 0.863945
# Train Epoch: 20 [0/150 (0%)]	Loss: 0.738945
# Train Epoch: 21 [0/150 (0%)]	Loss: 0.863945
# Train Epoch: 22 [0/150 (0%)]	Loss: 0.926445
# Train Epoch: 23 [0/150 (0%)]	Loss: 1.051445
# Train Epoch: 24 [0/150 (0%)]	Loss: 0.926445
# Train Epoch: 25 [0/150 (0%)]	Loss: 1.051445
# Train Epoch: 26 [0/150 (0%)]	Loss: 0.926445
# Train Epoch: 27 [0/150 (0%)]	Loss: 0.926445
# Train Epoch: 28 [0/150 (0%)]	Loss: 0.863945
# Train Epoch: 29 [0/150 (0%)]	Loss: 0.801445
# Train Epoch: 30 [0/150 (0%)]	Loss: 0.863945
# [['D', 1024], ['R', 0.2], ['D', 512], ['R', 0.2], ['D', 128]]
# ['R', 0.2]
# ['D', 512]
# ['R', 0.2]
# ['D', 128]
# ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=1024, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=1024, out_features=512, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=512, out_features=128, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=128, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )
# Train Epoch: 1 [0/150 (0%)]	Loss: 1.097605
# Train Epoch: 2 [0/150 (0%)]	Loss: 1.301445
# Train Epoch: 3 [0/150 (0%)]	Loss: 0.988945
# Train Epoch: 4 [0/150 (0%)]	Loss: 1.301445
# Train Epoch: 5 [0/150 (0%)]	Loss: 1.113945
# Train Epoch: 6 [0/150 (0%)]	Loss: 1.426445
# Train Epoch: 7 [0/150 (0%)]	Loss: 1.176445
# Train Epoch: 8 [0/150 (0%)]	Loss: 1.363945
# Train Epoch: 9 [0/150 (0%)]	Loss: 1.051445
# Train Epoch: 10 [0/150 (0%)]	Loss: 1.238945
# Train Epoch: 11 [0/150 (0%)]	Loss: 1.051445
# Train Epoch: 12 [0/150 (0%)]	Loss: 1.301445
# Train Epoch: 13 [0/150 (0%)]	Loss: 1.238945
# Train Epoch: 14 [0/150 (0%)]	Loss: 1.238945
# Train Epoch: 15 [0/150 (0%)]	Loss: 1.238945
# Train Epoch: 16 [0/150 (0%)]	Loss: 1.176445
# Train Epoch: 17 [0/150 (0%)]	Loss: 1.051445
# Train Epoch: 18 [0/150 (0%)]	Loss: 1.301445
# Train Epoch: 19 [0/150 (0%)]	Loss: 1.301445
# Train Epoch: 20 [0/150 (0%)]	Loss: 1.301445
# Train Epoch: 21 [0/150 (0%)]	Loss: 1.363945
# Train Epoch: 22 [0/150 (0%)]	Loss: 1.238945
# Train Epoch: 23 [0/150 (0%)]	Loss: 1.238945
# Train Epoch: 24 [0/150 (0%)]	Loss: 1.176445
# Train Epoch: 25 [0/150 (0%)]	Loss: 1.301445
# Train Epoch: 26 [0/150 (0%)]	Loss: 1.301445
# Train Epoch: 27 [0/150 (0%)]	Loss: 1.113945
# Train Epoch: 28 [0/150 (0%)]	Loss: 1.176445
# Train Epoch: 29 [0/150 (0%)]	Loss: 1.301445
# Train Epoch: 30 [0/150 (0%)]	Loss: 1.301445
# [['D', 64], ['D', 64]]
# ['D', 64]
# ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=64, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=64, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )
# Train Epoch: 1 [0/150 (0%)]	Loss: 1.104269
# Train Epoch: 2 [0/150 (0%)]	Loss: 0.758675
# Train Epoch: 3 [0/150 (0%)]	Loss: 0.725526
# Train Epoch: 4 [0/150 (0%)]	Loss: 0.660500
# Train Epoch: 5 [0/150 (0%)]	Loss: 0.683574
# Train Epoch: 6 [0/150 (0%)]	Loss: 0.742986
# Train Epoch: 7 [0/150 (0%)]	Loss: 0.601760
# Train Epoch: 8 [0/150 (0%)]	Loss: 0.564840
# Train Epoch: 9 [0/150 (0%)]	Loss: 0.619028
# Train Epoch: 10 [0/150 (0%)]	Loss: 0.586305
# Train Epoch: 11 [0/150 (0%)]	Loss: 0.676307
# Train Epoch: 12 [0/150 (0%)]	Loss: 0.566487
# Train Epoch: 13 [0/150 (0%)]	Loss: 0.638781
# Train Epoch: 14 [0/150 (0%)]	Loss: 0.561560
# Train Epoch: 15 [0/150 (0%)]	Loss: 0.592737
# Train Epoch: 16 [0/150 (0%)]	Loss: 0.556081
# Train Epoch: 17 [0/150 (0%)]	Loss: 0.559183
# Train Epoch: 18 [0/150 (0%)]	Loss: 0.709241
# Train Epoch: 19 [0/150 (0%)]	Loss: 0.587643
# Train Epoch: 20 [0/150 (0%)]	Loss: 0.564147
# Train Epoch: 21 [0/150 (0%)]	Loss: 0.576871
# Train Epoch: 22 [0/150 (0%)]	Loss: 0.609658
# Train Epoch: 23 [0/150 (0%)]	Loss: 0.608014
# Train Epoch: 24 [0/150 (0%)]	Loss: 0.607336
# Train Epoch: 25 [0/150 (0%)]	Loss: 0.625208
# Train Epoch: 26 [0/150 (0%)]	Loss: 0.611788
# Train Epoch: 27 [0/150 (0%)]	Loss: 0.595834
# Train Epoch: 28 [0/150 (0%)]	Loss: 0.615330
# Train Epoch: 29 [0/150 (0%)]	Loss: 0.560717
# Train Epoch: 30 [0/150 (0%)]	Loss: 0.558723

# %%
generations
# Out:
# [[ConstructNet(
#     (loss_fn): CrossEntropyLoss()
#     (net): Sequential(
#       (0): Linear(in_features=4, out_features=1024, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=1024, out_features=512, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=512, out_features=128, bias=True)
#       (5): ReLU()
#       (6): Linear(in_features=128, out_features=3, bias=True)
#       (7): Softmax(dim=1)
#     )
#   ),
#   ConstructNet(
#     (loss_fn): CrossEntropyLoss()
#     (net): Sequential(
#       (0): Linear(in_features=4, out_features=1024, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.2, inplace=False)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): ReLU()
#       (5): Dropout(p=0.2, inplace=False)
#       (6): Linear(in_features=512, out_features=128, bias=True)
#       (7): ReLU()
#       (8): Linear(in_features=128, out_features=3, bias=True)
#       (9): Softmax(dim=1)
#     )
#   ),
#   ConstructNet(
#     (loss_fn): CrossEntropyLoss()
#     (net): Sequential(
#       (0): Linear(in_features=4, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=64, out_features=3, bias=True)
#       (5): Softmax(dim=1)
#     )
#   )]]

# %% [markdown]
# # Start of GA code

# %%
import random
import numpy as np
class GA():
    def __init__(self, generation_length, population_size, initial_size, initial_depth, 
                 lossFn, input_size, output_size, outputLayer, device, train_dataloader, test_dataloader, optimizerFn, epoch):
        self.generation_length = generation_length
        self.population_size = population_size
        self.initial = True # No previous individuals can be used for mutations
        self.initial_size = initial_size
        self.initial_depth = initial_depth
        
        self.lossFn = lossFn
        self.optimizerFn = optimizerFn
        self.input_size = input_size
        self.output_size = output_size
        self.outputLayer = outputLayer
        
        self.device = device
        self.train_dataloader = train_dataloader
        self.test_dataloader = test_dataloader
        self.epoch = epoch
        self.population = []
        
        #self.generate_population()
    
    def auto_evolve(self):
        for i in range(self.generation_length):
            print(f"Generation #{i}")
            self.generate_population()
            self.train_population()
            self.evaluate_population()
            self.calculate_fitness()
            
    def generate_population(self):
        tmp_list = []
        for index,item in enumerate(self.population):
            tmp_list.append({
                'genome': item['genome'],
                'model': item['model'],
            })
        self.population = tmp_list
        del tmp_list
        
        if self.initial:
            for i in range(self.population_size):
                genome = self.generate_individual()
                self.population.append({'genome': genome})
        else:
            # Delete 25% of the population
            del self.population[:int(np.floor(self.population_size/4))]
            # Generate new individuals to have the same population size
            for i in range(self.population_size-len(self.population)):
                genome = self.generate_individual()
                self.population.append({'genome': genome})
        # Create models for each individual        
        for index,individual in enumerate(self.population):
            model = ConstructNet(individual['genome'], self.lossFn, self.input_size, self.output_size, self.outputLayer)
            individual['model'] = model
            self.population[index] = individual
        self.initial = False
            
    def generate_individual(self):
        genome = []
        if self.initial:
            for chromosome in range(random.randint(np.floor(self.initial_depth/2), np.ceil(self.initial_depth*2))):
                layer_size = random.randint(np.floor(self.initial_size/2), np.ceil(self.initial_size*2))
                genome.append(["D",layer_size])
        else:
            # Get the DNA of one of the best 5 individuals, that are at the end of the list
            random_index = random.randint(len(self.population)-5, len(self.population)-1)
            #print(random_index)
            original_genome = self.population[random_index]['genome'].copy()
            genome = self.mutate_genome(original_genome)
        #print(genome)
        return genome
    
    def mutate_genome(self, genome):
        # example genome: [["D",1024],["D",512],["D",128]]
        # possible mutations: Add new larger layer, add new smaller layer, change layer size, remove layer
        # 1. Add new larger layer
        if random.random() < 0.25:
            # select random layer
            layer_index = random.randint(0, len(genome)-1)
            new_layer_size = np.ceil(genome[layer_index][1] * (1 + random.random())).astype(int)
            genome.insert(layer_index, ["D",new_layer_size])
        # 2. Add new smaller layer
        if random.random() < 0.25:
            # select random layer
            layer_index = random.randint(0, len(genome)-1)
            new_layer_size = np.floor(genome[layer_index][1] * (1 - random.random())).astype(int)
            genome.insert(layer_index, ["D",new_layer_size])
        # 3. Change layer size
        if random.random() < 0.25:
            # select random layer
            layer_index = random.randint(0, len(genome)-1)
            new_layer_size = np.round(genome[layer_index][1] * random.random()).astype(int)
            genome[layer_index][1] = new_layer_size
        # 4. Remove layer
        if random.random() < 0.25 and len(genome) > 1:
            # select random layer
            layer_index = random.randint(0, len(genome)-1)
            del genome[layer_index]
        return genome
    
    def print_population(self, top_n=False):
        if not top_n:
            top_n = len(self.population)
        for index,individual in enumerate(self.population[-top_n:]):
            print(f"Individual #{index}: {individual}")
            
    def train_population(self):
        print(self.population)
        for index,individual in enumerate(self.population):
            print(f"Training individual #{index}")
            if self.optimizerFn == "Adam":
                optimizer = torch.optim.Adam(individual['model'].parameters(), lr=0.01)
            individual['model'].train_net(self.device,self.train_dataloader, optimizer,self.epoch, 100, False)
    
    def evaluate_population(self):
        for index,individual in enumerate(self.population):
            print(f"Evaluating individual #{index}")
            loss, accuracy = individual['model'].test(self.device, self.test_dataloader)
            individual['id'] = index
            individual['loss'] = loss
            individual['accuracy'] = accuracy
            individual['parameters'] = individual['model'].count_parameters()
            self.population[index] = individual
        
    def calculate_fitness(self):
        # Create copy of list using only a few columns
        tmp_list = []
        for index,item in enumerate(self.population):
            tmp_list.append({
                'id' : item['id'],
                'accuracy': item['accuracy'],
                'parameters': item['parameters'],
                'fitness': 0
            })
        accuracy_list = sorted(tmp_list, key=lambda d: d['accuracy'])
        # Adding more emphasis on accuracy
        for index,item in enumerate(accuracy_list):
            accuracy_list[index]['fitness'] += index*2
        # Reverse sort, smaller is better
        parameter_size_list = sorted(accuracy_list, key=lambda d: d['parameters'], reverse=True)
        for index,item in enumerate(parameter_size_list):
            parameter_size_list[index]['fitness'] += index
        sorted_by_fitness = sorted(parameter_size_list, key=lambda d: d['fitness'])
        for fitness in sorted_by_fitness:
            for index,individual in enumerate(self.population):
                if individual['id'] == fitness['id']:
                    individual['fitness'] = fitness['fitness']
            self.population[index] = individual
        # Sort population
        self.population = sorted(self.population, key=lambda d: d['fitness'])
        #print(self.population)

# %%
train_dataset = Iris_dataset(df.values[:,:4], df['species'])
test_dataset = Iris_dataset(df.values[:,:4], df['species'])
train_loader = torch.utils.data.DataLoader(train_dataset,shuffle=True,**train_kwargs)
test_loader = torch.utils.data.DataLoader(test_dataset,shuffle=True, **test_kwargs)

generation = GA(generation_length=10,population_size=50,initial_size=256,initial_depth=5, lossFn=nn.CrossEntropyLoss(), input_size=4, output_size=3, outputLayer=nn.Softmax(dim=1), device=device, train_dataloader=train_loader, test_dataloader=test_loader, optimizerFn="Adam", epoch=100  )
generation.generate_population()
generation.print_population()
# Out:
# [['D', 323], ['D', 268], ['D', 411], ['D', 379], ['D', 155], ['D', 254]]
# ['D', 268]
# ['D', 411]
# ['D', 379]
# ['D', 155]
# ['D', 254]
# [['D', 463], ['D', 248], ['D', 379], ['D', 330], ['D', 466], ['D', 191], ['D', 354], ['D', 480]]
# ['D', 248]
# ['D', 379]
# ['D', 330]
# ['D', 466]
# ['D', 191]
# ['D', 354]
# ['D', 480]
# [['D', 492], ['D', 259], ['D', 437], ['D', 256], ['D', 379], ['D', 383], ['D', 251], ['D', 176], ['D', 395]]
# ['D', 259]
# ['D', 437]
# ['D', 256]
# ['D', 379]
# ['D', 383]
# ['D', 251]
# ['D', 176]
# ['D', 395]
# [['D', 497], ['D', 387], ['D', 232], ['D', 287], ['D', 429], ['D', 214], ['D', 472], ['D', 415]]
# ['D', 387]
# ['D', 232]
# ['D', 287]
# ['D', 429]
# ['D', 214]
# ['D', 472]
# ['D', 415]
# [['D', 447], ['D', 460], ['D', 160], ['D', 292], ['D', 313], ['D', 214], ['D', 341]]
# ['D', 460]
# ['D', 160]
# ['D', 292]
# ['D', 313]
# ['D', 214]
# ['D', 341]
# [['D', 402], ['D', 375], ['D', 242]]
# ['D', 375]
# ['D', 242]
# [['D', 424], ['D', 441], ['D', 361], ['D', 255], ['D', 309], ['D', 228], ['D', 199], ['D', 130]]
# ['D', 441]
# ['D', 361]
# ['D', 255]
# ['D', 309]
# ['D', 228]
# ['D', 199]
# ['D', 130]
# [['D', 413], ['D', 171], ['D', 498], ['D', 495], ['D', 336], ['D', 175]]
# ['D', 171]
# ['D', 498]
# ['D', 495]
# ['D', 336]
# ['D', 175]
# [['D', 416], ['D', 214], ['D', 482]]
# ['D', 214]
# ['D', 482]
# [['D', 395], ['D', 417], ['D', 260]]
# ['D', 417]
# ['D', 260]
# [['D', 304], ['D', 395], ['D', 460]]
# ['D', 395]
# ['D', 460]
# [['D', 495], ['D', 475], ['D', 501], ['D', 364], ['D', 421], ['D', 453]]
# ['D', 475]
# ['D', 501]
# ['D', 364]
# ['D', 421]
# ['D', 453]
# [['D', 305], ['D', 329], ['D', 278], ['D', 205], ['D', 320], ['D', 407], ['D', 190], ['D', 262]]
# ['D', 329]
# ['D', 278]
# ['D', 205]
# ['D', 320]
# ['D', 407]
# ['D', 190]
# ['D', 262]
# [['D', 140], ['D', 407], ['D', 394], ['D', 255], ['D', 421], ['D', 332]]
# ['D', 407]
# ['D', 394]
# ['D', 255]
# ['D', 421]
# ['D', 332]
# [['D', 213], ['D', 309], ['D', 365], ['D', 333], ['D', 154], ['D', 331], ['D', 418]]
# ['D', 309]
# ['D', 365]
# ['D', 333]
# ['D', 154]
# ['D', 331]
# ['D', 418]
# [['D', 378], ['D', 303], ['D', 292], ['D', 149], ['D', 373]]
# ['D', 303]
# ['D', 292]
# ['D', 149]
# ['D', 373]
# [['D', 232], ['D', 477], ['D', 443], ['D', 470], ['D', 215], ['D', 324]]
# ['D', 477]
# ['D', 443]
# ['D', 470]
# ['D', 215]
# ['D', 324]
# [['D', 217], ['D', 255], ['D', 141]]
# ['D', 255]
# ['D', 141]
# [['D', 136], ['D', 322], ['D', 455], ['D', 419]]
# ['D', 322]
# ['D', 455]
# ['D', 419]
# [['D', 424], ['D', 478]]
# ['D', 478]
# [['D', 402], ['D', 298], ['D', 480], ['D', 204], ['D', 364], ['D', 287], ['D', 444], ['D', 312]]
# ['D', 298]
# ['D', 480]
# ['D', 204]
# ['D', 364]
# ['D', 287]
# ['D', 444]
# ['D', 312]
# [['D', 281], ['D', 206], ['D', 274], ['D', 283], ['D', 191], ['D', 281], ['D', 458], ['D', 312], ['D', 146], ['D', 309]]
# ['D', 206]
# ['D', 274]
# ['D', 283]
# ['D', 191]
# ['D', 281]
# ['D', 458]
# ['D', 312]
# ['D', 146]
# ['D', 309]
# [['D', 160], ['D', 481], ['D', 255], ['D', 323], ['D', 463]]
# ['D', 481]
# ['D', 255]
# ['D', 323]
# ['D', 463]
# [['D', 453], ['D', 296], ['D', 353]]
# ['D', 296]
# ['D', 353]
# [['D', 233], ['D', 376], ['D', 302], ['D', 196], ['D', 381]]
# ['D', 376]
# ['D', 302]
# ['D', 196]
# ['D', 381]
# [['D', 494], ['D', 481], ['D', 213], ['D', 492], ['D', 269]]
# ['D', 481]
# ['D', 213]
# ['D', 492]
# ['D', 269]
# [['D', 464], ['D', 241], ['D', 237], ['D', 316], ['D', 451], ['D', 298]]
# ['D', 241]
# ['D', 237]
# ['D', 316]
# ['D', 451]
# ['D', 298]
# [['D', 369], ['D', 245], ['D', 295], ['D', 492], ['D', 353], ['D', 298], ['D', 131], ['D', 329], ['D', 380], ['D', 192]]
# ['D', 245]
# ['D', 295]
# ['D', 492]
# ['D', 353]
# ['D', 298]
# ['D', 131]
# ['D', 329]
# ['D', 380]
# ['D', 192]
# [['D', 133], ['D', 349], ['D', 384], ['D', 467], ['D', 360]]
# ['D', 349]
# ['D', 384]
# ['D', 467]
# ['D', 360]
# [['D', 156], ['D', 358], ['D', 191], ['D', 427], ['D', 149], ['D', 300]]
# ['D', 358]
# ['D', 191]
# ['D', 427]
# ['D', 149]
# ['D', 300]
# [['D', 203], ['D', 380]]
# ['D', 380]
# [['D', 195], ['D', 290], ['D', 343], ['D', 291]]
# ['D', 290]
# ['D', 343]
# ['D', 291]
# [['D', 210], ['D', 366], ['D', 211], ['D', 237]]
# ['D', 366]
# ['D', 211]
# ['D', 237]
# [['D', 390], ['D', 243]]
# ['D', 243]
# [['D', 347], ['D', 417]]
# ['D', 417]
# [['D', 389], ['D', 224], ['D', 183], ['D', 252], ['D', 249], ['D', 386], ['D', 152], ['D', 202]]
# ['D', 224]
# ['D', 183]
# ['D', 252]
# ['D', 249]
# ['D', 386]
# ['D', 152]
# ['D', 202]
# [['D', 266], ['D', 174], ['D', 232], ['D', 395], ['D', 484], ['D', 458], ['D', 480], ['D', 391], ['D', 511]]
# ['D', 174]
# ['D', 232]
# ['D', 395]
# ['D', 484]
# ['D', 458]
# ['D', 480]
# ['D', 391]
# ['D', 511]
# [['D', 397], ['D', 364], ['D', 263], ['D', 361]]
# ['D', 364]
# ['D', 263]
# ['D', 361]
# [['D', 302], ['D', 211], ['D', 490], ['D', 183], ['D', 507], ['D', 486], ['D', 168]]
# ['D', 211]
# ['D', 490]
# ['D', 183]
# ['D', 507]
# ['D', 486]
# ['D', 168]
# [['D', 156], ['D', 349], ['D', 368], ['D', 443], ['D', 431], ['D', 206], ['D', 357], ['D', 353], ['D', 141]]
# ['D', 349]
# ['D', 368]
# ['D', 443]
# ['D', 431]
# ['D', 206]
# ['D', 357]
# ['D', 353]
# ['D', 141]
# [['D', 177], ['D', 293], ['D', 502]]
# ['D', 293]
# ['D', 502]
# [['D', 325], ['D', 174], ['D', 347], ['D', 345], ['D', 384]]
# ['D', 174]
# ['D', 347]
# ['D', 345]
# ['D', 384]
# [['D', 326], ['D', 286], ['D', 257], ['D', 181], ['D', 260], ['D', 376], ['D', 157]]
# ['D', 286]
# ['D', 257]
# ['D', 181]
# ['D', 260]
# ['D', 376]
# ['D', 157]
# [['D', 400], ['D', 457], ['D', 214], ['D', 455]]
# ['D', 457]
# ['D', 214]
# ['D', 455]
# [['D', 269], ['D', 137], ['D', 214], ['D', 326], ['D', 331], ['D', 185], ['D', 135]]
# ['D', 137]
# ['D', 214]
# ['D', 326]
# ['D', 331]
# ['D', 185]
# ['D', 135]
# [['D', 359], ['D', 369], ['D', 447], ['D', 232], ['D', 278], ['D', 237]]
# ['D', 369]
# ['D', 447]
# ['D', 232]
# ['D', 278]
# ['D', 237]
# [['D', 240], ['D', 351], ['D', 333], ['D', 489], ['D', 157], ['D', 130]]
# ['D', 351]
# ['D', 333]
# ['D', 489]
# ['D', 157]
# ['D', 130]
# [['D', 247], ['D', 372], ['D', 240], ['D', 288], ['D', 334], ['D', 506], ['D', 165], ['D', 325], ['D', 243]]
# ['D', 372]
# ['D', 240]
# ['D', 288]
# ['D', 334]
# ['D', 506]
# ['D', 165]
# ['D', 325]
# ['D', 243]
# [['D', 290], ['D', 263]]
# ['D', 263]
# [['D', 428], ['D', 393]]
# ['D', 393]
# Individual #0: {'genome': [['D', 323], ['D', 268], ['D', 411], ['D', 379], ['D', 155], ['D', 254]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=323, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=323, out_features=268, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=268, out_features=411, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=411, out_features=379, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=379, out_features=155, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=155, out_features=254, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=254, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}
# Individual #1: {'genome': [['D', 463], ['D', 248], ['D', 379], ['D', 330], ['D', 466], ['D', 191], ['D', 354], ['D', 480]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=463, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=463, out_features=248, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=248, out_features=379, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=379, out_features=330, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=330, out_features=466, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=466, out_features=191, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=191, out_features=354, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=354, out_features=480, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=480, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}
# Individual #2: {'genome': [['D', 492], ['D', 259], ['D', 437], ['D', 256], ['D', 379], ['D', 383], ['D', 251], ['D', 176], ['D', 395]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=492, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=492, out_features=259, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=259, out_features=437, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=437, out_features=256, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=256, out_features=379, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=379, out_features=383, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=383, out_features=251, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=251, out_features=176, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=176, out_features=395, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=395, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}
# Individual #3: {'genome': [['D', 497], ['D', 387], ['D', 232], ['D', 287], ['D', 429], ['D', 214], ['D', 472], ['D', 415]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=497, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=497, out_features=387, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=387, out_features=232, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=232, out_features=287, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=287, out_features=429, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=429, out_features=214, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=214, out_features=472, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=472, out_features=415, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=415, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}
# Individual #4: {'genome': [['D', 447], ['D', 460], ['D', 160], ['D', 292], ['D', 313], ['D', 214], ['D', 341]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=447, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=447, out_features=460, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=460, out_features=160, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=160, out_features=292, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=292, out_features=313, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=313, out_features=214, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=214, out_features=341, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=341, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}
# Individual #5: {'genome': [['D', 402], ['D', 375], ['D', 242]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=402, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=402, out_features=375, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=375, out_features=242, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=242, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}
# Individual #6: {'genome': [['D', 424], ['D', 441], ['D', 361], ['D', 255], ['D', 309], ['D', 228], ['D', 199], ['D', 130]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=424, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=424, out_features=441, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=441, out_features=361, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=361, out_features=255, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=255, out_features=309, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=309, out_features=228, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=228, out_features=199, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=199, out_features=130, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=130, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}
# Individual #7: {'genome': [['D', 413], ['D', 171], ['D', 498], ['D', 495], ['D', 336], ['D', 175]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=413, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=413, out_features=171, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=171, out_features=498, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=498, out_features=495, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=495, out_features=336, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=336, out_features=175, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=175, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}
# Individual #8: {'genome': [['D', 416], ['D', 214], ['D', 482]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=416, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=416, out_features=214, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=214, out_features=482, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=482, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}
# Individual #9: {'genome': [['D', 395], ['D', 417], ['D', 260]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=395, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=395, out_features=417, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=417, out_features=260, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=260, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}
# Individual #10: {'genome': [['D', 304], ['D', 395], ['D', 460]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=304, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=304, out_features=395, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=395, out_features=460, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=460, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}
# Individual #11: {'genome': [['D', 495], ['D', 475], ['D', 501], ['D', 364], ['D', 421], ['D', 453]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=495, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=495, out_features=475, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=475, out_features=501, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=501, out_features=364, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=364, out_features=421, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=421, out_features=453, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=453, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}
# Individual #12: {'genome': [['D', 305], ['D', 329], ['D', 278], ['D', 205], ['D', 320], ['D', 407], ['D', 190], ['D', 262]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=305, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=305, out_features=329, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=329, out_features=278, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=278, out_features=205, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=205, out_features=320, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=320, out_features=407, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=407, out_features=190, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=190, out_features=262, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=262, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}
# Individual #13: {'genome': [['D', 140], ['D', 407], ['D', 394], ['D', 255], ['D', 421], ['D', 332]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=140, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=140, out_features=407, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=407, out_features=394, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=394, out_features=255, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=255, out_features=421, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=421, out_features=332, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=332, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}
# Individual #14: {'genome': [['D', 213], ['D', 309], ['D', 365], ['D', 333], ['D', 154], ['D', 331], ['D', 418]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=213, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=213, out_features=309, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=309, out_features=365, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=365, out_features=333, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=333, out_features=154, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=154, out_features=331, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=331, out_features=418, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=418, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}
# Individual #15: {'genome': [['D', 378], ['D', 303], ['D', 292], ['D', 149], ['D', 373]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=378, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=378, out_features=303, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=303, out_features=292, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=292, out_features=149, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=149, out_features=373, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=373, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}
# Individual #16: {'genome': [['D', 232], ['D', 477], ['D', 443], ['D', 470], ['D', 215], ['D', 324]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=232, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=232, out_features=477, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=477, out_features=443, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=443, out_features=470, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=470, out_features=215, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=215, out_features=324, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=324, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}
# Individual #17: {'genome': [['D', 217], ['D', 255], ['D', 141]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=217, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=217, out_features=255, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=255, out_features=141, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=141, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}
# Individual #18: {'genome': [['D', 136], ['D', 322], ['D', 455], ['D', 419]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=136, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=136, out_features=322, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=322, out_features=455, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=455, out_features=419, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=419, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}
# Individual #19: {'genome': [['D', 424], ['D', 478]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=424, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=424, out_features=478, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=478, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}
# Individual #20: {'genome': [['D', 402], ['D', 298], ['D', 480], ['D', 204], ['D', 364], ['D', 287], ['D', 444], ['D', 312]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=402, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=402, out_features=298, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=298, out_features=480, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=480, out_features=204, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=204, out_features=364, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=364, out_features=287, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=287, out_features=444, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=444, out_features=312, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=312, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}
# Individual #21: {'genome': [['D', 281], ['D', 206], ['D', 274], ['D', 283], ['D', 191], ['D', 281], ['D', 458], ['D', 312], ['D', 146], ['D', 309]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=281, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=281, out_features=206, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=206, out_features=274, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=274, out_features=283, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=283, out_features=191, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=191, out_features=281, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=281, out_features=458, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=458, out_features=312, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=312, out_features=146, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=146, out_features=309, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=309, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# )}
# Individual #22: {'genome': [['D', 160], ['D', 481], ['D', 255], ['D', 323], ['D', 463]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=160, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=160, out_features=481, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=481, out_features=255, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=255, out_features=323, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=323, out_features=463, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=463, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}
# Individual #23: {'genome': [['D', 453], ['D', 296], ['D', 353]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=453, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=453, out_features=296, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=296, out_features=353, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=353, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}
# Individual #24: {'genome': [['D', 233], ['D', 376], ['D', 302], ['D', 196], ['D', 381]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=233, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=233, out_features=376, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=376, out_features=302, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=302, out_features=196, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=196, out_features=381, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=381, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}
# Individual #25: {'genome': [['D', 494], ['D', 481], ['D', 213], ['D', 492], ['D', 269]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=494, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=494, out_features=481, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=481, out_features=213, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=213, out_features=492, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=492, out_features=269, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=269, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}
# Individual #26: {'genome': [['D', 464], ['D', 241], ['D', 237], ['D', 316], ['D', 451], ['D', 298]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=464, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=464, out_features=241, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=241, out_features=237, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=237, out_features=316, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=316, out_features=451, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=451, out_features=298, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=298, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}
# Individual #27: {'genome': [['D', 369], ['D', 245], ['D', 295], ['D', 492], ['D', 353], ['D', 298], ['D', 131], ['D', 329], ['D', 380], ['D', 192]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=369, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=369, out_features=245, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=245, out_features=295, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=295, out_features=492, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=492, out_features=353, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=353, out_features=298, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=298, out_features=131, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=131, out_features=329, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=329, out_features=380, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=380, out_features=192, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=192, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# )}
# Individual #28: {'genome': [['D', 133], ['D', 349], ['D', 384], ['D', 467], ['D', 360]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=133, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=133, out_features=349, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=349, out_features=384, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=384, out_features=467, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=467, out_features=360, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=360, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}
# Individual #29: {'genome': [['D', 156], ['D', 358], ['D', 191], ['D', 427], ['D', 149], ['D', 300]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=156, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=156, out_features=358, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=358, out_features=191, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=191, out_features=427, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=427, out_features=149, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=149, out_features=300, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=300, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}
# Individual #30: {'genome': [['D', 203], ['D', 380]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=203, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=203, out_features=380, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=380, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}
# Individual #31: {'genome': [['D', 195], ['D', 290], ['D', 343], ['D', 291]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=195, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=195, out_features=290, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=290, out_features=343, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=343, out_features=291, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=291, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}
# Individual #32: {'genome': [['D', 210], ['D', 366], ['D', 211], ['D', 237]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=210, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=210, out_features=366, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=366, out_features=211, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=211, out_features=237, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=237, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}
# Individual #33: {'genome': [['D', 390], ['D', 243]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=390, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=390, out_features=243, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=243, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}
# Individual #34: {'genome': [['D', 347], ['D', 417]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=347, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=347, out_features=417, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=417, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}
# Individual #35: {'genome': [['D', 389], ['D', 224], ['D', 183], ['D', 252], ['D', 249], ['D', 386], ['D', 152], ['D', 202]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=389, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=389, out_features=224, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=224, out_features=183, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=183, out_features=252, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=252, out_features=249, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=249, out_features=386, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=386, out_features=152, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=152, out_features=202, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=202, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}
# Individual #36: {'genome': [['D', 266], ['D', 174], ['D', 232], ['D', 395], ['D', 484], ['D', 458], ['D', 480], ['D', 391], ['D', 511]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=266, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=266, out_features=174, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=174, out_features=232, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=232, out_features=395, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=395, out_features=484, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=484, out_features=458, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=458, out_features=480, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=480, out_features=391, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=391, out_features=511, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=511, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}
# Individual #37: {'genome': [['D', 397], ['D', 364], ['D', 263], ['D', 361]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=397, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=397, out_features=364, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=364, out_features=263, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=263, out_features=361, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=361, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}
# Individual #38: {'genome': [['D', 302], ['D', 211], ['D', 490], ['D', 183], ['D', 507], ['D', 486], ['D', 168]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=302, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=302, out_features=211, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=211, out_features=490, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=490, out_features=183, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=183, out_features=507, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=507, out_features=486, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=486, out_features=168, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=168, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}
# Individual #39: {'genome': [['D', 156], ['D', 349], ['D', 368], ['D', 443], ['D', 431], ['D', 206], ['D', 357], ['D', 353], ['D', 141]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=156, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=156, out_features=349, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=349, out_features=368, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=368, out_features=443, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=443, out_features=431, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=431, out_features=206, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=206, out_features=357, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=357, out_features=353, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=353, out_features=141, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=141, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}
# Individual #40: {'genome': [['D', 177], ['D', 293], ['D', 502]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=177, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=177, out_features=293, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=293, out_features=502, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=502, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}
# Individual #41: {'genome': [['D', 325], ['D', 174], ['D', 347], ['D', 345], ['D', 384]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=325, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=325, out_features=174, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=174, out_features=347, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=347, out_features=345, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=345, out_features=384, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=384, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}
# Individual #42: {'genome': [['D', 326], ['D', 286], ['D', 257], ['D', 181], ['D', 260], ['D', 376], ['D', 157]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=326, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=326, out_features=286, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=286, out_features=257, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=257, out_features=181, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=181, out_features=260, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=260, out_features=376, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=376, out_features=157, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=157, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}
# Individual #43: {'genome': [['D', 400], ['D', 457], ['D', 214], ['D', 455]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=400, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=400, out_features=457, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=457, out_features=214, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=214, out_features=455, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=455, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}
# Individual #44: {'genome': [['D', 269], ['D', 137], ['D', 214], ['D', 326], ['D', 331], ['D', 185], ['D', 135]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=269, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=269, out_features=137, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=137, out_features=214, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=214, out_features=326, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=326, out_features=331, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=331, out_features=185, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=185, out_features=135, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=135, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}
# Individual #45: {'genome': [['D', 359], ['D', 369], ['D', 447], ['D', 232], ['D', 278], ['D', 237]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=359, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=359, out_features=369, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=369, out_features=447, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=447, out_features=232, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=232, out_features=278, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=278, out_features=237, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=237, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}
# Individual #46: {'genome': [['D', 240], ['D', 351], ['D', 333], ['D', 489], ['D', 157], ['D', 130]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=240, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=240, out_features=351, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=351, out_features=333, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=333, out_features=489, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=489, out_features=157, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=157, out_features=130, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=130, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}
# Individual #47: {'genome': [['D', 247], ['D', 372], ['D', 240], ['D', 288], ['D', 334], ['D', 506], ['D', 165], ['D', 325], ['D', 243]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=247, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=247, out_features=372, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=372, out_features=240, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=240, out_features=288, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=288, out_features=334, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=334, out_features=506, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=506, out_features=165, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=165, out_features=325, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=325, out_features=243, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=243, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}
# Individual #48: {'genome': [['D', 290], ['D', 263]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=290, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=290, out_features=263, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=263, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}
# Individual #49: {'genome': [['D', 428], ['D', 393]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=428, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=428, out_features=393, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=393, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}

# %%
generation.train_population()
# Out:
# [{'genome': [['D', 323], ['D', 268], ['D', 411], ['D', 379], ['D', 155], ['D', 254]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=323, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=323, out_features=268, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=268, out_features=411, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=411, out_features=379, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=379, out_features=155, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=155, out_features=254, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=254, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 463], ['D', 248], ['D', 379], ['D', 330], ['D', 466], ['D', 191], ['D', 354], ['D', 480]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=463, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=463, out_features=248, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=248, out_features=379, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=379, out_features=330, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=330, out_features=466, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=466, out_features=191, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=191, out_features=354, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=354, out_features=480, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=480, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 492], ['D', 259], ['D', 437], ['D', 256], ['D', 379], ['D', 383], ['D', 251], ['D', 176], ['D', 395]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=492, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=492, out_features=259, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=259, out_features=437, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=437, out_features=256, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=256, out_features=379, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=379, out_features=383, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=383, out_features=251, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=251, out_features=176, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=176, out_features=395, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=395, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 497], ['D', 387], ['D', 232], ['D', 287], ['D', 429], ['D', 214], ['D', 472], ['D', 415]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=497, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=497, out_features=387, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=387, out_features=232, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=232, out_features=287, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=287, out_features=429, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=429, out_features=214, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=214, out_features=472, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=472, out_features=415, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=415, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 447], ['D', 460], ['D', 160], ['D', 292], ['D', 313], ['D', 214], ['D', 341]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=447, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=447, out_features=460, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=460, out_features=160, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=160, out_features=292, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=292, out_features=313, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=313, out_features=214, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=214, out_features=341, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=341, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 402], ['D', 375], ['D', 242]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=402, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=402, out_features=375, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=375, out_features=242, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=242, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 424], ['D', 441], ['D', 361], ['D', 255], ['D', 309], ['D', 228], ['D', 199], ['D', 130]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=424, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=424, out_features=441, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=441, out_features=361, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=361, out_features=255, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=255, out_features=309, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=309, out_features=228, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=228, out_features=199, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=199, out_features=130, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=130, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 413], ['D', 171], ['D', 498], ['D', 495], ['D', 336], ['D', 175]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=413, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=413, out_features=171, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=171, out_features=498, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=498, out_features=495, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=495, out_features=336, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=336, out_features=175, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=175, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 416], ['D', 214], ['D', 482]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=416, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=416, out_features=214, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=214, out_features=482, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=482, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 395], ['D', 417], ['D', 260]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=395, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=395, out_features=417, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=417, out_features=260, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=260, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 304], ['D', 395], ['D', 460]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=304, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=304, out_features=395, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=395, out_features=460, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=460, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 495], ['D', 475], ['D', 501], ['D', 364], ['D', 421], ['D', 453]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=495, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=495, out_features=475, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=475, out_features=501, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=501, out_features=364, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=364, out_features=421, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=421, out_features=453, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=453, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 305], ['D', 329], ['D', 278], ['D', 205], ['D', 320], ['D', 407], ['D', 190], ['D', 262]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=305, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=305, out_features=329, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=329, out_features=278, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=278, out_features=205, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=205, out_features=320, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=320, out_features=407, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=407, out_features=190, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=190, out_features=262, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=262, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 140], ['D', 407], ['D', 394], ['D', 255], ['D', 421], ['D', 332]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=140, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=140, out_features=407, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=407, out_features=394, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=394, out_features=255, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=255, out_features=421, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=421, out_features=332, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=332, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 213], ['D', 309], ['D', 365], ['D', 333], ['D', 154], ['D', 331], ['D', 418]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=213, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=213, out_features=309, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=309, out_features=365, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=365, out_features=333, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=333, out_features=154, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=154, out_features=331, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=331, out_features=418, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=418, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 378], ['D', 303], ['D', 292], ['D', 149], ['D', 373]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=378, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=378, out_features=303, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=303, out_features=292, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=292, out_features=149, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=149, out_features=373, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=373, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 232], ['D', 477], ['D', 443], ['D', 470], ['D', 215], ['D', 324]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=232, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=232, out_features=477, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=477, out_features=443, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=443, out_features=470, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=470, out_features=215, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=215, out_features=324, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=324, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 217], ['D', 255], ['D', 141]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=217, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=217, out_features=255, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=255, out_features=141, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=141, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 136], ['D', 322], ['D', 455], ['D', 419]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=136, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=136, out_features=322, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=322, out_features=455, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=455, out_features=419, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=419, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 424], ['D', 478]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=424, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=424, out_features=478, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=478, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 402], ['D', 298], ['D', 480], ['D', 204], ['D', 364], ['D', 287], ['D', 444], ['D', 312]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=402, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=402, out_features=298, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=298, out_features=480, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=480, out_features=204, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=204, out_features=364, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=364, out_features=287, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=287, out_features=444, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=444, out_features=312, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=312, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 281], ['D', 206], ['D', 274], ['D', 283], ['D', 191], ['D', 281], ['D', 458], ['D', 312], ['D', 146], ['D', 309]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=281, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=281, out_features=206, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=206, out_features=274, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=274, out_features=283, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=283, out_features=191, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=191, out_features=281, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=281, out_features=458, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=458, out_features=312, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=312, out_features=146, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=146, out_features=309, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=309, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 160], ['D', 481], ['D', 255], ['D', 323], ['D', 463]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=160, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=160, out_features=481, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=481, out_features=255, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=255, out_features=323, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=323, out_features=463, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=463, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 453], ['D', 296], ['D', 353]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=453, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=453, out_features=296, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=296, out_features=353, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=353, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 233], ['D', 376], ['D', 302], ['D', 196], ['D', 381]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=233, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=233, out_features=376, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=376, out_features=302, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=302, out_features=196, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=196, out_features=381, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=381, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 494], ['D', 481], ['D', 213], ['D', 492], ['D', 269]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=494, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=494, out_features=481, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=481, out_features=213, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=213, out_features=492, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=492, out_features=269, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=269, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 464], ['D', 241], ['D', 237], ['D', 316], ['D', 451], ['D', 298]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=464, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=464, out_features=241, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=241, out_features=237, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=237, out_features=316, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=316, out_features=451, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=451, out_features=298, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=298, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 369], ['D', 245], ['D', 295], ['D', 492], ['D', 353], ['D', 298], ['D', 131], ['D', 329], ['D', 380], ['D', 192]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=369, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=369, out_features=245, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=245, out_features=295, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=295, out_features=492, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=492, out_features=353, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=353, out_features=298, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=298, out_features=131, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=131, out_features=329, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=329, out_features=380, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=380, out_features=192, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=192, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 133], ['D', 349], ['D', 384], ['D', 467], ['D', 360]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=133, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=133, out_features=349, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=349, out_features=384, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=384, out_features=467, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=467, out_features=360, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=360, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 156], ['D', 358], ['D', 191], ['D', 427], ['D', 149], ['D', 300]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=156, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=156, out_features=358, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=358, out_features=191, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=191, out_features=427, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=427, out_features=149, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=149, out_features=300, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=300, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 203], ['D', 380]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=203, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=203, out_features=380, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=380, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 195], ['D', 290], ['D', 343], ['D', 291]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=195, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=195, out_features=290, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=290, out_features=343, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=343, out_features=291, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=291, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 210], ['D', 366], ['D', 211], ['D', 237]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=210, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=210, out_features=366, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=366, out_features=211, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=211, out_features=237, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=237, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 390], ['D', 243]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=390, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=390, out_features=243, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=243, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 347], ['D', 417]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=347, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=347, out_features=417, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=417, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 389], ['D', 224], ['D', 183], ['D', 252], ['D', 249], ['D', 386], ['D', 152], ['D', 202]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=389, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=389, out_features=224, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=224, out_features=183, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=183, out_features=252, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=252, out_features=249, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=249, out_features=386, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=386, out_features=152, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=152, out_features=202, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=202, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 266], ['D', 174], ['D', 232], ['D', 395], ['D', 484], ['D', 458], ['D', 480], ['D', 391], ['D', 511]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=266, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=266, out_features=174, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=174, out_features=232, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=232, out_features=395, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=395, out_features=484, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=484, out_features=458, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=458, out_features=480, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=480, out_features=391, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=391, out_features=511, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=511, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 397], ['D', 364], ['D', 263], ['D', 361]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=397, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=397, out_features=364, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=364, out_features=263, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=263, out_features=361, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=361, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 302], ['D', 211], ['D', 490], ['D', 183], ['D', 507], ['D', 486], ['D', 168]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=302, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=302, out_features=211, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=211, out_features=490, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=490, out_features=183, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=183, out_features=507, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=507, out_features=486, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=486, out_features=168, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=168, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 156], ['D', 349], ['D', 368], ['D', 443], ['D', 431], ['D', 206], ['D', 357], ['D', 353], ['D', 141]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=156, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=156, out_features=349, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=349, out_features=368, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=368, out_features=443, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=443, out_features=431, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=431, out_features=206, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=206, out_features=357, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=357, out_features=353, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=353, out_features=141, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=141, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 177], ['D', 293], ['D', 502]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=177, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=177, out_features=293, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=293, out_features=502, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=502, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 325], ['D', 174], ['D', 347], ['D', 345], ['D', 384]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=325, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=325, out_features=174, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=174, out_features=347, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=347, out_features=345, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=345, out_features=384, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=384, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 326], ['D', 286], ['D', 257], ['D', 181], ['D', 260], ['D', 376], ['D', 157]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=326, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=326, out_features=286, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=286, out_features=257, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=257, out_features=181, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=181, out_features=260, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=260, out_features=376, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=376, out_features=157, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=157, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 400], ['D', 457], ['D', 214], ['D', 455]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=400, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=400, out_features=457, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=457, out_features=214, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=214, out_features=455, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=455, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 269], ['D', 137], ['D', 214], ['D', 326], ['D', 331], ['D', 185], ['D', 135]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=269, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=269, out_features=137, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=137, out_features=214, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=214, out_features=326, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=326, out_features=331, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=331, out_features=185, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=185, out_features=135, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=135, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 359], ['D', 369], ['D', 447], ['D', 232], ['D', 278], ['D', 237]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=359, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=359, out_features=369, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=369, out_features=447, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=447, out_features=232, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=232, out_features=278, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=278, out_features=237, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=237, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 240], ['D', 351], ['D', 333], ['D', 489], ['D', 157], ['D', 130]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=240, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=240, out_features=351, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=351, out_features=333, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=333, out_features=489, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=489, out_features=157, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=157, out_features=130, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=130, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 247], ['D', 372], ['D', 240], ['D', 288], ['D', 334], ['D', 506], ['D', 165], ['D', 325], ['D', 243]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=247, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=247, out_features=372, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=372, out_features=240, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=240, out_features=288, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=288, out_features=334, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=334, out_features=506, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=506, out_features=165, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=165, out_features=325, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=325, out_features=243, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=243, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 290], ['D', 263]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=290, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=290, out_features=263, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=263, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 428], ['D', 393]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=428, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=428, out_features=393, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=393, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}]
# Training individual #0
# Training individual #1
# Training individual #2
# Training individual #3
# Training individual #4
# Training individual #5
# Training individual #6
# Training individual #7
# Training individual #8
# Training individual #9
# Training individual #10
# Training individual #11
# Training individual #12
# Training individual #13
# Training individual #14
# Training individual #15
# Training individual #16
# Training individual #17
# Training individual #18
# Training individual #19
# Training individual #20
# Training individual #21
# Training individual #22
# Training individual #23
# Training individual #24
# Training individual #25
# Training individual #26
# Training individual #27
# Training individual #28
# Training individual #29
# Training individual #30
# Training individual #31
# Training individual #32
# Training individual #33
# Training individual #34
# Training individual #35
# Training individual #36
# Training individual #37
# Training individual #38
# Training individual #39
# Training individual #40
# Training individual #41
# Training individual #42
# Training individual #43
# Training individual #44
# Training individual #45
# Training individual #46
# Training individual #47
# Training individual #48
# Training individual #49

# %%
generation.evaluate_population()
# Out:
# Evaluating individual #0
# Evaluating individual #1
# Evaluating individual #2
# Evaluating individual #3
# Evaluating individual #4
# Evaluating individual #5
# Evaluating individual #6
# Evaluating individual #7
# Evaluating individual #8
# Evaluating individual #9
# Evaluating individual #10
# Evaluating individual #11
# Evaluating individual #12
# Evaluating individual #13
# Evaluating individual #14
# Evaluating individual #15
# Evaluating individual #16
# Evaluating individual #17
# Evaluating individual #18
# Evaluating individual #19
# Evaluating individual #20
# Evaluating individual #21
# Evaluating individual #22
# Evaluating individual #23
# Evaluating individual #24
# Evaluating individual #25
# Evaluating individual #26
# Evaluating individual #27
# Evaluating individual #28
# Evaluating individual #29
# Evaluating individual #30
# Evaluating individual #31
# Evaluating individual #32
# Evaluating individual #33
# Evaluating individual #34
# Evaluating individual #35
# Evaluating individual #36
# Evaluating individual #37
# Evaluating individual #38
# Evaluating individual #39
# Evaluating individual #40
# Evaluating individual #41
# Evaluating individual #42
# Evaluating individual #43
# Evaluating individual #44
# Evaluating individual #45
# Evaluating individual #46
# Evaluating individual #47
# Evaluating individual #48
# Evaluating individual #49

# %%
generation.print_population()
# Out:
# Individual #0: {'genome': [['D', 323], ['D', 268], ['D', 411], ['D', 379], ['D', 155], ['D', 254]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=323, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=323, out_features=268, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=268, out_features=411, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=411, out_features=379, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=379, out_features=155, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=155, out_features=254, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=254, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# ), 'id': 0, 'loss': 0.07981854518254598, 'accuracy': 0.3333333333333333, 'parameters': 454443}
# Individual #1: {'genome': [['D', 463], ['D', 248], ['D', 379], ['D', 330], ['D', 466], ['D', 191], ['D', 354], ['D', 480]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=463, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=463, out_features=248, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=248, out_features=379, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=379, out_features=330, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=330, out_features=466, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=466, out_features=191, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=191, out_features=354, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=354, out_features=480, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=480, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 1, 'loss': 0.08051297187805176, 'accuracy': 0.3333333333333333, 'parameters': 820412}
# Individual #2: {'genome': [['D', 492], ['D', 259], ['D', 437], ['D', 256], ['D', 379], ['D', 383], ['D', 251], ['D', 176], ['D', 395]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=492, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=492, out_features=259, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=259, out_features=437, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=437, out_features=256, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=256, out_features=379, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=379, out_features=383, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=383, out_features=251, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=251, out_features=176, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=176, out_features=395, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=395, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 2, 'loss': 0.0812074327468872, 'accuracy': 0.3333333333333333, 'parameters': 810677}
# Individual #3: {'genome': [['D', 497], ['D', 387], ['D', 232], ['D', 287], ['D', 429], ['D', 214], ['D', 472], ['D', 415]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=497, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=497, out_features=387, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=387, out_features=232, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=232, out_features=287, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=287, out_features=429, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=429, out_features=214, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=214, out_features=472, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=472, out_features=415, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=415, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 3, 'loss': 0.0805129861831665, 'accuracy': 0.3333333333333333, 'parameters': 866693}
# Individual #4: {'genome': [['D', 447], ['D', 460], ['D', 160], ['D', 292], ['D', 313], ['D', 214], ['D', 341]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=447, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=447, out_features=460, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=460, out_features=160, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=160, out_features=292, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=292, out_features=313, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=313, out_features=214, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=214, out_features=341, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=341, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# ), 'id': 4, 'loss': 0.0805129853884379, 'accuracy': 0.3333333333333333, 'parameters': 562333}
# Individual #5: {'genome': [['D', 402], ['D', 375], ['D', 242]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=402, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=402, out_features=375, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=375, out_features=242, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=242, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# ), 'id': 5, 'loss': 0.047060981194178265, 'accuracy': 0.84, 'parameters': 244856}
# Individual #6: {'genome': [['D', 424], ['D', 441], ['D', 361], ['D', 255], ['D', 309], ['D', 228], ['D', 199], ['D', 130]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=424, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=424, out_features=441, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=441, out_features=361, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=361, out_features=255, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=255, out_features=309, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=309, out_features=228, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=228, out_features=199, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=199, out_features=130, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=130, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 6, 'loss': 0.06218178908030192, 'accuracy': 0.6666666666666666, 'parameters': 663165}
# Individual #7: {'genome': [['D', 413], ['D', 171], ['D', 498], ['D', 495], ['D', 336], ['D', 175]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=413, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=413, out_features=171, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=171, out_features=498, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=498, out_features=495, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=495, out_features=336, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=336, out_features=175, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=175, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# ), 'id': 7, 'loss': 0.05829076409339905, 'accuracy': 0.6666666666666666, 'parameters': 631679}
# Individual #8: {'genome': [['D', 416], ['D', 214], ['D', 482]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=416, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=416, out_features=214, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=214, out_features=482, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=482, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# ), 'id': 8, 'loss': 0.05898599068323771, 'accuracy': 0.6666666666666666, 'parameters': 196397}
# Individual #9: {'genome': [['D', 395], ['D', 417], ['D', 260]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=395, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=395, out_features=417, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=417, out_features=260, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=260, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# ), 'id': 9, 'loss': 0.05828582485516866, 'accuracy': 0.6666666666666666, 'parameters': 276570}
# Individual #10: {'genome': [['D', 304], ['D', 395], ['D', 460]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=304, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=304, out_features=395, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=395, out_features=460, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=460, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# ), 'id': 10, 'loss': 0.050968201955159505, 'accuracy': 0.74, 'parameters': 305538}
# Individual #11: {'genome': [['D', 495], ['D', 475], ['D', 501], ['D', 364], ['D', 421], ['D', 453]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=495, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=495, out_features=475, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=475, out_features=501, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=501, out_features=364, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=364, out_features=421, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=421, out_features=453, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=453, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# ), 'id': 11, 'loss': 0.0798185416062673, 'accuracy': 0.3333333333333333, 'parameters': 1005472}
# Individual #12: {'genome': [['D', 305], ['D', 329], ['D', 278], ['D', 205], ['D', 320], ['D', 407], ['D', 190], ['D', 262]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=305, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=305, out_features=329, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=329, out_features=278, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=278, out_features=205, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=205, out_features=320, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=320, out_features=407, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=407, out_features=190, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=190, out_features=262, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=262, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 12, 'loss': 0.06319292585055034, 'accuracy': 0.6666666666666666, 'parameters': 576052}
# Individual #13: {'genome': [['D', 140], ['D', 407], ['D', 394], ['D', 255], ['D', 421], ['D', 332]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=140, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=140, out_features=407, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=407, out_features=394, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=394, out_features=255, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=255, out_features=421, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=421, out_features=332, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=332, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# ), 'id': 13, 'loss': 0.08120743076006572, 'accuracy': 0.3333333333333333, 'parameters': 568443}
# Individual #14: {'genome': [['D', 213], ['D', 309], ['D', 365], ['D', 333], ['D', 154], ['D', 331], ['D', 418]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=213, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=213, out_features=309, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=309, out_features=365, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=365, out_features=333, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=333, out_features=154, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=154, out_features=331, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=331, out_features=418, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=418, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# ), 'id': 14, 'loss': 0.07259983936945598, 'accuracy': 0.3333333333333333, 'parameters': 544993}
# Individual #15: {'genome': [['D', 378], ['D', 303], ['D', 292], ['D', 149], ['D', 373]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=378, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=378, out_features=303, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=303, out_features=292, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=292, out_features=149, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=149, out_features=373, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=373, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# ), 'id': 15, 'loss': 0.08393890301386515, 'accuracy': 0.3333333333333333, 'parameters': 306224}
# Individual #16: {'genome': [['D', 232], ['D', 477], ['D', 443], ['D', 470], ['D', 215], ['D', 324]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=232, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=232, out_features=477, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=477, out_features=443, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=443, out_features=470, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=470, out_features=215, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=215, out_features=324, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=324, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# ), 'id': 16, 'loss': 0.06525281151135763, 'accuracy': 0.6666666666666666, 'parameters': 704959}
# Individual #17: {'genome': [['D', 217], ['D', 255], ['D', 141]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=217, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=217, out_features=255, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=255, out_features=141, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=141, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# ), 'id': 17, 'loss': 0.046621350844701134, 'accuracy': 0.92, 'parameters': 93197}
# Individual #18: {'genome': [['D', 136], ['D', 322], ['D', 455], ['D', 419]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=136, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=136, out_features=322, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=322, out_features=455, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=455, out_features=419, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=419, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# ), 'id': 18, 'loss': 0.05831665555636088, 'accuracy': 0.6666666666666666, 'parameters': 384083}
# Individual #19: {'genome': [['D', 424], ['D', 478]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=424, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=424, out_features=478, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=478, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 19, 'loss': 0.055728761355082194, 'accuracy': 0.6866666666666666, 'parameters': 206707}
# Individual #20: {'genome': [['D', 402], ['D', 298], ['D', 480], ['D', 204], ['D', 364], ['D', 287], ['D', 444], ['D', 312]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=402, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=402, out_features=298, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=298, out_features=480, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=480, out_features=204, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=204, out_features=364, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=364, out_features=287, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=287, out_features=444, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=444, out_features=312, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=312, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 20, 'loss': 0.07312728325525919, 'accuracy': 0.6333333333333333, 'parameters': 810774}
# Individual #21: {'genome': [['D', 281], ['D', 206], ['D', 274], ['D', 283], ['D', 191], ['D', 281], ['D', 458], ['D', 312], ['D', 146], ['D', 309]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=281, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=281, out_features=206, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=206, out_features=274, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=274, out_features=283, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=283, out_features=191, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=191, out_features=281, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=281, out_features=458, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=458, out_features=312, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=312, out_features=146, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=146, out_features=309, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=309, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# ), 'id': 21, 'loss': 0.0732594617207845, 'accuracy': 0.3333333333333333, 'parameters': 666651}
# Individual #22: {'genome': [['D', 160], ['D', 481], ['D', 255], ['D', 323], ['D', 463]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=160, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=160, out_features=481, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=481, out_features=255, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=255, out_features=323, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=323, out_features=463, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=463, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# ), 'id': 22, 'loss': 0.058875271876653035, 'accuracy': 0.6666666666666666, 'parameters': 435243}
# Individual #23: {'genome': [['D', 453], ['D', 296], ['D', 353]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=453, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=453, out_features=296, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=296, out_features=353, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=353, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# ), 'id': 23, 'loss': 0.043923869530359906, 'accuracy': 0.9266666666666666, 'parameters': 242552}
# Individual #24: {'genome': [['D', 233], ['D', 376], ['D', 302], ['D', 196], ['D', 381]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=233, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=233, out_features=376, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=376, out_features=302, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=302, out_features=196, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=196, out_features=381, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=381, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# ), 'id': 24, 'loss': 0.05378091017405192, 'accuracy': 0.7, 'parameters': 338594}
# Individual #25: {'genome': [['D', 494], ['D', 481], ['D', 213], ['D', 492], ['D', 269]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=494, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=494, out_features=481, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=481, out_features=213, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=213, out_features=492, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=492, out_features=269, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=269, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# ), 'id': 25, 'loss': 0.05435436288515727, 'accuracy': 0.6666666666666666, 'parameters': 581946}
# Individual #26: {'genome': [['D', 464], ['D', 241], ['D', 237], ['D', 316], ['D', 451], ['D', 298]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=464, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=464, out_features=241, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=241, out_features=237, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=237, out_features=316, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=316, out_features=451, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=451, out_features=298, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=298, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# ), 'id': 26, 'loss': 0.05590590000152588, 'accuracy': 0.6666666666666666, 'parameters': 525507}
# Individual #27: {'genome': [['D', 369], ['D', 245], ['D', 295], ['D', 492], ['D', 353], ['D', 298], ['D', 131], ['D', 329], ['D', 380], ['D', 192]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=369, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=369, out_features=245, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=245, out_features=295, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=295, out_features=492, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=492, out_features=353, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=353, out_features=298, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=298, out_features=131, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=131, out_features=329, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=329, out_features=380, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=380, out_features=192, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=192, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# ), 'id': 27, 'loss': 0.07184271415074667, 'accuracy': 0.3333333333333333, 'parameters': 871946}
# Individual #28: {'genome': [['D', 133], ['D', 349], ['D', 384], ['D', 467], ['D', 360]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=133, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=133, out_features=349, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=349, out_features=384, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=384, out_features=467, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=467, out_features=360, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=360, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# ), 'id': 28, 'loss': 0.056712069511413575, 'accuracy': 0.6666666666666666, 'parameters': 531189}
# Individual #29: {'genome': [['D', 156], ['D', 358], ['D', 191], ['D', 427], ['D', 149], ['D', 300]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=156, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=156, out_features=358, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=358, out_features=191, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=191, out_features=427, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=427, out_features=149, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=149, out_features=300, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=300, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# ), 'id': 29, 'loss': 0.05907407522201538, 'accuracy': 0.6666666666666666, 'parameters': 317214}
# Individual #30: {'genome': [['D', 203], ['D', 380]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=203, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=203, out_features=380, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=380, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 30, 'loss': 0.04858899394671122, 'accuracy': 0.8066666666666666, 'parameters': 79678}
# Individual #31: {'genome': [['D', 195], ['D', 290], ['D', 343], ['D', 291]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=195, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=195, out_features=290, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=290, out_features=343, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=343, out_features=291, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=291, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# ), 'id': 31, 'loss': 0.051563453674316403, 'accuracy': 0.6933333333333334, 'parameters': 258608}
# Individual #32: {'genome': [['D', 210], ['D', 366], ['D', 211], ['D', 237]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=210, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=210, out_features=366, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=366, out_features=211, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=211, out_features=237, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=237, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# ), 'id': 32, 'loss': 0.057688906987508136, 'accuracy': 0.6666666666666666, 'parameters': 206671}
# Individual #33: {'genome': [['D', 390], ['D', 243]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=390, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=390, out_features=243, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=243, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 33, 'loss': 0.05660820921262105, 'accuracy': 0.6666666666666666, 'parameters': 97695}
# Individual #34: {'genome': [['D', 347], ['D', 417]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=347, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=347, out_features=417, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=417, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 34, 'loss': 0.048230453729629516, 'accuracy': 0.8533333333333334, 'parameters': 148105}
# Individual #35: {'genome': [['D', 389], ['D', 224], ['D', 183], ['D', 252], ['D', 249], ['D', 386], ['D', 152], ['D', 202]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=389, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=389, out_features=224, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=224, out_features=183, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=183, out_features=252, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=252, out_features=249, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=249, out_features=386, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=386, out_features=152, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=152, out_features=202, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=202, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 35, 'loss': 0.06781895438830057, 'accuracy': 0.6666666666666666, 'parameters': 426684}
# Individual #36: {'genome': [['D', 266], ['D', 174], ['D', 232], ['D', 395], ['D', 484], ['D', 458], ['D', 480], ['D', 391], ['D', 511]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=266, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=266, out_features=174, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=174, out_features=232, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=232, out_features=395, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=395, out_features=484, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=484, out_features=458, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=458, out_features=480, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=480, out_features=391, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=391, out_features=511, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=511, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 36, 'loss': 0.08120709578196207, 'accuracy': 0.3333333333333333, 'parameters': 1204456}
# Individual #37: {'genome': [['D', 397], ['D', 364], ['D', 263], ['D', 361]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=397, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=397, out_features=364, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=364, out_features=263, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=263, out_features=361, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=361, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# ), 'id': 37, 'loss': 0.057164467970530194, 'accuracy': 0.68, 'parameters': 339242}
# Individual #38: {'genome': [['D', 302], ['D', 211], ['D', 490], ['D', 183], ['D', 507], ['D', 486], ['D', 168]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=302, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=302, out_features=211, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=211, out_features=490, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=490, out_features=183, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=183, out_features=507, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=507, out_features=486, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=486, out_features=168, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=168, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# ), 'id': 38, 'loss': 0.08051172097524008, 'accuracy': 0.3333333333333333, 'parameters': 681675}
# Individual #39: {'genome': [['D', 156], ['D', 349], ['D', 368], ['D', 443], ['D', 431], ['D', 206], ['D', 357], ['D', 353], ['D', 141]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=156, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=156, out_features=349, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=349, out_features=368, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=368, out_features=443, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=443, out_features=431, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=431, out_features=206, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=206, out_features=357, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=357, out_features=353, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=353, out_features=141, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=141, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 39, 'loss': 0.07399683594703674, 'accuracy': 0.3333333333333333, 'parameters': 878809}
# Individual #40: {'genome': [['D', 177], ['D', 293], ['D', 502]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=177, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=177, out_features=293, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=293, out_features=502, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=502, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# ), 'id': 40, 'loss': 0.059603328307469686, 'accuracy': 0.6666666666666666, 'parameters': 202136}
# Individual #41: {'genome': [['D', 325], ['D', 174], ['D', 347], ['D', 345], ['D', 384]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=325, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=325, out_features=174, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=174, out_features=347, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=347, out_features=345, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=345, out_features=384, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=384, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# ), 'id': 41, 'loss': 0.053810264666875204, 'accuracy': 0.6666666666666666, 'parameters': 373153}
# Individual #42: {'genome': [['D', 326], ['D', 286], ['D', 257], ['D', 181], ['D', 260], ['D', 376], ['D', 157]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=326, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=326, out_features=286, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=286, out_features=257, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=257, out_features=181, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=181, out_features=260, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=260, out_features=376, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=376, out_features=157, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=157, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# ), 'id': 42, 'loss': 0.05759629527727763, 'accuracy': 0.6666666666666666, 'parameters': 420728}
# Individual #43: {'genome': [['D', 400], ['D', 457], ['D', 214], ['D', 455]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=400, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=400, out_features=457, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=457, out_features=214, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=214, out_features=455, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=455, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# ), 'id': 43, 'loss': 0.053999106089274086, 'accuracy': 0.6666666666666666, 'parameters': 382462}
# Individual #44: {'genome': [['D', 269], ['D', 137], ['D', 214], ['D', 326], ['D', 331], ['D', 185], ['D', 135]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=269, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=269, out_features=137, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=137, out_features=214, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=214, out_features=326, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=326, out_features=331, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=331, out_features=185, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=185, out_features=135, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=135, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# ), 'id': 44, 'loss': 0.06153763771057129, 'accuracy': 0.38, 'parameters': 333132}
# Individual #45: {'genome': [['D', 359], ['D', 369], ['D', 447], ['D', 232], ['D', 278], ['D', 237]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=359, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=359, out_features=369, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=369, out_features=447, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=447, out_features=232, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=232, out_features=278, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=278, out_features=237, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=237, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# ), 'id': 45, 'loss': 0.08120743036270142, 'accuracy': 0.3333333333333333, 'parameters': 535572}
# Individual #46: {'genome': [['D', 240], ['D', 351], ['D', 333], ['D', 489], ['D', 157], ['D', 130]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=240, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=240, out_features=351, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=351, out_features=333, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=333, out_features=489, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=489, out_features=157, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=157, out_features=130, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=130, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# ), 'id': 46, 'loss': 0.05825926264127095, 'accuracy': 0.6666666666666666, 'parameters': 464196}
# Individual #47: {'genome': [['D', 247], ['D', 372], ['D', 240], ['D', 288], ['D', 334], ['D', 506], ['D', 165], ['D', 325], ['D', 243]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=247, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=247, out_features=372, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=372, out_features=240, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=240, out_features=288, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=288, out_features=334, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=334, out_features=506, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=506, out_features=165, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=165, out_features=325, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=325, out_features=243, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=243, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 47, 'loss': 0.05725598335266113, 'accuracy': 0.6666666666666666, 'parameters': 736010}
# Individual #48: {'genome': [['D', 290], ['D', 263]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=290, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=290, out_features=263, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=263, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 48, 'loss': 0.05802601456642151, 'accuracy': 0.6666666666666666, 'parameters': 78775}
# Individual #49: {'genome': [['D', 428], ['D', 393]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=428, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=428, out_features=393, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=393, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 49, 'loss': 0.04775075872739156, 'accuracy': 0.82, 'parameters': 171919}

# %%
generation.calculate_fitness()

# %% [markdown]
# # Now use the automated evolve

# %%
train_dataset = Iris_dataset(df.values[:,:4], df['species'])
test_dataset = Iris_dataset(df.values[:,:4], df['species'])
train_loader = torch.utils.data.DataLoader(train_dataset,shuffle=True,**train_kwargs)
test_loader = torch.utils.data.DataLoader(test_dataset,shuffle=True, **test_kwargs)

generation = GA(generation_length=10,population_size=50,initial_size=256,initial_depth=5, lossFn=nn.CrossEntropyLoss(), input_size=4, output_size=3, outputLayer=nn.Softmax(dim=1), device=device, train_dataloader=train_loader, test_dataloader=test_loader, optimizerFn="Adam", epoch=100  )
generation.auto_evolve()
# Out:
# Generation #0
# [['D', 253], ['D', 331], ['D', 242], ['D', 399], ['D', 282], ['D', 392], ['D', 247]]
# ['D', 331]
# ['D', 242]
# ['D', 399]
# ['D', 282]
# ['D', 392]
# ['D', 247]
# [['D', 367], ['D', 266], ['D', 226], ['D', 161], ['D', 219], ['D', 306]]
# ['D', 266]
# ['D', 226]
# ['D', 161]
# ['D', 219]
# ['D', 306]
# [['D', 403], ['D', 458], ['D', 201], ['D', 400], ['D', 221], ['D', 149], ['D', 309], ['D', 425], ['D', 175], ['D', 500]]
# ['D', 458]
# ['D', 201]
# ['D', 400]
# ['D', 221]
# ['D', 149]
# ['D', 309]
# ['D', 425]
# ['D', 175]
# ['D', 500]
# [['D', 163], ['D', 306], ['D', 350], ['D', 381]]
# ['D', 306]
# ['D', 350]
# ['D', 381]
# [['D', 387], ['D', 198], ['D', 307], ['D', 500]]
# ['D', 198]
# ['D', 307]
# ['D', 500]
# [['D', 479], ['D', 204]]
# ['D', 204]
# [['D', 340], ['D', 374]]
# ['D', 374]
# [['D', 417], ['D', 210]]
# ['D', 210]
# [['D', 304], ['D', 353], ['D', 425], ['D', 295], ['D', 506], ['D', 410], ['D', 511]]
# ['D', 353]
# ['D', 425]
# ['D', 295]
# ['D', 506]
# ['D', 410]
# ['D', 511]
# [['D', 134], ['D', 437], ['D', 438], ['D', 463], ['D', 301], ['D', 491], ['D', 150], ['D', 375], ['D', 280], ['D', 341]]
# ['D', 437]
# ['D', 438]
# ['D', 463]
# ['D', 301]
# ['D', 491]
# ['D', 150]
# ['D', 375]
# ['D', 280]
# ['D', 341]
# [['D', 273], ['D', 320], ['D', 494], ['D', 352], ['D', 193]]
# ['D', 320]
# ['D', 494]
# ['D', 352]
# ['D', 193]
# [['D', 368], ['D', 128], ['D', 355], ['D', 279]]
# ['D', 128]
# ['D', 355]
# ['D', 279]
# [['D', 156], ['D', 210], ['D', 436], ['D', 402], ['D', 132], ['D', 194]]
# ['D', 210]
# ['D', 436]
# ['D', 402]
# ['D', 132]
# ['D', 194]
# [['D', 242], ['D', 249], ['D', 424], ['D', 249]]
# ['D', 249]
# ['D', 424]
# ['D', 249]
# [['D', 338], ['D', 305], ['D', 151], ['D', 288], ['D', 286], ['D', 128], ['D', 128]]
# ['D', 305]
# ['D', 151]
# ['D', 288]
# ['D', 286]
# ['D', 128]
# ['D', 128]
# [['D', 174], ['D', 213], ['D', 388], ['D', 329], ['D', 383], ['D', 327], ['D', 504]]
# ['D', 213]
# ['D', 388]
# ['D', 329]
# ['D', 383]
# ['D', 327]
# ['D', 504]
# [['D', 423], ['D', 464], ['D', 246], ['D', 401], ['D', 202], ['D', 237], ['D', 194], ['D', 299], ['D', 283], ['D', 482]]
# ['D', 464]
# ['D', 246]
# ['D', 401]
# ['D', 202]
# ['D', 237]
# ['D', 194]
# ['D', 299]
# ['D', 283]
# ['D', 482]
# [['D', 295], ['D', 352], ['D', 437], ['D', 360], ['D', 193], ['D', 398], ['D', 396], ['D', 239], ['D', 461]]
# ['D', 352]
# ['D', 437]
# ['D', 360]
# ['D', 193]
# ['D', 398]
# ['D', 396]
# ['D', 239]
# ['D', 461]
# [['D', 271], ['D', 354], ['D', 493], ['D', 232], ['D', 418], ['D', 246]]
# ['D', 354]
# ['D', 493]
# ['D', 232]
# ['D', 418]
# ['D', 246]
# [['D', 164], ['D', 393], ['D', 261], ['D', 306], ['D', 170], ['D', 483]]
# ['D', 393]
# ['D', 261]
# ['D', 306]
# ['D', 170]
# ['D', 483]
# [['D', 211], ['D', 406], ['D', 497]]
# ['D', 406]
# ['D', 497]
# [['D', 171], ['D', 507], ['D', 266], ['D', 504], ['D', 436], ['D', 413], ['D', 270], ['D', 156], ['D', 449], ['D', 255]]
# ['D', 507]
# ['D', 266]
# ['D', 504]
# ['D', 436]
# ['D', 413]
# ['D', 270]
# ['D', 156]
# ['D', 449]
# ['D', 255]
# [['D', 163], ['D', 429], ['D', 378], ['D', 481], ['D', 487]]
# ['D', 429]
# ['D', 378]
# ['D', 481]
# ['D', 487]
# [['D', 151], ['D', 479], ['D', 197]]
# ['D', 479]
# ['D', 197]
# [['D', 265], ['D', 239], ['D', 279], ['D', 255], ['D', 281], ['D', 244]]
# ['D', 239]
# ['D', 279]
# ['D', 255]
# ['D', 281]
# ['D', 244]
# [['D', 144], ['D', 237]]
# ['D', 237]
# [['D', 264], ['D', 488], ['D', 182]]
# ['D', 488]
# ['D', 182]
# [['D', 256], ['D', 412], ['D', 212], ['D', 420], ['D', 472], ['D', 354], ['D', 312], ['D', 259], ['D', 154]]
# ['D', 412]
# ['D', 212]
# ['D', 420]
# ['D', 472]
# ['D', 354]
# ['D', 312]
# ['D', 259]
# ['D', 154]
# [['D', 469], ['D', 466], ['D', 175], ['D', 192], ['D', 423]]
# ['D', 466]
# ['D', 175]
# ['D', 192]
# ['D', 423]
# [['D', 386], ['D', 415], ['D', 472]]
# ['D', 415]
# ['D', 472]
# [['D', 337], ['D', 395], ['D', 201], ['D', 140], ['D', 461], ['D', 434], ['D', 467], ['D', 245], ['D', 211], ['D', 298]]
# ['D', 395]
# ['D', 201]
# ['D', 140]
# ['D', 461]
# ['D', 434]
# ['D', 467]
# ['D', 245]
# ['D', 211]
# ['D', 298]
# [['D', 335], ['D', 459], ['D', 449], ['D', 305], ['D', 256], ['D', 146]]
# ['D', 459]
# ['D', 449]
# ['D', 305]
# ['D', 256]
# ['D', 146]
# [['D', 297], ['D', 383], ['D', 325], ['D', 496], ['D', 393], ['D', 295]]
# ['D', 383]
# ['D', 325]
# ['D', 496]
# ['D', 393]
# ['D', 295]
# [['D', 142], ['D', 313], ['D', 268], ['D', 286], ['D', 314], ['D', 182], ['D', 334]]
# ['D', 313]
# ['D', 268]
# ['D', 286]
# ['D', 314]
# ['D', 182]
# ['D', 334]
# [['D', 213], ['D', 383], ['D', 226], ['D', 343], ['D', 193], ['D', 187], ['D', 229]]
# ['D', 383]
# ['D', 226]
# ['D', 343]
# ['D', 193]
# ['D', 187]
# ['D', 229]
# [['D', 442], ['D', 407], ['D', 381], ['D', 405]]
# ['D', 407]
# ['D', 381]
# ['D', 405]
# [['D', 402], ['D', 174], ['D', 207], ['D', 130], ['D', 471], ['D', 246], ['D', 296]]
# ['D', 174]
# ['D', 207]
# ['D', 130]
# ['D', 471]
# ['D', 246]
# ['D', 296]
# [['D', 472], ['D', 278], ['D', 283], ['D', 496], ['D', 311], ['D', 254], ['D', 152]]
# ['D', 278]
# ['D', 283]
# ['D', 496]
# ['D', 311]
# ['D', 254]
# ['D', 152]
# [['D', 218], ['D', 351], ['D', 503], ['D', 382]]
# ['D', 351]
# ['D', 503]
# ['D', 382]
# [['D', 201], ['D', 417], ['D', 164], ['D', 229], ['D', 330]]
# ['D', 417]
# ['D', 164]
# ['D', 229]
# ['D', 330]
# [['D', 194], ['D', 461], ['D', 157]]
# ['D', 461]
# ['D', 157]
# [['D', 466], ['D', 284], ['D', 348], ['D', 132], ['D', 398], ['D', 246], ['D', 160]]
# ['D', 284]
# ['D', 348]
# ['D', 132]
# ['D', 398]
# ['D', 246]
# ['D', 160]
# [['D', 487], ['D', 290], ['D', 173], ['D', 303], ['D', 343], ['D', 495], ['D', 324], ['D', 201], ['D', 459], ['D', 254]]
# ['D', 290]
# ['D', 173]
# ['D', 303]
# ['D', 343]
# ['D', 495]
# ['D', 324]
# ['D', 201]
# ['D', 459]
# ['D', 254]
# [['D', 259], ['D', 233], ['D', 334], ['D', 239], ['D', 468]]
# ['D', 233]
# ['D', 334]
# ['D', 239]
# ['D', 468]
# [['D', 223], ['D', 463], ['D', 387], ['D', 389], ['D', 383], ['D', 335], ['D', 407], ['D', 358]]
# ['D', 463]
# ['D', 387]
# ['D', 389]
# ['D', 383]
# ['D', 335]
# ['D', 407]
# ['D', 358]
# [['D', 382], ['D', 299]]
# ['D', 299]
# [['D', 446], ['D', 434], ['D', 280], ['D', 395], ['D', 485]]
# ['D', 434]
# ['D', 280]
# ['D', 395]
# ['D', 485]
# [['D', 504], ['D', 288], ['D', 204], ['D', 240], ['D', 239], ['D', 308], ['D', 202], ['D', 162], ['D', 423], ['D', 153]]
# ['D', 288]
# ['D', 204]
# ['D', 240]
# ['D', 239]
# ['D', 308]
# ['D', 202]
# ['D', 162]
# ['D', 423]
# ['D', 153]
# [['D', 170], ['D', 239], ['D', 428], ['D', 468]]
# ['D', 239]
# ['D', 428]
# ['D', 468]
# [['D', 398], ['D', 309], ['D', 174], ['D', 481], ['D', 244], ['D', 426], ['D', 436], ['D', 342], ['D', 312], ['D', 349]]
# ['D', 309]
# ['D', 174]
# ['D', 481]
# ['D', 244]
# ['D', 426]
# ['D', 436]
# ['D', 342]
# ['D', 312]
# ['D', 349]
# [{'genome': [['D', 253], ['D', 331], ['D', 242], ['D', 399], ['D', 282], ['D', 392], ['D', 247]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=253, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=253, out_features=331, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=331, out_features=242, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=242, out_features=399, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=399, out_features=282, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=282, out_features=392, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=392, out_features=247, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=247, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 367], ['D', 266], ['D', 226], ['D', 161], ['D', 219], ['D', 306]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=367, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=367, out_features=266, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=266, out_features=226, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=226, out_features=161, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=161, out_features=219, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=219, out_features=306, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=306, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 403], ['D', 458], ['D', 201], ['D', 400], ['D', 221], ['D', 149], ['D', 309], ['D', 425], ['D', 175], ['D', 500]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=403, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=403, out_features=458, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=458, out_features=201, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=201, out_features=400, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=400, out_features=221, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=221, out_features=149, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=149, out_features=309, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=309, out_features=425, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=425, out_features=175, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=175, out_features=500, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=500, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 163], ['D', 306], ['D', 350], ['D', 381]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=163, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=163, out_features=306, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=306, out_features=350, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=350, out_features=381, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=381, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 387], ['D', 198], ['D', 307], ['D', 500]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=387, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=387, out_features=198, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=198, out_features=307, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=307, out_features=500, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=500, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 479], ['D', 204]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=479, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=479, out_features=204, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=204, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 340], ['D', 374]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=340, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=340, out_features=374, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=374, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 417], ['D', 210]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=417, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=417, out_features=210, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=210, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 304], ['D', 353], ['D', 425], ['D', 295], ['D', 506], ['D', 410], ['D', 511]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=304, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=304, out_features=353, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=353, out_features=425, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=425, out_features=295, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=295, out_features=506, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=506, out_features=410, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=410, out_features=511, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=511, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 134], ['D', 437], ['D', 438], ['D', 463], ['D', 301], ['D', 491], ['D', 150], ['D', 375], ['D', 280], ['D', 341]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=134, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=134, out_features=437, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=437, out_features=438, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=438, out_features=463, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=463, out_features=301, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=301, out_features=491, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=491, out_features=150, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=150, out_features=375, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=375, out_features=280, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=280, out_features=341, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=341, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 273], ['D', 320], ['D', 494], ['D', 352], ['D', 193]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=273, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=273, out_features=320, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=320, out_features=494, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=494, out_features=352, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=352, out_features=193, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=193, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 368], ['D', 128], ['D', 355], ['D', 279]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=368, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=368, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=128, out_features=355, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=355, out_features=279, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=279, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 156], ['D', 210], ['D', 436], ['D', 402], ['D', 132], ['D', 194]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=156, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=156, out_features=210, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=210, out_features=436, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=436, out_features=402, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=402, out_features=132, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=132, out_features=194, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=194, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 242], ['D', 249], ['D', 424], ['D', 249]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=242, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=242, out_features=249, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=249, out_features=424, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=424, out_features=249, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=249, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 338], ['D', 305], ['D', 151], ['D', 288], ['D', 286], ['D', 128], ['D', 128]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=338, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=338, out_features=305, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=305, out_features=151, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=151, out_features=288, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=288, out_features=286, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=286, out_features=128, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=128, out_features=128, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=128, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 174], ['D', 213], ['D', 388], ['D', 329], ['D', 383], ['D', 327], ['D', 504]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=174, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=174, out_features=213, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=213, out_features=388, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=388, out_features=329, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=329, out_features=383, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=383, out_features=327, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=327, out_features=504, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=504, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 423], ['D', 464], ['D', 246], ['D', 401], ['D', 202], ['D', 237], ['D', 194], ['D', 299], ['D', 283], ['D', 482]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=423, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=423, out_features=464, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=464, out_features=246, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=246, out_features=401, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=401, out_features=202, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=202, out_features=237, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=237, out_features=194, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=194, out_features=299, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=299, out_features=283, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=283, out_features=482, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=482, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 295], ['D', 352], ['D', 437], ['D', 360], ['D', 193], ['D', 398], ['D', 396], ['D', 239], ['D', 461]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=295, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=295, out_features=352, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=352, out_features=437, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=437, out_features=360, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=360, out_features=193, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=193, out_features=398, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=398, out_features=396, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=396, out_features=239, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=239, out_features=461, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=461, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 271], ['D', 354], ['D', 493], ['D', 232], ['D', 418], ['D', 246]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=271, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=271, out_features=354, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=354, out_features=493, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=493, out_features=232, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=232, out_features=418, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=418, out_features=246, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=246, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 164], ['D', 393], ['D', 261], ['D', 306], ['D', 170], ['D', 483]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=164, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=164, out_features=393, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=393, out_features=261, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=261, out_features=306, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=306, out_features=170, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=170, out_features=483, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=483, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 211], ['D', 406], ['D', 497]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=211, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=211, out_features=406, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=406, out_features=497, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=497, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 171], ['D', 507], ['D', 266], ['D', 504], ['D', 436], ['D', 413], ['D', 270], ['D', 156], ['D', 449], ['D', 255]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=171, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=171, out_features=507, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=507, out_features=266, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=266, out_features=504, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=504, out_features=436, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=436, out_features=413, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=413, out_features=270, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=270, out_features=156, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=156, out_features=449, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=449, out_features=255, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=255, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 163], ['D', 429], ['D', 378], ['D', 481], ['D', 487]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=163, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=163, out_features=429, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=429, out_features=378, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=378, out_features=481, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=481, out_features=487, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=487, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 151], ['D', 479], ['D', 197]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=151, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=151, out_features=479, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=479, out_features=197, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=197, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 265], ['D', 239], ['D', 279], ['D', 255], ['D', 281], ['D', 244]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=265, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=265, out_features=239, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=239, out_features=279, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=279, out_features=255, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=255, out_features=281, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=281, out_features=244, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=244, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 144], ['D', 237]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=144, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=144, out_features=237, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=237, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 264], ['D', 488], ['D', 182]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=264, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=264, out_features=488, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=488, out_features=182, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=182, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 256], ['D', 412], ['D', 212], ['D', 420], ['D', 472], ['D', 354], ['D', 312], ['D', 259], ['D', 154]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=412, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=412, out_features=212, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=212, out_features=420, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=420, out_features=472, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=472, out_features=354, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=354, out_features=312, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=312, out_features=259, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=259, out_features=154, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=154, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 469], ['D', 466], ['D', 175], ['D', 192], ['D', 423]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=469, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=469, out_features=466, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=466, out_features=175, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=175, out_features=192, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=192, out_features=423, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=423, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 386], ['D', 415], ['D', 472]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=386, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=386, out_features=415, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=415, out_features=472, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=472, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 337], ['D', 395], ['D', 201], ['D', 140], ['D', 461], ['D', 434], ['D', 467], ['D', 245], ['D', 211], ['D', 298]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=337, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=337, out_features=395, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=395, out_features=201, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=201, out_features=140, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=140, out_features=461, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=461, out_features=434, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=434, out_features=467, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=467, out_features=245, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=245, out_features=211, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=211, out_features=298, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=298, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 335], ['D', 459], ['D', 449], ['D', 305], ['D', 256], ['D', 146]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=335, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=335, out_features=459, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=459, out_features=449, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=449, out_features=305, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=305, out_features=256, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=256, out_features=146, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=146, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 297], ['D', 383], ['D', 325], ['D', 496], ['D', 393], ['D', 295]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=297, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=297, out_features=383, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=383, out_features=325, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=325, out_features=496, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=496, out_features=393, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=393, out_features=295, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=295, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 142], ['D', 313], ['D', 268], ['D', 286], ['D', 314], ['D', 182], ['D', 334]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=142, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=142, out_features=313, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=313, out_features=268, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=268, out_features=286, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=286, out_features=314, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=314, out_features=182, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=182, out_features=334, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=334, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 213], ['D', 383], ['D', 226], ['D', 343], ['D', 193], ['D', 187], ['D', 229]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=213, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=213, out_features=383, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=383, out_features=226, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=226, out_features=343, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=343, out_features=193, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=193, out_features=187, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=187, out_features=229, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=229, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 442], ['D', 407], ['D', 381], ['D', 405]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=442, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=442, out_features=407, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=407, out_features=381, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=381, out_features=405, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=405, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 402], ['D', 174], ['D', 207], ['D', 130], ['D', 471], ['D', 246], ['D', 296]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=402, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=402, out_features=174, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=174, out_features=207, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=207, out_features=130, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=130, out_features=471, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=471, out_features=246, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=246, out_features=296, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=296, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 472], ['D', 278], ['D', 283], ['D', 496], ['D', 311], ['D', 254], ['D', 152]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=472, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=472, out_features=278, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=278, out_features=283, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=283, out_features=496, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=496, out_features=311, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=311, out_features=254, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=254, out_features=152, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=152, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 218], ['D', 351], ['D', 503], ['D', 382]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=218, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=218, out_features=351, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=351, out_features=503, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=503, out_features=382, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=382, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 201], ['D', 417], ['D', 164], ['D', 229], ['D', 330]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=201, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=201, out_features=417, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=417, out_features=164, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=164, out_features=229, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=229, out_features=330, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=330, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 194], ['D', 461], ['D', 157]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=194, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=194, out_features=461, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=461, out_features=157, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=157, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 466], ['D', 284], ['D', 348], ['D', 132], ['D', 398], ['D', 246], ['D', 160]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=466, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=466, out_features=284, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=284, out_features=348, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=348, out_features=132, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=132, out_features=398, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=398, out_features=246, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=246, out_features=160, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=160, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 487], ['D', 290], ['D', 173], ['D', 303], ['D', 343], ['D', 495], ['D', 324], ['D', 201], ['D', 459], ['D', 254]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=487, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=487, out_features=290, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=290, out_features=173, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=173, out_features=303, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=303, out_features=343, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=343, out_features=495, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=495, out_features=324, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=324, out_features=201, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=201, out_features=459, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=459, out_features=254, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=254, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 259], ['D', 233], ['D', 334], ['D', 239], ['D', 468]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=259, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=259, out_features=233, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=233, out_features=334, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=334, out_features=239, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=239, out_features=468, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=468, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 223], ['D', 463], ['D', 387], ['D', 389], ['D', 383], ['D', 335], ['D', 407], ['D', 358]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=223, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=223, out_features=463, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=463, out_features=387, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=387, out_features=389, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=389, out_features=383, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=383, out_features=335, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=335, out_features=407, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=407, out_features=358, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=358, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 382], ['D', 299]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=382, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=382, out_features=299, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=299, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 446], ['D', 434], ['D', 280], ['D', 395], ['D', 485]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=446, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=446, out_features=434, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=434, out_features=280, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=280, out_features=395, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=395, out_features=485, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=485, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 504], ['D', 288], ['D', 204], ['D', 240], ['D', 239], ['D', 308], ['D', 202], ['D', 162], ['D', 423], ['D', 153]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=504, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=504, out_features=288, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=288, out_features=204, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=204, out_features=240, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=240, out_features=239, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=239, out_features=308, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=308, out_features=202, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=202, out_features=162, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=162, out_features=423, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=423, out_features=153, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=153, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 170], ['D', 239], ['D', 428], ['D', 468]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=170, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=170, out_features=239, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=239, out_features=428, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=428, out_features=468, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=468, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 398], ['D', 309], ['D', 174], ['D', 481], ['D', 244], ['D', 426], ['D', 436], ['D', 342], ['D', 312], ['D', 349]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=398, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=398, out_features=309, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=309, out_features=174, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=174, out_features=481, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=481, out_features=244, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=244, out_features=426, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=426, out_features=436, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=436, out_features=342, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=342, out_features=312, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=312, out_features=349, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=349, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# )}]
# Training individual #0
# Training individual #1
# Training individual #2
# Training individual #3
# Training individual #4
# Training individual #5
# Training individual #6
# Training individual #7
# Training individual #8
# Training individual #9
# Training individual #10
# Training individual #11
# Training individual #12
# Training individual #13
# Training individual #14
# Training individual #15
# Training individual #16
# Training individual #17
# Training individual #18
# Training individual #19
# Training individual #20
# Training individual #21
# Training individual #22
# Training individual #23
# Training individual #24
# Training individual #25
# Training individual #26
# Training individual #27
# Training individual #28
# Training individual #29
# Training individual #30
# Training individual #31
# Training individual #32
# Training individual #33
# Training individual #34
# Training individual #35
# Training individual #36
# Training individual #37
# Training individual #38
# Training individual #39
# Training individual #40
# Training individual #41
# Training individual #42
# Training individual #43
# Training individual #44
# Training individual #45
# Training individual #46
# Training individual #47
# Training individual #48
# Training individual #49
# Evaluating individual #0
# Evaluating individual #1
# Evaluating individual #2
# Evaluating individual #3
# Evaluating individual #4
# Evaluating individual #5
# Evaluating individual #6
# Evaluating individual #7
# Evaluating individual #8
# Evaluating individual #9
# Evaluating individual #10
# Evaluating individual #11
# Evaluating individual #12
# Evaluating individual #13
# Evaluating individual #14
# Evaluating individual #15
# Evaluating individual #16
# Evaluating individual #17
# Evaluating individual #18
# Evaluating individual #19
# Evaluating individual #20
# Evaluating individual #21
# Evaluating individual #22
# Evaluating individual #23
# Evaluating individual #24
# Evaluating individual #25
# Evaluating individual #26
# Evaluating individual #27
# Evaluating individual #28
# Evaluating individual #29
# Evaluating individual #30
# Evaluating individual #31
# Evaluating individual #32
# Evaluating individual #33
# Evaluating individual #34
# Evaluating individual #35
# Evaluating individual #36
# Evaluating individual #37
# Evaluating individual #38
# Evaluating individual #39
# Evaluating individual #40
# Evaluating individual #41
# Evaluating individual #42
# Evaluating individual #43
# Evaluating individual #44
# Evaluating individual #45
# Evaluating individual #46
# Evaluating individual #47
# Evaluating individual #48
# Evaluating individual #49
# Generation #1
# [['D', 387], ['D', 198], ['D', 307], ['D', 500]]
# ['D', 198]
# ['D', 307]
# ['D', 500]
# [['D', 402], ['D', 174], ['D', 207], ['D', 130], ['D', 471], ['D', 246], ['D', 296]]
# ['D', 174]
# ['D', 207]
# ['D', 130]
# ['D', 471]
# ['D', 246]
# ['D', 296]
# [['D', 446], ['D', 434], ['D', 280], ['D', 395], ['D', 485]]
# ['D', 434]
# ['D', 280]
# ['D', 395]
# ['D', 485]
# [['D', 442], ['D', 407], ['D', 381], ['D', 405]]
# ['D', 407]
# ['D', 381]
# ['D', 405]
# [['D', 273], ['D', 320], ['D', 494], ['D', 352], ['D', 193]]
# ['D', 320]
# ['D', 494]
# ['D', 352]
# ['D', 193]
# [['D', 504], ['D', 288], ['D', 204], ['D', 240], ['D', 239], ['D', 308], ['D', 202], ['D', 162], ['D', 423], ['D', 153]]
# ['D', 288]
# ['D', 204]
# ['D', 240]
# ['D', 239]
# ['D', 308]
# ['D', 202]
# ['D', 162]
# ['D', 423]
# ['D', 153]
# [['D', 466], ['D', 284], ['D', 348], ['D', 132], ['D', 398], ['D', 246], ['D', 160]]
# ['D', 284]
# ['D', 348]
# ['D', 132]
# ['D', 398]
# ['D', 246]
# ['D', 160]
# [['D', 142], ['D', 313], ['D', 268], ['D', 286], ['D', 314], ['D', 182], ['D', 334]]
# ['D', 313]
# ['D', 268]
# ['D', 286]
# ['D', 314]
# ['D', 182]
# ['D', 334]
# [['D', 338], ['D', 305], ['D', 151], ['D', 288], ['D', 286], ['D', 128], ['D', 128]]
# ['D', 305]
# ['D', 151]
# ['D', 288]
# ['D', 286]
# ['D', 128]
# ['D', 128]
# [['D', 213], ['D', 383], ['D', 226], ['D', 343], ['D', 193], ['D', 187], ['D', 229]]
# ['D', 383]
# ['D', 226]
# ['D', 343]
# ['D', 193]
# ['D', 187]
# ['D', 229]
# [['D', 368], ['D', 128], ['D', 355], ['D', 279]]
# ['D', 128]
# ['D', 355]
# ['D', 279]
# [['D', 256], ['D', 412], ['D', 212], ['D', 420], ['D', 472], ['D', 354], ['D', 312], ['D', 259], ['D', 154]]
# ['D', 412]
# ['D', 212]
# ['D', 420]
# ['D', 472]
# ['D', 354]
# ['D', 312]
# ['D', 259]
# ['D', 154]
# [['D', 156], ['D', 210], ['D', 436], ['D', 402], ['D', 132], ['D', 194]]
# ['D', 210]
# ['D', 436]
# ['D', 402]
# ['D', 132]
# ['D', 194]
# [['D', 164], ['D', 393], ['D', 261], ['D', 306], ['D', 170], ['D', 483]]
# ['D', 393]
# ['D', 261]
# ['D', 306]
# ['D', 170]
# ['D', 483]
# [['D', 163], ['D', 306], ['D', 350], ['D', 381]]
# ['D', 306]
# ['D', 350]
# ['D', 381]
# [['D', 297], ['D', 383], ['D', 325], ['D', 496], ['D', 393], ['D', 295]]
# ['D', 383]
# ['D', 325]
# ['D', 496]
# ['D', 393]
# ['D', 295]
# [['D', 223], ['D', 463], ['D', 387], ['D', 389], ['D', 383], ['D', 335], ['D', 407], ['D', 358]]
# ['D', 463]
# ['D', 387]
# ['D', 389]
# ['D', 383]
# ['D', 335]
# ['D', 407]
# ['D', 358]
# [['D', 335], ['D', 459], ['D', 449], ['D', 305], ['D', 256], ['D', 146]]
# ['D', 459]
# ['D', 449]
# ['D', 305]
# ['D', 256]
# ['D', 146]
# [['D', 265], ['D', 239], ['D', 279], ['D', 255], ['D', 281], ['D', 244]]
# ['D', 239]
# ['D', 279]
# ['D', 255]
# ['D', 281]
# ['D', 244]
# [['D', 469], ['D', 466], ['D', 175], ['D', 192], ['D', 423]]
# ['D', 466]
# ['D', 175]
# ['D', 192]
# ['D', 423]
# [['D', 242], ['D', 249], ['D', 424], ['D', 249]]
# ['D', 249]
# ['D', 424]
# ['D', 249]
# [['D', 211], ['D', 406], ['D', 497]]
# ['D', 406]
# ['D', 497]
# [['D', 479], ['D', 204]]
# ['D', 204]
# [['D', 218], ['D', 351], ['D', 503], ['D', 382]]
# ['D', 351]
# ['D', 503]
# ['D', 382]
# [['D', 386], ['D', 415], ['D', 472]]
# ['D', 415]
# ['D', 472]
# [['D', 163], ['D', 429], ['D', 378], ['D', 481], ['D', 487]]
# ['D', 429]
# ['D', 378]
# ['D', 481]
# ['D', 487]
# [['D', 253], ['D', 331], ['D', 242], ['D', 399], ['D', 282], ['D', 392], ['D', 247]]
# ['D', 331]
# ['D', 242]
# ['D', 399]
# ['D', 282]
# ['D', 392]
# ['D', 247]
# [['D', 264], ['D', 488], ['D', 182]]
# ['D', 488]
# ['D', 182]
# [['D', 271], ['D', 354], ['D', 493], ['D', 232], ['D', 418], ['D', 246]]
# ['D', 354]
# ['D', 493]
# ['D', 232]
# ['D', 418]
# ['D', 246]
# [['D', 144], ['D', 237]]
# ['D', 237]
# [['D', 259], ['D', 233], ['D', 334], ['D', 239], ['D', 468]]
# ['D', 233]
# ['D', 334]
# ['D', 239]
# ['D', 468]
# [['D', 170], ['D', 239], ['D', 428], ['D', 468]]
# ['D', 239]
# ...
#     (3): ReLU()
#     (4): Linear(in_features=4, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 13], ['D', 15]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=13, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=13, out_features=15, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=15, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 31], ['D', 13], ['D', 15]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=31, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=31, out_features=13, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=13, out_features=15, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=15, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 19], ['D', 13], ['D', 239], ['D', 15]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=19, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=19, out_features=13, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=13, out_features=239, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=239, out_features=15, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=15, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 30], ['D', 13], ['D', 15]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=30, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=30, out_features=13, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=13, out_features=15, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=15, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 11], ['D', 13], ['D', 80], ['D', 15]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=11, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=11, out_features=13, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=13, out_features=80, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=80, out_features=15, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=15, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 168], ['D', 247], ['D', 54]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=168, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=168, out_features=247, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=247, out_features=54, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=54, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 479], ['D', 204]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=479, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=479, out_features=204, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=204, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 13], ['D', 52], ['D', 15]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=13, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=13, out_features=52, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=52, out_features=15, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=15, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 30], ['D', 13], ['D', 15]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=30, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=30, out_features=13, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=13, out_features=15, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=15, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 4]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=4, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=4, out_features=3, bias=True)
#     (3): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 11], ['D', 13], ['D', 15]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=11, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=11, out_features=13, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=13, out_features=15, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=15, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 31], ['D', 14], ['D', 34], ['D', 13], ['D', 15]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=31, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=31, out_features=14, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=14, out_features=34, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=34, out_features=13, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=13, out_features=15, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=15, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 13], ['D', 15]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=13, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=13, out_features=15, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=15, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 54]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=54, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=54, out_features=3, bias=True)
#     (3): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 11], ['D', 13], ['D', 80], ['D', 15]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=11, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=11, out_features=13, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=13, out_features=80, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=80, out_features=15, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=15, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 31], ['D', 14], ['D', 13], ['D', 15]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=31, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=31, out_features=14, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=14, out_features=13, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=13, out_features=15, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=15, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 13], ['D', 15]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=13, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=13, out_features=15, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=15, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 13], ['D', 15]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=13, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=13, out_features=15, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=15, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 13], ['D', 15]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=13, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=13, out_features=15, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=15, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 13], ['D', 15]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=13, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=13, out_features=15, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=15, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 31], ['D', 14], ['D', 9], ['D', 13], ['D', 15]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=31, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=31, out_features=14, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=14, out_features=9, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=9, out_features=13, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=13, out_features=15, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=15, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 13]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=13, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=13, out_features=3, bias=True)
#     (3): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 16], ['D', 26], ['D', 15]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=16, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=16, out_features=26, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=26, out_features=15, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=15, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 13], ['D', 0], ['D', 15]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=13, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=13, out_features=0, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=0, out_features=15, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=15, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 13], ['D', 15]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=13, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=13, out_features=15, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=15, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 13], ['D', 0], ['D', 15]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=13, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=13, out_features=0, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=0, out_features=15, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=15, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 48], ['D', 13], ['D', 15]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=48, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=48, out_features=13, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=13, out_features=15, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=15, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 13], ['D', 15]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=13, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=13, out_features=15, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=15, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 0], ['D', 6], ['D', 15]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=0, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=0, out_features=6, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=6, out_features=15, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=15, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 48], ['D', 13], ['D', 15]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=48, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=48, out_features=13, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=13, out_features=15, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=15, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 48], ['D', 13], ['D', 15]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=48, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=48, out_features=13, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=13, out_features=15, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=15, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}, {'genome': [['D', 13], ['D', 15]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=13, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=13, out_features=15, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=15, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}]
# Training individual #0
# Training individual #1
# Training individual #2
# Training individual #3
# Training individual #4
# Training individual #5
# Training individual #6
# Training individual #7
# Training individual #8
# Training individual #9
# Training individual #10
# Training individual #11
# Training individual #12
# Training individual #13
# Training individual #14
# Training individual #15
# Training individual #16
# Training individual #17
# Training individual #18
# Training individual #19
# Training individual #20
# Training individual #21
# Training individual #22
# Training individual #23
# Training individual #24
# Training individual #25
# Training individual #26
# Training individual #27
# Training individual #28
# Training individual #29
# Training individual #30
# Training individual #31
# Training individual #32
# Training individual #33
# Training individual #34
# Training individual #35
# Training individual #36
# Training individual #37
# Training individual #38
# Training individual #39
# Training individual #40
# Training individual #41
# Training individual #42
# Training individual #43
# Training individual #44
# Training individual #45
# Training individual #46
# Training individual #47
# Training individual #48
# Training individual #49
# Evaluating individual #0
# Evaluating individual #1
# Evaluating individual #2
# Evaluating individual #3
# Evaluating individual #4
# Evaluating individual #5
# Evaluating individual #6
# Evaluating individual #7
# Evaluating individual #8
# Evaluating individual #9
# Evaluating individual #10
# Evaluating individual #11
# Evaluating individual #12
# Evaluating individual #13
# Evaluating individual #14
# Evaluating individual #15
# Evaluating individual #16
# Evaluating individual #17
# Evaluating individual #18
# Evaluating individual #19
# Evaluating individual #20
# Evaluating individual #21
# Evaluating individual #22
# Evaluating individual #23
# Evaluating individual #24
# Evaluating individual #25
# Evaluating individual #26
# Evaluating individual #27
# Evaluating individual #28
# Evaluating individual #29
# Evaluating individual #30
# Evaluating individual #31
# Evaluating individual #32
# Evaluating individual #33
# Evaluating individual #34
# Evaluating individual #35
# Evaluating individual #36
# Evaluating individual #37
# Evaluating individual #38
# Evaluating individual #39
# Evaluating individual #40
# Evaluating individual #41
# Evaluating individual #42
# Evaluating individual #43
# Evaluating individual #44
# Evaluating individual #45
# Evaluating individual #46
# Evaluating individual #47
# Evaluating individual #48
# Evaluating individual #49

# %% [markdown]
# # Best architectures

# %%
generation.print_population(5)
# Out:
# Individual #0: {'genome': [['D', 13], ['D', 15]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=13, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=13, out_features=15, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=15, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 30, 'loss': 0.07205087582270304, 'accuracy': 0.6666666666666666, 'parameters': 323, 'fitness': 116}
# Individual #1: {'genome': [['D', 13], ['D', 15]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=13, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=13, out_features=15, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=15, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 35, 'loss': 0.0694393515586853, 'accuracy': 0.6666666666666666, 'parameters': 323, 'fitness': 123}
# Individual #2: {'genome': [['D', 4]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=4, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=4, out_features=3, bias=True)
#     (3): Softmax(dim=1)
#   )
# ), 'id': 27, 'loss': 0.07195507605870564, 'accuracy': 0.6666666666666666, 'parameters': 35, 'fitness': 125}
# Individual #3: {'genome': [['D', 13]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=13, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=13, out_features=3, bias=True)
#     (3): Softmax(dim=1)
#   )
# ), 'id': 39, 'loss': 0.06933621565500896, 'accuracy': 0.6666666666666666, 'parameters': 107, 'fitness': 135}
# Individual #4: {'genome': [['D', 13], ['D', 15]], 'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=13, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=13, out_features=15, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=15, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 34, 'loss': 0.06982066154479981, 'accuracy': 0.84, 'parameters': 323, 'fitness': 136}
