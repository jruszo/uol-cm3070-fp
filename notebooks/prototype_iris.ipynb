# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import pandas as pd

# %% [markdown]
# # Create dataset object for dataloader for XOR dataset

# %%
class Iris_dataset(torch.utils.data.Dataset):
    def __init__(self, data, labels):
        self.x = torch.tensor(data, dtype=torch.float32)
        self.y = torch.tensor(labels, dtype=torch.long)
        
    def __len__(self):
        return len(self.x)
    
    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]

# %%
data = pd.read_csv('../data/IRIS.csv')
df_norm = data[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']].apply(lambda x: (x - x.min()) / (x.max() - x.min()))
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
target= labelencoder.fit_transform(data['species'])
target = pd.DataFrame(target)
target.rename(columns = {0:'species'}, inplace = True)
df = pd.concat([df_norm, target], axis=1)

# %%
class ConstructNet(nn.Module):
    def __init__(self, DNA, loss_fn, input_size, output_size, outputlayer):
        super(ConstructNet, self).__init__()
        self.DNA = DNA
        self.input_size = input_size
        self.output_size = output_size
        self.layers = []
        self.loss_fn = loss_fn
        
        # Append first layer
        self.layers.append(nn.Linear(self.input_size, self.DNA[0][1]))
        self.layers.append(nn.ReLU())
        
        for i in range(1, len(self.DNA)):
            if self.DNA[i][0] == "D":
                # The input size is the output of the last layer
                tmp_input_size = self.last_layer_output_size()
                self.layers.append(nn.Linear(tmp_input_size, self.DNA[i][1]))
                self.layers.append(nn.ReLU())
            if self.DNA[i][0] == "R":
                self.layers.append(nn.Dropout(self.DNA[i][1]))
        
        # Append the output layer        
        self.layers.append(nn.Linear(self.layers[-2].out_features, self.output_size))
        #if self.output_size > 1: 
        #    self.layers.append(nn.Softmax(dim=1))
        #else:
        #    self.layers.append(nn.Sigmoid())
        self.layers.append(outputlayer)
        self.net = nn.Sequential(*self.layers)
        
    def forward(self, x):
        return self.net(x)
    '''
    Based on the layers created, find the output size of the last dense layer
    '''
    def last_layer_output_size(self):
        for layer in self.layers[::-1]:
            if isinstance(layer, nn.Linear):
                return layer.out_features
            
    def train_net(self, device, train_loader, optimizer, epoch, log_interval, print_stats):
        self.train()
        for batch_idx, (data, target) in enumerate(train_loader):
            data, target = data.to(device), target.to(device)
            optimizer.zero_grad()
            output = self.forward(data)
            loss = self.loss_fn(output, target)
            loss.backward()
            optimizer.step()
            if batch_idx % log_interval == 0 and print_stats:
                print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                    epoch, batch_idx * len(data), len(train_loader.dataset),
                    100. * batch_idx / len(train_loader), loss.item()))


    def test(self, device, test_loader, print_stats=False):
        self.eval()
        test_loss = 0
        correct = 0
        with torch.no_grad():
            for data, target in test_loader:
                data, target = data.to(device), target.to(device)
                output = self.forward(data)
                #print(f"output: {output}, target: {target}")
                test_loss += self.loss_fn.forward(output, target).item()  # sum up batch loss
                pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
                correct += pred.eq(target.view_as(pred)).sum().item()
        test_loss /= len(test_loader.dataset)
        accuracy = correct / len(test_loader.dataset)
        if print_stats:
            print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
                test_loss, correct, len(test_loader.dataset),
                100. * accuracy))
        return test_loss, accuracy
        
    def count_parameters(self):
        # https://discuss.pytorch.org/t/how-do-i-check-the-number-of-parameters-of-a-model/4325/7
        return sum(p.numel() for p in self.net.parameters() if p.requires_grad)

# %%
DNA_list = [
    [["D",1024],["D",512],["D",128]],
    [["D",1024],["R",0.2],["D",512],["R",0.2],["D",128]],
    [["D",64],["D", 64]]
]

# %% [markdown]
# # Initialise hyperparameters

# %%
batch_size = 16
use_mps = False and torch.backends.mps.is_available()
use_cuda = True and torch.cuda.is_available()
test_batch_size = 16
epochs = 30
lr = 0.02
gamma = 0.7
seed = 1
log_interval = 100
save_model = False

if use_cuda:
    device = torch.device("cuda")
elif use_mps:
    device = torch.device("mps")
else:
    device = torch.device("cpu")
    
train_kwargs = {'batch_size': batch_size}
test_kwargs = {'batch_size': test_batch_size}

# %%
train_dataset = Iris_dataset(df.values[:,:4], df['species'])
test_dataset = Iris_dataset(df.values[:,:4], df['species'])
train_loader = torch.utils.data.DataLoader(train_dataset,shuffle=True,**train_kwargs)
test_loader = torch.utils.data.DataLoader(test_dataset,shuffle=True, **test_kwargs)

# %%
outputlayer = nn.Softmax(dim=1)
generations = [[]]

for DNA in DNA_list:
    inv_net = ConstructNet(DNA, nn.CrossEntropyLoss(), input_size=4, output_size=3, outputlayer=outputlayer)
    print(inv_net)
    optimizer = optim.Adam(inv_net.parameters(), lr=lr)

    for epoch in range(1, epochs + 1):
        inv_net.train_net(device, train_loader, optimizer, epoch, log_interval, print_stats=True)
        inv_net.test(device, test_loader)
    if save_model:
        torch.save(inv_net.state_dict(), "mnist_cnn.pt")
    generations[0].append(inv_net)
# Out:
# ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=1024, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=1024, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=128, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=128, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )
# Train Epoch: 1 [0/150 (0%)]	Loss: 1.099543
# Train Epoch: 2 [0/150 (0%)]	Loss: 1.113945
# Train Epoch: 3 [0/150 (0%)]	Loss: 1.238945
# Train Epoch: 4 [0/150 (0%)]	Loss: 1.426445
# Train Epoch: 5 [0/150 (0%)]	Loss: 1.176445
# Train Epoch: 6 [0/150 (0%)]	Loss: 1.363945
# Train Epoch: 7 [0/150 (0%)]	Loss: 1.238945
# Train Epoch: 8 [0/150 (0%)]	Loss: 1.301445
# Train Epoch: 9 [0/150 (0%)]	Loss: 1.051445
# Train Epoch: 10 [0/150 (0%)]	Loss: 1.301445
# Train Epoch: 11 [0/150 (0%)]	Loss: 1.238945
# Train Epoch: 12 [0/150 (0%)]	Loss: 1.301445
# Train Epoch: 13 [0/150 (0%)]	Loss: 1.176445
# Train Epoch: 14 [0/150 (0%)]	Loss: 1.238945
# Train Epoch: 15 [0/150 (0%)]	Loss: 1.426445
# Train Epoch: 16 [0/150 (0%)]	Loss: 1.113945
# Train Epoch: 17 [0/150 (0%)]	Loss: 1.113945
# Train Epoch: 18 [0/150 (0%)]	Loss: 1.113945
# Train Epoch: 19 [0/150 (0%)]	Loss: 1.176445
# Train Epoch: 20 [0/150 (0%)]	Loss: 1.238945
# Train Epoch: 21 [0/150 (0%)]	Loss: 1.113945
# Train Epoch: 22 [0/150 (0%)]	Loss: 1.363945
# Train Epoch: 23 [0/150 (0%)]	Loss: 1.238945
# Train Epoch: 24 [0/150 (0%)]	Loss: 1.363945
# Train Epoch: 25 [0/150 (0%)]	Loss: 1.051445
# Train Epoch: 26 [0/150 (0%)]	Loss: 1.113945
# Train Epoch: 27 [0/150 (0%)]	Loss: 1.238945
# Train Epoch: 28 [0/150 (0%)]	Loss: 1.363945
# Train Epoch: 29 [0/150 (0%)]	Loss: 1.238945
# Train Epoch: 30 [0/150 (0%)]	Loss: 1.238945
# ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=1024, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=1024, out_features=512, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=512, out_features=128, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=128, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )
# Train Epoch: 1 [0/150 (0%)]	Loss: 1.100799
# Train Epoch: 2 [0/150 (0%)]	Loss: 1.176445
# Train Epoch: 3 [0/150 (0%)]	Loss: 1.301445
# Train Epoch: 4 [0/150 (0%)]	Loss: 1.176445
# Train Epoch: 5 [0/150 (0%)]	Loss: 1.363945
# Train Epoch: 6 [0/150 (0%)]	Loss: 1.238945
# Train Epoch: 7 [0/150 (0%)]	Loss: 1.051445
# Train Epoch: 8 [0/150 (0%)]	Loss: 1.176445
# Train Epoch: 9 [0/150 (0%)]	Loss: 1.176445
# Train Epoch: 10 [0/150 (0%)]	Loss: 1.176445
# Train Epoch: 11 [0/150 (0%)]	Loss: 1.363945
# Train Epoch: 12 [0/150 (0%)]	Loss: 1.113945
# Train Epoch: 13 [0/150 (0%)]	Loss: 1.176445
# Train Epoch: 14 [0/150 (0%)]	Loss: 1.238945
# Train Epoch: 15 [0/150 (0%)]	Loss: 1.238945
# Train Epoch: 16 [0/150 (0%)]	Loss: 1.176445
# Train Epoch: 17 [0/150 (0%)]	Loss: 1.301445
# Train Epoch: 18 [0/150 (0%)]	Loss: 1.238945
# Train Epoch: 19 [0/150 (0%)]	Loss: 1.113945
# Train Epoch: 20 [0/150 (0%)]	Loss: 1.176445
# Train Epoch: 21 [0/150 (0%)]	Loss: 1.238945
# Train Epoch: 22 [0/150 (0%)]	Loss: 1.238945
# Train Epoch: 23 [0/150 (0%)]	Loss: 1.238945
# Train Epoch: 24 [0/150 (0%)]	Loss: 1.238945
# Train Epoch: 25 [0/150 (0%)]	Loss: 1.301445
# Train Epoch: 26 [0/150 (0%)]	Loss: 1.238945
# Train Epoch: 27 [0/150 (0%)]	Loss: 1.426445
# Train Epoch: 28 [0/150 (0%)]	Loss: 0.988945
# Train Epoch: 29 [0/150 (0%)]	Loss: 1.051445
# Train Epoch: 30 [0/150 (0%)]	Loss: 1.113945
# ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=64, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=64, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )
# Train Epoch: 1 [0/150 (0%)]	Loss: 1.095790
# Train Epoch: 2 [0/150 (0%)]	Loss: 0.720573
# Train Epoch: 3 [0/150 (0%)]	Loss: 0.718721
# Train Epoch: 4 [0/150 (0%)]	Loss: 0.615065
# Train Epoch: 5 [0/150 (0%)]	Loss: 0.708497
# Train Epoch: 6 [0/150 (0%)]	Loss: 0.662789
# Train Epoch: 7 [0/150 (0%)]	Loss: 0.553265
# Train Epoch: 8 [0/150 (0%)]	Loss: 0.604767
# Train Epoch: 9 [0/150 (0%)]	Loss: 0.727322
# Train Epoch: 10 [0/150 (0%)]	Loss: 0.558828
# Train Epoch: 11 [0/150 (0%)]	Loss: 0.584869
# Train Epoch: 12 [0/150 (0%)]	Loss: 0.595459
# Train Epoch: 13 [0/150 (0%)]	Loss: 0.609376
# Train Epoch: 14 [0/150 (0%)]	Loss: 0.665343
# Train Epoch: 15 [0/150 (0%)]	Loss: 0.553272
# Train Epoch: 16 [0/150 (0%)]	Loss: 0.577754
# Train Epoch: 17 [0/150 (0%)]	Loss: 0.610950
# Train Epoch: 18 [0/150 (0%)]	Loss: 0.631036
# Train Epoch: 19 [0/150 (0%)]	Loss: 0.716229
# Train Epoch: 20 [0/150 (0%)]	Loss: 0.555687
# Train Epoch: 21 [0/150 (0%)]	Loss: 0.600028
# Train Epoch: 22 [0/150 (0%)]	Loss: 0.555929
# Train Epoch: 23 [0/150 (0%)]	Loss: 0.591136
# Train Epoch: 24 [0/150 (0%)]	Loss: 0.552172
# Train Epoch: 25 [0/150 (0%)]	Loss: 0.769576
# Train Epoch: 26 [0/150 (0%)]	Loss: 0.612327
# Train Epoch: 27 [0/150 (0%)]	Loss: 0.552174
# Train Epoch: 28 [0/150 (0%)]	Loss: 0.553313
# Train Epoch: 29 [0/150 (0%)]	Loss: 0.667638
# Train Epoch: 30 [0/150 (0%)]	Loss: 0.564779

# %%
generations
# Out:
# [[ConstructNet(
#     (loss_fn): CrossEntropyLoss()
#     (net): Sequential(
#       (0): Linear(in_features=4, out_features=1024, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=1024, out_features=512, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=512, out_features=128, bias=True)
#       (5): ReLU()
#       (6): Linear(in_features=128, out_features=3, bias=True)
#       (7): Softmax(dim=1)
#     )
#   ),
#   ConstructNet(
#     (loss_fn): CrossEntropyLoss()
#     (net): Sequential(
#       (0): Linear(in_features=4, out_features=1024, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.2, inplace=False)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): ReLU()
#       (5): Dropout(p=0.2, inplace=False)
#       (6): Linear(in_features=512, out_features=128, bias=True)
#       (7): ReLU()
#       (8): Linear(in_features=128, out_features=3, bias=True)
#       (9): Softmax(dim=1)
#     )
#   ),
#   ConstructNet(
#     (loss_fn): CrossEntropyLoss()
#     (net): Sequential(
#       (0): Linear(in_features=4, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=64, out_features=3, bias=True)
#       (5): Softmax(dim=1)
#     )
#   )]]

# %% [markdown]
# # Start of GA code

# %%
import random
import numpy as np
class GA():
    def __init__(self, generation_length, population_size, initial_size, initial_depth, 
                 lossFn, input_size, output_size, outputLayer, device, train_dataloader, test_dataloader, optimizerFn, epoch):
        self.generation_length = generation_length
        self.population_size = population_size
        self.initial = True # No previous individuals can be used for mutations
        self.initial_size = initial_size
        self.initial_depth = initial_depth
        
        self.lossFn = lossFn
        self.optimizerFn = optimizerFn
        self.input_size = input_size
        self.output_size = output_size
        self.outputLayer = outputLayer
        
        self.device = device
        self.train_dataloader = train_dataloader
        self.test_dataloader = test_dataloader
        self.epoch = epoch
        
        self.generate_population()
    
    def generate_population(self):
        self.population = []
        for i in range(self.population_size):
            self.population.append({'model': self.generate_individual()})
        self.initial = False
            
    def generate_individual(self):
        genome = []
        if self.initial:
            for chromosome in range(random.randint(np.floor(self.initial_depth/2), np.ceil(self.initial_depth*2))):
                layer_size = random.randint(np.floor(self.initial_size/2), np.ceil(self.initial_size*2))
                genome.append(["D",layer_size])
        return ConstructNet(genome, self.lossFn, self.input_size, self.output_size, self.outputLayer)
    
    def print_population(self):
        for index,individual in enumerate(self.population):
            print(f"Individual #{index}: {individual}")
            
    def train_population(self):
        for index,individual in enumerate(self.population):
            print(f"Training individual #{index}")
            if(self.optimizerFn == "Adam"):
                optimizer = torch.optim.Adam(individual['model'].parameters(), lr=0.01)
            individual['model'].train_net(self.device,self.train_dataloader, optimizer,self.epoch, 100, False)
    
    def evaluate_population(self):
        for index,individual in enumerate(self.population):
            print(f"Evaluating individual #{index}")
            loss, accuracy = individual['model'].test(self.device, self.test_dataloader)
            individual['id'] = index
            individual['loss'] = loss
            individual['accuracy'] = accuracy
            individual['parameters'] = individual['model'].count_parameters()
            self.population[index] = individual
        # sort population by accuracy
        #self.population = sorted(self.population, key=lambda d: d['accuracy'])
        
    def calculate_fitness(self):
        # Create copy of list using only a few columns
        tmp_list = []
        for index,item in enumerate(self.population):
            tmp_list.append({
                'id' : item['id'],
                'accuracy': item['accuracy'],
                'parameters': item['parameters'],
                'fitness': 0
            })
        accuracy_list = sorted(tmp_list, key=lambda d: d['accuracy'])
        # Adding more emphasis on accuracy
        for index,item in enumerate(accuracy_list):
            accuracy_list[index]['fitness'] += index*2
        # Reverse sort, smaller is better
        parameter_size_list = sorted(accuracy_list, key=lambda d: d['parameters'], reverse=True)
        for index,item in enumerate(parameter_size_list):
            parameter_size_list[index]['fitness'] += index
        sorted_by_fitness = sorted(parameter_size_list, key=lambda d: d['fitness'])
        #print("======= list by accuracy_list =========")
        #print(accuracy_list)
        #print("======= list by parameter_size =========")
        #print(parameter_size_list)
        #print("======= list by fitness =========")
        #print(sorted_by_fitness)
        for fitness in sorted_by_fitness:
            for index,individual in enumerate(self.population):
                if individual['id'] == fitness['id']:
                    individual['fitness'] = fitness['fitness']
            self.population[index] = individual
        # Sort population
        self.population = sorted(self.population, key=lambda d: d['fitness'])
        print(self.population)

# %%
train_dataset = Iris_dataset(df.values[:,:4], df['species'])
test_dataset = Iris_dataset(df.values[:,:4], df['species'])
train_loader = torch.utils.data.DataLoader(train_dataset,shuffle=True,**train_kwargs)
test_loader = torch.utils.data.DataLoader(test_dataset,shuffle=True, **test_kwargs)

generation = GA(generation_length=10,population_size=50,initial_size=256,initial_depth=5, lossFn=nn.CrossEntropyLoss(), input_size=4, output_size=3, outputLayer=nn.Softmax(dim=1), device=device, train_dataloader=train_loader, test_dataloader=test_loader, optimizerFn="Adam", epoch=100  )
generation.print_population()
# Out:
# Individual #0: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=236, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=236, out_features=350, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=350, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}
# Individual #1: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=417, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=417, out_features=334, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=334, out_features=416, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=416, out_features=157, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=157, out_features=430, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=430, out_features=270, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=270, out_features=365, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=365, out_features=210, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=210, out_features=418, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=418, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}
# Individual #2: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=305, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=305, out_features=171, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=171, out_features=250, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=250, out_features=301, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=301, out_features=208, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=208, out_features=371, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=371, out_features=239, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=239, out_features=176, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=176, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}
# Individual #3: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=179, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=179, out_features=271, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=271, out_features=427, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=427, out_features=435, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=435, out_features=307, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=307, out_features=488, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=488, out_features=196, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=196, out_features=277, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=277, out_features=436, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=436, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}
# Individual #4: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=325, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=325, out_features=306, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=306, out_features=192, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=192, out_features=275, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=275, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}
# Individual #5: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=152, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=152, out_features=232, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=232, out_features=201, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=201, out_features=252, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=252, out_features=182, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=182, out_features=509, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=509, out_features=496, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=496, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}
# Individual #6: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=299, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=299, out_features=316, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=316, out_features=501, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=501, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}
# Individual #7: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=466, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=466, out_features=133, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=133, out_features=423, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=423, out_features=170, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=170, out_features=197, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=197, out_features=145, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=145, out_features=393, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=393, out_features=345, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=345, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}
# Individual #8: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=316, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=316, out_features=206, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=206, out_features=359, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=359, out_features=231, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=231, out_features=130, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=130, out_features=413, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=413, out_features=418, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=418, out_features=426, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=426, out_features=506, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=506, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}
# Individual #9: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=295, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=295, out_features=427, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=427, out_features=293, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=293, out_features=213, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=213, out_features=155, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=155, out_features=247, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=247, out_features=507, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=507, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}
# Individual #10: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=203, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=203, out_features=312, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=312, out_features=395, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=395, out_features=419, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=419, out_features=370, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=370, out_features=365, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=365, out_features=259, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=259, out_features=455, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=455, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}
# Individual #11: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=243, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=243, out_features=309, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=309, out_features=166, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=166, out_features=172, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=172, out_features=191, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=191, out_features=274, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=274, out_features=359, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=359, out_features=349, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=349, out_features=248, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=248, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}
# Individual #12: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=339, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=339, out_features=395, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=395, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}
# Individual #13: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=231, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=231, out_features=146, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=146, out_features=442, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=442, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}
# Individual #14: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=218, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=218, out_features=154, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=154, out_features=402, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=402, out_features=435, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=435, out_features=354, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=354, out_features=188, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=188, out_features=183, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=183, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}
# Individual #15: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=233, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=233, out_features=448, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=448, out_features=386, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=386, out_features=241, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=241, out_features=397, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=397, out_features=184, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=184, out_features=512, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=512, out_features=353, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=353, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}
# Individual #16: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=327, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=327, out_features=350, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=350, out_features=249, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=249, out_features=210, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=210, out_features=354, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=354, out_features=426, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=426, out_features=245, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=245, out_features=415, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=415, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}
# Individual #17: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=417, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=417, out_features=175, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=175, out_features=234, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=234, out_features=509, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=509, out_features=279, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=279, out_features=131, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=131, out_features=269, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=269, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# )}
# Individual #18: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=491, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=491, out_features=295, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=295, out_features=151, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=151, out_features=301, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=301, out_features=273, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=273, out_features=196, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=196, out_features=284, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=284, out_features=157, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=157, out_features=367, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=367, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}
# Individual #19: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=227, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=227, out_features=495, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=495, out_features=195, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=195, out_features=155, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=155, out_features=452, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=452, out_features=337, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=337, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}
# Individual #20: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=183, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=183, out_features=444, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=444, out_features=434, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=434, out_features=393, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=393, out_features=461, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=461, out_features=130, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=130, out_features=355, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=355, out_features=427, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=427, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}
# Individual #21: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=196, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=196, out_features=368, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=368, out_features=307, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=307, out_features=259, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=259, out_features=470, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=470, out_features=486, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=486, out_features=249, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=249, out_features=438, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=438, out_features=494, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=494, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}
# Individual #22: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=194, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=194, out_features=283, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=283, out_features=185, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=185, out_features=240, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=240, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}
# Individual #23: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=510, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=510, out_features=384, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=384, out_features=389, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=389, out_features=467, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=467, out_features=142, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=142, out_features=128, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=128, out_features=353, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=353, out_features=460, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=460, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}
# Individual #24: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=191, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=191, out_features=487, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=487, out_features=276, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=276, out_features=383, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=383, out_features=329, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=329, out_features=372, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=372, out_features=223, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=223, out_features=432, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=432, out_features=444, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=444, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}
# Individual #25: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=272, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=272, out_features=375, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=375, out_features=487, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=487, out_features=132, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=132, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}
# Individual #26: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=199, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=199, out_features=432, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=432, out_features=408, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=408, out_features=139, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=139, out_features=282, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=282, out_features=464, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=464, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}
# Individual #27: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=407, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=407, out_features=154, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=154, out_features=443, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=443, out_features=232, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=232, out_features=489, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=489, out_features=293, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=293, out_features=272, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=272, out_features=284, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=284, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# )}
# Individual #28: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=441, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=441, out_features=260, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=260, out_features=321, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=321, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}
# Individual #29: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=366, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=366, out_features=467, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=467, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}
# Individual #30: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=447, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=447, out_features=471, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=471, out_features=310, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=310, out_features=128, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=128, out_features=285, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=285, out_features=205, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=205, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}
# Individual #31: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=139, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=139, out_features=162, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=162, out_features=510, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=510, out_features=149, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=149, out_features=304, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=304, out_features=426, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=426, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}
# Individual #32: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=223, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=223, out_features=493, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=493, out_features=277, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=277, out_features=472, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=472, out_features=380, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=380, out_features=201, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=201, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}
# Individual #33: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=469, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=469, out_features=343, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=343, out_features=207, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=207, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}
# Individual #34: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=276, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=276, out_features=178, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=178, out_features=447, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=447, out_features=348, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=348, out_features=494, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=494, out_features=131, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=131, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# )}
# Individual #35: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=156, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=156, out_features=238, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=238, out_features=429, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=429, out_features=153, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=153, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}
# Individual #36: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=211, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=211, out_features=293, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=293, out_features=286, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=286, out_features=240, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=240, out_features=501, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=501, out_features=245, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=245, out_features=511, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=511, out_features=251, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=251, out_features=310, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=310, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}
# Individual #37: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=231, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=231, out_features=451, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=451, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}
# Individual #38: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=234, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=234, out_features=243, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=243, out_features=350, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=350, out_features=202, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=202, out_features=344, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=344, out_features=257, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=257, out_features=326, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=326, out_features=231, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=231, out_features=452, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=452, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}
# Individual #39: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=411, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=411, out_features=264, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=264, out_features=232, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=232, out_features=343, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=343, out_features=217, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=217, out_features=262, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=262, out_features=136, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=136, out_features=498, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=498, out_features=210, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=210, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}
# Individual #40: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=376, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=376, out_features=164, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=164, out_features=140, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=140, out_features=326, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=326, out_features=325, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=325, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}
# Individual #41: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=278, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=278, out_features=226, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=226, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}
# Individual #42: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=494, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=494, out_features=313, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=313, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}
# Individual #43: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=286, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=286, out_features=495, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=495, out_features=483, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=483, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# )}
# Individual #44: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=378, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=378, out_features=250, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=250, out_features=500, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=500, out_features=373, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=373, out_features=172, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=172, out_features=294, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=294, out_features=299, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=299, out_features=493, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=493, out_features=296, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=296, out_features=165, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=165, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# )}
# Individual #45: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=223, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=223, out_features=277, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=277, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )}
# Individual #46: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=150, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=150, out_features=357, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=357, out_features=464, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=464, out_features=462, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=462, out_features=323, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=323, out_features=363, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=363, out_features=395, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=395, out_features=393, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=393, out_features=293, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=293, out_features=310, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=310, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# )}
# Individual #47: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=379, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=379, out_features=300, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=300, out_features=274, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=274, out_features=257, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=257, out_features=390, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=390, out_features=195, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=195, out_features=206, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=206, out_features=425, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=425, out_features=233, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=233, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# )}
# Individual #48: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=331, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=331, out_features=332, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=332, out_features=311, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=311, out_features=374, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=374, out_features=223, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=223, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# )}
# Individual #49: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=452, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=452, out_features=481, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=481, out_features=403, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=403, out_features=200, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=200, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# )}

# %%
generation.train_population()
# Out:
# Training individual #0
# Training individual #1
# Training individual #2
# Training individual #3
# Training individual #4
# Training individual #5
# Training individual #6
# Training individual #7
# Training individual #8
# Training individual #9
# Training individual #10
# Training individual #11
# Training individual #12
# Training individual #13
# Training individual #14
# Training individual #15
# Training individual #16
# Training individual #17
# Training individual #18
# Training individual #19
# Training individual #20
# Training individual #21
# Training individual #22
# Training individual #23
# Training individual #24
# Training individual #25
# Training individual #26
# Training individual #27
# Training individual #28
# Training individual #29
# Training individual #30
# Training individual #31
# Training individual #32
# Training individual #33
# Training individual #34
# Training individual #35
# Training individual #36
# Training individual #37
# Training individual #38
# Training individual #39
# Training individual #40
# Training individual #41
# Training individual #42
# Training individual #43
# Training individual #44
# Training individual #45
# Training individual #46
# Training individual #47
# Training individual #48
# Training individual #49

# %%
generation.evaluate_population()
# Out:
# Evaluating individual #0
# Evaluating individual #1
# Evaluating individual #2
# Evaluating individual #3
# Evaluating individual #4
# Evaluating individual #5
# Evaluating individual #6
# Evaluating individual #7
# Evaluating individual #8
# Evaluating individual #9
# Evaluating individual #10
# Evaluating individual #11
# Evaluating individual #12
# Evaluating individual #13
# Evaluating individual #14
# Evaluating individual #15
# Evaluating individual #16
# Evaluating individual #17
# Evaluating individual #18
# Evaluating individual #19
# Evaluating individual #20
# Evaluating individual #21
# Evaluating individual #22
# Evaluating individual #23
# Evaluating individual #24
# Evaluating individual #25
# Evaluating individual #26
# Evaluating individual #27
# Evaluating individual #28
# Evaluating individual #29
# Evaluating individual #30
# Evaluating individual #31
# Evaluating individual #32
# Evaluating individual #33
# Evaluating individual #34
# Evaluating individual #35
# Evaluating individual #36
# Evaluating individual #37
# Evaluating individual #38
# Evaluating individual #39
# Evaluating individual #40
# Evaluating individual #41
# Evaluating individual #42
# Evaluating individual #43
# Evaluating individual #44
# Evaluating individual #45
# Evaluating individual #46
# Evaluating individual #47
# Evaluating individual #48
# Evaluating individual #49

# %%
generation.print_population()
# Out:
# Individual #0: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=236, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=236, out_features=350, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=350, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 0, 'loss': 0.05758402506510417, 'accuracy': 0.6666666666666666, 'parameters': 85183}
# Individual #1: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=417, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=417, out_features=334, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=334, out_features=416, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=416, out_features=157, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=157, out_features=430, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=430, out_features=270, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=270, out_features=365, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=365, out_features=210, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=210, out_features=418, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=418, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 1, 'loss': 0.06843905806541443, 'accuracy': 0.66, 'parameters': 796066}
# Individual #2: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=305, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=305, out_features=171, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=171, out_features=250, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=250, out_features=301, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=301, out_features=208, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=208, out_features=371, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=371, out_features=239, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=239, out_features=176, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=176, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 2, 'loss': 0.0732213576634725, 'accuracy': 0.3333333333333333, 'parameters': 444436}
# Individual #3: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=179, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=179, out_features=271, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=271, out_features=427, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=427, out_features=435, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=435, out_features=307, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=307, out_features=488, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=488, out_features=196, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=196, out_features=277, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=277, out_features=436, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=436, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 3, 'loss': 0.0732745122909546, 'accuracy': 0.3333333333333333, 'parameters': 909087}
# Individual #4: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=325, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=325, out_features=306, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=306, out_features=192, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=192, out_features=275, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=275, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# ), 'id': 4, 'loss': 0.05999790787696838, 'accuracy': 0.66, 'parameters': 214228}
# Individual #5: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=152, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=152, out_features=232, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=232, out_features=201, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=201, out_features=252, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=252, out_features=182, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=182, out_features=509, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=509, out_features=496, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=496, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# ), 'id': 5, 'loss': 0.0637717620531718, 'accuracy': 0.6666666666666666, 'parameters': 527637}
# Individual #6: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=299, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=299, out_features=316, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=316, out_features=501, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=501, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# ), 'id': 6, 'loss': 0.060969424645106, 'accuracy': 0.6, 'parameters': 256618}
# Individual #7: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=466, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=466, out_features=133, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=133, out_features=423, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=423, out_features=170, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=170, out_features=197, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=197, out_features=145, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=145, out_features=393, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=393, out_features=345, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=345, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 7, 'loss': 0.07817335367202759, 'accuracy': 0.34, 'parameters': 449946}
# Individual #8: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=316, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=316, out_features=206, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=206, out_features=359, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=359, out_features=231, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=231, out_features=130, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=130, out_features=413, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=413, out_features=418, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=418, out_features=426, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=426, out_features=506, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=506, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 8, 'loss': 0.06033379236857096, 'accuracy': 0.6666666666666666, 'parameters': 877747}
# Individual #9: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=295, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=295, out_features=427, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=427, out_features=293, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=293, out_features=213, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=213, out_features=155, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=155, out_features=247, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=247, out_features=507, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=507, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# ), 'id': 9, 'loss': 0.05967965284983317, 'accuracy': 0.6666666666666666, 'parameters': 514855}
# Individual #10: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=203, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=203, out_features=312, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=312, out_features=395, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=395, out_features=419, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=419, out_features=370, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=370, out_features=365, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=365, out_features=259, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=259, out_features=455, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=455, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 10, 'loss': 0.06148362159729004, 'accuracy': 0.6333333333333333, 'parameters': 859499}
# Individual #11: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=243, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=243, out_features=309, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=309, out_features=166, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=166, out_features=172, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=172, out_features=191, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=191, out_features=274, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=274, out_features=359, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=359, out_features=349, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=349, out_features=248, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=248, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 11, 'loss': 0.070661989847819, 'accuracy': 0.25333333333333335, 'parameters': 554358}
# Individual #12: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=339, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=339, out_features=395, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=395, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 12, 'loss': 0.057407337427139285, 'accuracy': 0.6666666666666666, 'parameters': 137183}
# Individual #13: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=231, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=231, out_features=146, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=146, out_features=442, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=442, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# ), 'id': 13, 'loss': 0.05478837291399638, 'accuracy': 0.6666666666666666, 'parameters': 101330}
# Individual #14: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=218, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=218, out_features=154, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=154, out_features=402, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=402, out_features=435, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=435, out_features=354, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=354, out_features=188, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=188, out_features=183, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=183, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# ), 'id': 14, 'loss': 0.0650059994061788, 'accuracy': 0.6666666666666666, 'parameters': 528654}
# Individual #15: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=233, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=233, out_features=448, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=448, out_features=386, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=386, out_features=241, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=241, out_features=397, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=397, out_features=184, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=184, out_features=512, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=512, out_features=353, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=353, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 15, 'loss': 0.07123314221700032, 'accuracy': 0.3333333333333333, 'parameters': 818755}
# Individual #16: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=327, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=327, out_features=350, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=350, out_features=249, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=249, out_features=210, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=210, out_features=354, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=354, out_features=426, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=426, out_features=245, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=245, out_features=415, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=415, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 16, 'loss': 0.08190188050270081, 'accuracy': 0.3333333333333333, 'parameters': 690211}
# Individual #17: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=417, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=417, out_features=175, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=175, out_features=234, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=234, out_features=509, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=509, out_features=279, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=279, out_features=131, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=131, out_features=269, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=269, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# ), 'id': 17, 'loss': 0.07305783033370972, 'accuracy': 0.3333333333333333, 'parameters': 451322}
# Individual #18: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=491, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=491, out_features=295, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=295, out_features=151, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=151, out_features=301, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=301, out_features=273, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=273, out_features=196, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=196, out_features=284, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=284, out_features=157, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=157, out_features=367, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=367, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 18, 'loss': 0.07981854518254598, 'accuracy': 0.3333333333333333, 'parameters': 533976}
# Individual #19: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=227, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=227, out_features=495, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=495, out_features=195, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=195, out_features=155, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=155, out_features=452, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=452, out_features=337, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=337, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# ), 'id': 19, 'loss': 0.06738431294759115, 'accuracy': 0.3333333333333333, 'parameters': 465282}
# Individual #20: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=183, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=183, out_features=444, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=444, out_features=434, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=434, out_features=393, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=393, out_features=461, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=461, out_features=130, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=130, out_features=355, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=355, out_features=427, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=427, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 20, 'loss': 0.05571957310040792, 'accuracy': 0.6666666666666666, 'parameters': 888191}
# Individual #21: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=196, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=196, out_features=368, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=368, out_features=307, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=307, out_features=259, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=259, out_features=470, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=470, out_features=486, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=486, out_features=249, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=249, out_features=438, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=438, out_features=494, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=494, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 21, 'loss': 0.07326417684555053, 'accuracy': 0.3333333333333333, 'parameters': 1066751}
# Individual #22: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=194, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=194, out_features=283, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=283, out_features=185, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=185, out_features=240, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=240, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# ), 'id': 22, 'loss': 0.06036105036735535, 'accuracy': 0.6666666666666666, 'parameters': 154058}
# Individual #23: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=510, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=510, out_features=384, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=384, out_features=389, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=389, out_features=467, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=467, out_features=142, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=142, out_features=128, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=128, out_features=353, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=353, out_features=460, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=460, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 23, 'loss': 0.07239339431126912, 'accuracy': 0.3933333333333333, 'parameters': 825189}
# Individual #24: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=191, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=191, out_features=487, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=487, out_features=276, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=276, out_features=383, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=383, out_features=329, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=329, out_features=372, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=372, out_features=223, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=223, out_features=432, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=432, out_features=444, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=444, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 24, 'loss': 0.05759632031122843, 'accuracy': 0.6666666666666666, 'parameters': 957868}
# Individual #25: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=272, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=272, out_features=375, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=375, out_features=487, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=487, out_features=132, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=132, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# ), 'id': 25, 'loss': 0.05734206517537435, 'accuracy': 0.6666666666666666, 'parameters': 351662}
# Individual #26: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=199, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=199, out_features=432, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=432, out_features=408, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=408, out_features=139, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=139, out_features=282, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=282, out_features=464, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=464, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# ), 'id': 26, 'loss': 0.05967965483665466, 'accuracy': 0.6666666666666666, 'parameters': 493097}
# Individual #27: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=407, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=407, out_features=154, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=154, out_features=443, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=443, out_features=232, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=232, out_features=489, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=489, out_features=293, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=293, out_features=272, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=272, out_features=284, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=284, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 27, 'loss': 0.05604582111040751, 'accuracy': 0.6666666666666666, 'parameters': 652402}
# Individual #28: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=441, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=441, out_features=260, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=260, out_features=321, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=321, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# ), 'id': 28, 'loss': 0.04951334714889526, 'accuracy': 0.76, 'parameters': 201872}
# Individual #29: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=366, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=366, out_features=467, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=467, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 29, 'loss': 0.05898520747820536, 'accuracy': 0.6666666666666666, 'parameters': 174623}
# Individual #30: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=447, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=447, out_features=471, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=471, out_features=310, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=310, out_features=128, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=128, out_features=285, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=285, out_features=205, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=205, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# ), 'id': 30, 'loss': 0.06218456784884135, 'accuracy': 0.6266666666666667, 'parameters': 495384}
# Individual #31: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=139, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=139, out_features=162, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=162, out_features=510, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=510, out_features=149, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=149, out_features=304, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=304, out_features=426, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=426, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# ), 'id': 31, 'loss': 0.06349273165067038, 'accuracy': 0.43333333333333335, 'parameters': 359455}
# Individual #32: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=223, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=223, out_features=493, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=493, out_features=277, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=277, out_features=472, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=472, out_features=380, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=380, out_features=201, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=201, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# ), 'id': 32, 'loss': 0.06270701050758362, 'accuracy': 0.6066666666666667, 'parameters': 636528}
# Individual #33: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=469, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=469, out_features=343, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=343, out_features=207, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=207, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# ), 'id': 33, 'loss': 0.04538963238398234, 'accuracy': 0.88, 'parameters': 235387}
# Individual #34: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=276, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=276, out_features=178, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=178, out_features=447, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=447, out_features=348, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=348, out_features=494, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=494, out_features=131, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=131, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# ), 'id': 34, 'loss': 0.05988239010175069, 'accuracy': 0.6666666666666666, 'parameters': 524250}
# Individual #35: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=156, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=156, out_features=238, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=238, out_features=429, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=429, out_features=153, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=153, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# ), 'id': 35, 'loss': 0.05731015841166178, 'accuracy': 0.6666666666666666, 'parameters': 206929}
# Individual #36: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=211, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=211, out_features=293, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=293, out_features=286, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=286, out_features=240, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=240, out_features=501, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=501, out_features=245, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=245, out_features=511, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=511, out_features=251, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=251, out_features=310, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=310, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 36, 'loss': 0.07344729661941528, 'accuracy': 0.3333333333333333, 'parameters': 793137}
# Individual #37: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=231, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=231, out_features=451, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=451, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 37, 'loss': 0.055101219018300375, 'accuracy': 0.6733333333333333, 'parameters': 107143}
# Individual #38: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=234, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=234, out_features=243, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=243, out_features=350, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=350, out_features=202, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=202, out_features=344, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=344, out_features=257, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=257, out_features=326, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=326, out_features=231, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=231, out_features=452, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=452, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 38, 'loss': 0.07162819544474285, 'accuracy': 0.64, 'parameters': 638942}
# Individual #39: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=411, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=411, out_features=264, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=264, out_features=232, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=232, out_features=343, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=343, out_features=217, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=217, out_features=262, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=262, out_features=136, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=136, out_features=498, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=498, out_features=210, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=210, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 39, 'loss': 0.08190187374750774, 'accuracy': 0.3333333333333333, 'parameters': 593403}
# Individual #40: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=376, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=376, out_features=164, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=164, out_features=140, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=140, out_features=326, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=326, out_features=325, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=325, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# ), 'id': 40, 'loss': 0.05898520747820536, 'accuracy': 0.6666666666666666, 'parameters': 240027}
# Individual #41: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=278, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=278, out_features=226, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=226, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 41, 'loss': 0.051259345213572186, 'accuracy': 0.7333333333333333, 'parameters': 65125}
# Individual #42: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=494, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=494, out_features=313, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=313, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 42, 'loss': 0.04933411439259847, 'accuracy': 0.82, 'parameters': 158347}
# Individual #43: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=286, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=286, out_features=495, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=495, out_features=483, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=483, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# ), 'id': 43, 'loss': 0.058983410199483235, 'accuracy': 0.6666666666666666, 'parameters': 384515}
# Individual #44: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=378, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=378, out_features=250, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=250, out_features=500, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=500, out_features=373, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=373, out_features=172, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=172, out_features=294, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=294, out_features=299, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=299, out_features=493, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=493, out_features=296, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=296, out_features=165, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=165, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# ), 'id': 44, 'loss': 0.0708661925792694, 'accuracy': 0.6533333333333333, 'parameters': 956035}
# Individual #45: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=223, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=223, out_features=277, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=277, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 45, 'loss': 0.04807834068934123, 'accuracy': 0.8466666666666667, 'parameters': 63997}
# Individual #46: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=150, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=150, out_features=357, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=357, out_features=464, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=464, out_features=462, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=462, out_features=323, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=323, out_features=363, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=363, out_features=395, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=395, out_features=393, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=393, out_features=293, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=293, out_features=310, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=310, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# ), 'id': 46, 'loss': 0.07049023548762004, 'accuracy': 0.6666666666666666, 'parameters': 1209683}
# Individual #47: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=379, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=379, out_features=300, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=300, out_features=274, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=274, out_features=257, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=257, out_features=390, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=390, out_features=195, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=195, out_features=206, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=206, out_features=425, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=425, out_features=233, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=233, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 47, 'loss': 0.07324663241704304, 'accuracy': 0.3333333333333333, 'parameters': 674220}
# Individual #48: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=331, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=331, out_features=332, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=332, out_features=311, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=311, out_features=374, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=374, out_features=223, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=223, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# ), 'id': 48, 'loss': 0.05822990655899048, 'accuracy': 0.6666666666666666, 'parameters': 416427}
# Individual #49: {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=452, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=452, out_features=481, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=481, out_features=403, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=403, out_features=200, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=200, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# ), 'id': 49, 'loss': 0.05239598035812378, 'accuracy': 0.7666666666666667, 'parameters': 495802}

# %%
generation.calculate_fitness()
# Out:
# [{'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=179, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=179, out_features=271, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=271, out_features=427, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=427, out_features=435, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=435, out_features=307, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=307, out_features=488, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=488, out_features=196, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=196, out_features=277, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=277, out_features=436, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=436, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 3, 'loss': 0.0732745122909546, 'accuracy': 0.3333333333333333, 'parameters': 909087, 'fitness': 8}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=233, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=233, out_features=448, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=448, out_features=386, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=386, out_features=241, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=241, out_features=397, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=397, out_features=184, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=184, out_features=512, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=512, out_features=353, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=353, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 15, 'loss': 0.07123314221700032, 'accuracy': 0.3333333333333333, 'parameters': 818755, 'fitness': 15}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=196, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=196, out_features=368, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=368, out_features=307, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=307, out_features=259, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=259, out_features=470, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=470, out_features=486, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=486, out_features=249, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=249, out_features=438, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=438, out_features=494, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=494, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 21, 'loss': 0.07326417684555053, 'accuracy': 0.3333333333333333, 'parameters': 1066751, 'fitness': 17}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=243, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=243, out_features=309, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=309, out_features=166, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=166, out_features=172, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=172, out_features=191, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=191, out_features=274, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=274, out_features=359, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=359, out_features=349, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=349, out_features=248, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=248, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 11, 'loss': 0.070661989847819, 'accuracy': 0.25333333333333335, 'parameters': 554358, 'fitness': 18}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=327, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=327, out_features=350, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=350, out_features=249, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=249, out_features=210, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=210, out_features=354, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=354, out_features=426, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=426, out_features=245, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=245, out_features=415, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=415, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 16, 'loss': 0.08190188050270081, 'accuracy': 0.3333333333333333, 'parameters': 690211, 'fitness': 20}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=211, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=211, out_features=293, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=293, out_features=286, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=286, out_features=240, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=240, out_features=501, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=501, out_features=245, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=245, out_features=511, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=511, out_features=251, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=251, out_features=310, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=310, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 36, 'loss': 0.07344729661941528, 'accuracy': 0.3333333333333333, 'parameters': 793137, 'fitness': 29}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=491, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=491, out_features=295, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=295, out_features=151, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=151, out_features=301, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=301, out_features=273, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=273, out_features=196, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=196, out_features=284, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=284, out_features=157, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=157, out_features=367, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=367, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 18, 'loss': 0.07981854518254598, 'accuracy': 0.3333333333333333, 'parameters': 533976, 'fitness': 31}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=305, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=305, out_features=171, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=171, out_features=250, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=250, out_features=301, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=301, out_features=208, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=208, out_features=371, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=371, out_features=239, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=239, out_features=176, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=176, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 2, 'loss': 0.0732213576634725, 'accuracy': 0.3333333333333333, 'parameters': 444436, 'fitness': 32}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=510, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=510, out_features=384, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=384, out_features=389, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=389, out_features=467, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=467, out_features=142, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=142, out_features=128, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=128, out_features=353, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=353, out_features=460, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=460, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 23, 'loss': 0.07239339431126912, 'accuracy': 0.3933333333333333, 'parameters': 825189, 'fitness': 34}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=379, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=379, out_features=300, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=300, out_features=274, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=274, out_features=257, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=257, out_features=390, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=390, out_features=195, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=195, out_features=206, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=206, out_features=425, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=425, out_features=233, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=233, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 47, 'loss': 0.07324663241704304, 'accuracy': 0.3333333333333333, 'parameters': 674220, 'fitness': 35}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=411, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=411, out_features=264, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=264, out_features=232, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=232, out_features=343, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=343, out_features=217, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=217, out_features=262, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=262, out_features=136, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=136, out_features=498, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=498, out_features=210, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=210, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 39, 'loss': 0.08190187374750774, 'accuracy': 0.3333333333333333, 'parameters': 593403, 'fitness': 37}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=417, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=417, out_features=175, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=175, out_features=234, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=234, out_features=509, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=509, out_features=279, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=279, out_features=131, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=131, out_features=269, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=269, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# ), 'id': 17, 'loss': 0.07305783033370972, 'accuracy': 0.3333333333333333, 'parameters': 451322, 'fitness': 38}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=227, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=227, out_features=495, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=495, out_features=195, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=195, out_features=155, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=155, out_features=452, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=452, out_features=337, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=337, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# ), 'id': 19, 'loss': 0.06738431294759115, 'accuracy': 0.3333333333333333, 'parameters': 465282, 'fitness': 41}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=203, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=203, out_features=312, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=312, out_features=395, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=395, out_features=419, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=419, out_features=370, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=370, out_features=365, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=365, out_features=259, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=259, out_features=455, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=455, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 10, 'loss': 0.06148362159729004, 'accuracy': 0.6333333333333333, 'parameters': 859499, 'fitness': 43}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=378, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=378, out_features=250, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=250, out_features=500, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=500, out_features=373, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=373, out_features=172, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=172, out_features=294, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=294, out_features=299, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=299, out_features=493, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=493, out_features=296, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=296, out_features=165, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=165, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# ), 'id': 44, 'loss': 0.0708661925792694, 'accuracy': 0.6533333333333333, 'parameters': 956035, 'fitness': 43}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=223, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=223, out_features=493, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=493, out_features=277, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=277, out_features=472, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=472, out_features=380, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=380, out_features=201, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=201, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# ), 'id': 32, 'loss': 0.06270701050758362, 'accuracy': 0.6066666666666667, 'parameters': 636528, 'fitness': 48}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=417, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=417, out_features=334, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=334, out_features=416, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=416, out_features=157, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=157, out_features=430, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=430, out_features=270, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=270, out_features=365, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=365, out_features=210, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=210, out_features=418, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=418, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 1, 'loss': 0.06843905806541443, 'accuracy': 0.66, 'parameters': 796066, 'fitness': 52}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=466, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=466, out_features=133, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=133, out_features=423, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=423, out_features=170, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=170, out_features=197, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=197, out_features=145, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=145, out_features=393, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=393, out_features=345, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=345, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 7, 'loss': 0.07817335367202759, 'accuracy': 0.34, 'parameters': 449946, 'fitness': 53}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=234, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=234, out_features=243, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=243, out_features=350, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=350, out_features=202, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=202, out_features=344, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=344, out_features=257, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=257, out_features=326, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=326, out_features=231, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=231, out_features=452, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=452, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 38, 'loss': 0.07162819544474285, 'accuracy': 0.64, 'parameters': 638942, 'fitness': 53}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=316, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=316, out_features=206, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=206, out_features=359, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=359, out_features=231, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=231, out_features=130, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=130, out_features=413, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=413, out_features=418, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=418, out_features=426, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=426, out_features=506, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=506, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 8, 'loss': 0.06033379236857096, 'accuracy': 0.6666666666666666, 'parameters': 877747, 'fitness': 56}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=447, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=447, out_features=471, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=471, out_features=310, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=310, out_features=128, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=128, out_features=285, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=285, out_features=205, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=205, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# ), 'id': 30, 'loss': 0.06218456784884135, 'accuracy': 0.6266666666666667, 'parameters': 495384, 'fitness': 59}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=139, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=139, out_features=162, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=162, out_features=510, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=510, out_features=149, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=149, out_features=304, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=304, out_features=426, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=426, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# ), 'id': 31, 'loss': 0.06349273165067038, 'accuracy': 0.43333333333333335, 'parameters': 359455, 'fitness': 61}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=299, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=299, out_features=316, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=316, out_features=501, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=501, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# ), 'id': 6, 'loss': 0.060969424645106, 'accuracy': 0.6, 'parameters': 256618, 'fitness': 65}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=183, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=183, out_features=444, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=444, out_features=434, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=434, out_features=393, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=393, out_features=461, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=461, out_features=130, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=130, out_features=355, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=355, out_features=427, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=427, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 20, 'loss': 0.05571957310040792, 'accuracy': 0.6666666666666666, 'parameters': 888191, 'fitness': 65}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=191, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=191, out_features=487, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=487, out_features=276, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=276, out_features=383, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=383, out_features=329, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=329, out_features=372, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=372, out_features=223, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=223, out_features=432, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=432, out_features=444, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=444, out_features=3, bias=True)
#     (19): Softmax(dim=1)
#   )
# ), 'id': 24, 'loss': 0.05759632031122843, 'accuracy': 0.6666666666666666, 'parameters': 957868, 'fitness': 66}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=152, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=152, out_features=232, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=232, out_features=201, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=201, out_features=252, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=252, out_features=182, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=182, out_features=509, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=509, out_features=496, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=496, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# ), 'id': 5, 'loss': 0.0637717620531718, 'accuracy': 0.6666666666666666, 'parameters': 527637, 'fitness': 69}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=295, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=295, out_features=427, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=427, out_features=293, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=293, out_features=213, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=213, out_features=155, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=155, out_features=247, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=247, out_features=507, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=507, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# ), 'id': 9, 'loss': 0.05967965284983317, 'accuracy': 0.6666666666666666, 'parameters': 514855, 'fitness': 75}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=218, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=218, out_features=154, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=154, out_features=402, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=402, out_features=435, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=435, out_features=354, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=354, out_features=188, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=188, out_features=183, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=183, out_features=3, bias=True)
#     (15): Softmax(dim=1)
#   )
# ), 'id': 14, 'loss': 0.0650059994061788, 'accuracy': 0.6666666666666666, 'parameters': 528654, 'fitness': 78}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=325, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=325, out_features=306, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=306, out_features=192, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=192, out_features=275, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=275, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# ), 'id': 4, 'loss': 0.05999790787696838, 'accuracy': 0.66, 'parameters': 214228, 'fitness': 82}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=150, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=150, out_features=357, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=357, out_features=464, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=464, out_features=462, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=462, out_features=323, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=323, out_features=363, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=363, out_features=395, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=395, out_features=393, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=393, out_features=293, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=293, out_features=310, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=310, out_features=3, bias=True)
#     (21): Softmax(dim=1)
#   )
# ), 'id': 46, 'loss': 0.07049023548762004, 'accuracy': 0.6666666666666666, 'parameters': 1209683, 'fitness': 82}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=407, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=407, out_features=154, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=154, out_features=443, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=443, out_features=232, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=232, out_features=489, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=489, out_features=293, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=293, out_features=272, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=272, out_features=284, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=284, out_features=3, bias=True)
#     (17): Softmax(dim=1)
#   )
# ), 'id': 27, 'loss': 0.05604582111040751, 'accuracy': 0.6666666666666666, 'parameters': 652402, 'fitness': 84}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=236, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=236, out_features=350, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=350, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 0, 'loss': 0.05758402506510417, 'accuracy': 0.6666666666666666, 'parameters': 85183, 'fitness': 93}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=199, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=199, out_features=432, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=432, out_features=408, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=408, out_features=139, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=139, out_features=282, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=282, out_features=464, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=464, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# ), 'id': 26, 'loss': 0.05967965483665466, 'accuracy': 0.6666666666666666, 'parameters': 493097, 'fitness': 94}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=276, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=276, out_features=178, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=178, out_features=447, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=447, out_features=348, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=348, out_features=494, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=494, out_features=131, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=131, out_features=3, bias=True)
#     (13): Softmax(dim=1)
#   )
# ), 'id': 34, 'loss': 0.05988239010175069, 'accuracy': 0.6666666666666666, 'parameters': 524250, 'fitness': 96}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=339, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=339, out_features=395, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=395, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 12, 'loss': 0.057407337427139285, 'accuracy': 0.6666666666666666, 'parameters': 137183, 'fitness': 98}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=272, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=272, out_features=375, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=375, out_features=487, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=487, out_features=132, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=132, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# ), 'id': 25, 'loss': 0.05734206517537435, 'accuracy': 0.6666666666666666, 'parameters': 351662, 'fitness': 100}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=231, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=231, out_features=146, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=146, out_features=442, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=442, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# ), 'id': 13, 'loss': 0.05478837291399638, 'accuracy': 0.6666666666666666, 'parameters': 101330, 'fitness': 102}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=194, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=194, out_features=283, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=283, out_features=185, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=185, out_features=240, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=240, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# ), 'id': 22, 'loss': 0.06036105036735535, 'accuracy': 0.6666666666666666, 'parameters': 154058, 'fitness': 105}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=286, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=286, out_features=495, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=495, out_features=483, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=483, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# ), 'id': 43, 'loss': 0.058983410199483235, 'accuracy': 0.6666666666666666, 'parameters': 384515, 'fitness': 112}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=366, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=366, out_features=467, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=467, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 29, 'loss': 0.05898520747820536, 'accuracy': 0.6666666666666666, 'parameters': 174623, 'fitness': 113}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=376, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=376, out_features=164, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=164, out_features=140, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=140, out_features=326, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=326, out_features=325, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=325, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# ), 'id': 40, 'loss': 0.05898520747820536, 'accuracy': 0.6666666666666666, 'parameters': 240027, 'fitness': 114}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=156, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=156, out_features=238, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=238, out_features=429, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=429, out_features=153, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=153, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# ), 'id': 35, 'loss': 0.05731015841166178, 'accuracy': 0.6666666666666666, 'parameters': 206929, 'fitness': 115}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=331, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=331, out_features=332, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=332, out_features=311, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=311, out_features=374, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=374, out_features=223, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=223, out_features=3, bias=True)
#     (11): Softmax(dim=1)
#   )
# ), 'id': 48, 'loss': 0.05822990655899048, 'accuracy': 0.6666666666666666, 'parameters': 416427, 'fitness': 115}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=452, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=452, out_features=481, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=481, out_features=403, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=403, out_features=200, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=200, out_features=3, bias=True)
#     (9): Softmax(dim=1)
#   )
# ), 'id': 49, 'loss': 0.05239598035812378, 'accuracy': 0.7666666666666667, 'parameters': 495802, 'fitness': 116}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=441, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=441, out_features=260, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=260, out_features=321, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=321, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# ), 'id': 28, 'loss': 0.04951334714889526, 'accuracy': 0.76, 'parameters': 201872, 'fitness': 130}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=231, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=231, out_features=451, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=451, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 37, 'loss': 0.055101219018300375, 'accuracy': 0.6733333333333333, 'parameters': 107143, 'fitness': 131}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=469, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=469, out_features=343, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=343, out_features=207, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=207, out_features=3, bias=True)
#     (7): Softmax(dim=1)
#   )
# ), 'id': 33, 'loss': 0.04538963238398234, 'accuracy': 0.88, 'parameters': 235387, 'fitness': 135}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=278, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=278, out_features=226, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=226, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 41, 'loss': 0.051259345213572186, 'accuracy': 0.7333333333333333, 'parameters': 65125, 'fitness': 136}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=494, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=494, out_features=313, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=313, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 42, 'loss': 0.04933411439259847, 'accuracy': 0.82, 'parameters': 158347, 'fitness': 136}, {'model': ConstructNet(
#   (loss_fn): CrossEntropyLoss()
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=223, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=223, out_features=277, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=277, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# ), 'id': 45, 'loss': 0.04807834068934123, 'accuracy': 0.8466666666666667, 'parameters': 63997, 'fitness': 145}]
